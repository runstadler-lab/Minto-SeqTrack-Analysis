# %%
import pandas as pd

# %%
segments = range(1,9)
segments
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
segment1 = pd.read_csv('2.1 - Segment Transmission/Segment %s Transmissions.csv' % '1', index_col='Strain Name')
segment1
# Out:
#                                                 A/American black duck/Illinois/4119/2009  \
# Strain Name
# A/American black duck/Illinois/4119/2009                                        1.000000
# A/American black duck/New Brunswick/00321/2010                                  0.954486
# A/American black duck/New Brunswick/00322/2010                                  0.969224
# A/American black duck/New Brunswick/00326/2010                                  0.958981
# A/American black duck/New Brunswick/00328/2010                                  0.958981
# A/American black duck/New Brunswick/00344/2010                                  0.000000
# A/American black duck/New Brunswick/00385/2010                                  0.958388
# A/American black duck/New Brunswick/00410/2010                                  0.958549
# A/American black duck/New Brunswick/00424/2010                                  0.969658
# ...

# %%
segment2 = pd.read_csv('2.1 - Segment Transmission/Segment %s Transmissions.csv' % '2', index_col='Strain Name')
segment2
# Out:
#                                                    A/American black duck/Illinois/4119/2009  \
# Strain Name
# A/American black duck/Illinois/4119/2009                                           1.000000
# A/American black duck/New Brunswick/00321/2010                                     0.990480
# A/American black duck/New Brunswick/00322/2010                                     0.000000
# A/American black duck/New Brunswick/00326/2010                                     0.992228
# A/American black duck/New Brunswick/00328/2010                                     0.992211
# A/American black duck/New Brunswick/00344/2010                                     0.000000
# A/American black duck/New Brunswick/00385/2010                                     0.992228
# A/American black duck/New Brunswick/00410/2010                                     0.991364
# A/American black duck/New Brunswick/00424/2010                                     0.000000
# ...

# %%
segtrans = pd.read_csv('2.1 - Segment Transmission/Segment 1 Transmissions.csv', index_col = 'Strain Name')
segments = range(2,9)
for segment in segments:
    data = pd.read_csv('2.1 - Segment Transmission/Segment %d Transmissions.csv' % segment, index_col = 'Strain Name')
    segtrans = segtrans + data

# %%
len(segtrans)
# Out:
# 1456

# %%
segtrans.to_csv('2.2 - Full Transmission/Estimated 8 Segment Transmissions.csv')
