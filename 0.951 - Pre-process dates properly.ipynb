# %%
import pandas as pd
from datetime import datetime

# %%
data = pd.read_csv('Raw Data/20140211 Minto and North America Combined.csv', index_col=0, parse_dates=['Collection Date'])
data
# Out:
#      Collection Date Complete Genome Country                   Host Species  \
# 0         2008-10-26             Yes     USA  IRD:American Black Duck/Avian
# 1         2009-11-29             Yes     USA  IRD:American Black Duck/Avian
# 2         2010-08-08             Yes  Canada                      IRD:Avian
# 3         2010-08-08             Yes  Canada                      IRD:Avian
# 4         2010-08-08             Yes  Canada                      IRD:Avian
# 5         2010-08-08             Yes  Canada                      IRD:Avian
# 6         2010-08-08             Yes  Canada                      IRD:Avian
# 7         2010-08-09             Yes  Canada                      IRD:Avian
# 8         2010-08-10             Yes  Canada                      IRD:Avian
# 9         2010-08-10             Yes  Canada                      IRD:Avian
# 10        2010-08-10             Yes  Canada                      IRD:Avian
# ...

# %%
# data2 = pd.DataFrame()
# for row in data.iterrows():
#     if len(row[1]['Collection Date'].split('/')) == 3:
#         data2 = data2.append(row[1])
        
#     if len(row[1]['Collection Date'].split('-')) == 3:
#         data2 = data2.append(row[1])

# %%
data.to_csv('Raw Data/20140211 Minto and North America Combined Dates Cleaned.csv')

# %%
data2 = pd.read_csv('Raw Data/20140211 Minto and North America Combined Dates Cleaned.csv', index_col=0, parse_dates=['Collection Date'])
data2
len(data2)
# Out:
# 1787

# %%
# Query the data for its properties
# There are two lines for each query: a comment line, and a code line.
# Uncomment the code line by deleting the "#" sign before it to view results of the query.

# Strains collected outside of 2009 and 2010
# data2[(data2['Collection Date'] > datetime(2010, 12, 31)) | (data2['Collection Date'] < datetime(2009, 1, 1))]

# Strains not from Interior Alaska
data2[data2['Strain Name'].str.contains("Interior Alaska") == False]

# Strains collected in 2008
# data2[(data2['Collection Date'] >= datetime(2008, 1, 1)) & (data2['Collection Date'] <= datetime(2008, 12, 31))]

# Strains collected in 2009
# data2[(data2['Collection Date'] >= datetime(2009, 1, 1)) & (data2['Collection Date'] <= datetime(2009, 12, 31))]

# Strains collected in 2010
# data2[(data2['Collection Date'] >= datetime(2010, 1, 1)) & (data2['Collection Date'] <= datetime(2010, 12, 31))]

# Strains collected in 2011
# data2[(data2['Collection Date'] >= datetime(2011, 1, 1)) & (data2['Collection Date'] <= datetime(2011, 12, 31))]
# Out:
#      Collection Date Complete Genome Country  \
# 0         2008-10-26             Yes     USA
# 1         2009-11-29             Yes     USA
# 2         2010-08-08             Yes  Canada
# 3         2010-08-08             Yes  Canada
# 4         2010-08-08             Yes  Canada
# 5         2010-08-08             Yes  Canada
# 6         2010-08-08             Yes  Canada
# 7         2010-08-09             Yes  Canada
# 8         2010-08-10             Yes  Canada
# 9         2010-08-10             Yes  Canada
# 10        2010-08-10             Yes  Canada
# 11        2010-08-11             Yes  Canada
# 12        2010-08-12             Yes  Canada
# 13        2010-08-12             Yes  Canada
# 14        2010-08-12             Yes  Canada
# 15        2010-08-12             Yes  Canada
# 16        2010-08-12             Yes  Canada
# 17        2010-08-12             Yes  Canada
# 18        2010-08-12             Yes  Canada
# 19        2010-08-12             Yes  Canada
# ...
