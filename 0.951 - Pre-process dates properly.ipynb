# %%
import pandas as pd

# %%
data = pd.read_csv('20140211 Minto and North America Combined.csv', index_col=0)

# %%
data2 = pd.DataFrame()
for row in data.iterrows():
    if len(row[1]['Collection Date'].split('/')) == 3:
        data2 = data2.append(row[1])
        
    if len(row[1]['Collection Date'].split('-')) == 3:
        data2 = data2.append(row[1])

# %%
data2.to_csv('20140211 Minto and North America Combined Dates Cleaned.csv')

# %%
data2 = pd.read_csv('temp.csv', index_col=0, parse_dates=['Collection Date'])
data2
# Out:
#      Collection Date Complete Genome    Country Host Species  \
# 414       2009-08-03             Yes        USA         AGWT
# 415       2009-08-03             Yes        USA         AGWT
# 416       2009-08-03             Yes        USA         AGWT
# 422       2009-08-03             Yes        USA         AGWT
# 425       2009-08-04             Yes        USA         AGWT
# 440       2009-08-06             Yes        USA         AGWT
# 2446      2014-11-09             Yes        USA     IRD:null
# 2503      2014-09-10             Yes  Guatemala      IRD:Bat
# 2504      2014-05-09             Yes  Guatemala      IRD:Bat
# 2505      2014-05-09             Yes  Guatemala      IRD:Bat
# 41        2010-07-26             Yes        USA         MALL
# 72        2010-08-01             Yes        USA         MALL
# 75        2010-08-01             Yes        USA         MALL
# 96        2010-08-04             Yes        USA         MALL
# ...
