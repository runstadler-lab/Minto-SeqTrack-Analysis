# %%
import pandas as pd

# %%
minto = pd.read_csv('Minto Flats 520 with Accessions.csv')
minto
# Out:
#     Sample ID                                        Common Name  \
# 0   10BM00303  A/northern pintail/Interior Alaska/10BM00303R0...
# 1   10BM00849  A/northern pintail/Interior Alaska/10BM00849R2...
# 2   10BM01929  A/mallard/Interior Alaska/10BM01929R0/2010(H10N7)
# 3   10BM02111  A/mallard/Interior Alaska/10BM02111R0/2010(H12N5)
# 4   10BM02530   A/mallard/Interior Alaska/10BM02530R0/2010(H4N6)
# 5   10BM02539  A/northern pintail/Interior Alaska/10BM02539R0...
# 6   10BM02561  A/northern pintail/Interior Alaska/10BM02561R0...
# 7   10BM02585  A/northern pintail/Interior Alaska/10BM02585R0...
# 8   10BM02593  A/northern shoveler/Interior Alaska/10BM02593R...
# 9   10BM02644   A/mallard/Interior Alaska/10BM02644R0/2010(H4N6)
# 10  10BM02791  A/northern pintail/Interior Alaska/10BM02791R0...
# 11  10BM02892  A/northern shoveler/Interior Alaska/10BM02892R...
# 12  10BM02980   A/mallard/Interior Alaska/10BM02980R0/2010(H9N2)
# ...
