# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import json
import bokeh

from Bio import AlignIO, SeqIO
from networkx.readwrite import json_graph
from copy import deepcopy


# %matplotlib inline

# %%
# Load in Minto Flats' data sheet that contains the age class of the ducks
duck_ages = pd.read_csv('Raw Data/20140916 Strain Names with Ages.csv')

# If we get the unique values of the ages, we should get: 
# array(['1B', '1C', '2A', '2B', '2C', '3', 'AHY', 'HY'], dtype=object) 
np.unique(duck_ages['Age'].values)

# Based on that, do a replace.
old_ages = ['1B', '1C', '2A', '2B', '2C', '3', 'AHY', 'HY']
new_ages = ['DKL', 'DKL', 'DKL', 'DKL', 'DKL', 'DKL', 'ADT', 'FLG']

duck_ages = duck_ages.replace(old_ages, new_ages)
duck_ages

# Ensure that the common names do not contain the subtype information in it.
duck_ages['Common Name'] = duck_ages['Common Name'].str.split('(').str[0]
duck_ages = duck_ages.set_index('Common Name')
duck_ages['Age1'] = duck_ages['Age']
duck_ages['Age2'] = duck_ages['Age']
duck_ages
# Out:
#                                                                Age Age1 Age2
# Common Name
# A/northern pintail/Interior Alaska/10BM00303R0/2010            ADT  ADT  ADT
# A/northern pintail/Interior Alaska/10BM00849R2/2010            ADT  ADT  ADT
# A/mallard/Interior Alaska/10BM01929R0/2010                     ADT  ADT  ADT
# A/mallard/Interior Alaska/10BM02111R0/2010                     ADT  ADT  ADT
# A/mallard/Interior Alaska/10BM02530R0/2010                     ADT  ADT  ADT
# A/northern pintail/Interior Alaska/10BM02539R0/2010            ADT  ADT  ADT
# A/northern pintail/Interior Alaska/10BM02561R0/2010            ADT  ADT  ADT
# A/northern pintail/Interior Alaska/10BM02585R0/2010            ADT  ADT  ADT
# A/northern shoveler/Interior Alaska/10BM02593R0/2010           ADT  ADT  ADT
# A/mallard/Interior Alaska/10BM02644R0/2010                     ADT  ADT  ADT
# A/northern pintail/Interior Alaska/10BM02791R0/2010            ADT  ADT  ADT
# A/northern shoveler/Interior Alaska/10BM02892R0/2010           ADT  ADT  ADT
# A/mallard/Interior Alaska/10BM02980R0/2010                     DKL  DKL  DKL
# A/mallard/Interior Alaska/10BM03979R0/2010                     ADT  ADT  ADT
# A/American green-winged teal/Interior Alaska/10BM04207R0/2010  DKL  DKL  DKL
# A/mallard/Interior Alaska/10BM04564R1/2010                     ADT  ADT  ADT
# A/mallard/Interior Alaska/10BM04618R0/2010                     ADT  ADT  ADT
# A/mallard/Interior Alaska/10BM04623R0/2010                     ADT  ADT  ADT
# A/mallard/Interior Alaska/10BM04624R0/2010                     ADT  ADT  ADT
# A/mallard/Interior Alaska/10BM04626R0/2010                     ADT  ADT  ADT
# A/northern pintail/Interior Alaska/10BM04668R0/2010            ADT  ADT  ADT
# A/northern pintail/Interior Alaska/10BM04704R0/2010            ADT  ADT  ADT
# A/northern pintail/Interior Alaska/10BM04722R0/2010            ADT  ADT  ADT
# A/mallard/Interior Alaska/10BM04988R0/2010                     ADT  ADT  ADT
# A/northern pintail/Interior Alaska/10BM05034R0/2010            DKL  DKL  DKL
# A/American green-winged teal/Interior Alaska/10BM05165R0/2010  DKL  DKL  DKL
# A/northern pintail/Interior Alaska/10BM05171R0/2010            DKL  DKL  DKL
# A/mallard/Interior Alaska/10BM05247R0/2010                     DKL  DKL  DKL
# A/mallard/Interior Alaska/10BM05249R0/2010                     DKL  DKL  DKL
# A/mallard/Interior Alaska/10BM05337R0/2010                     DKL  DKL  DKL
# ...                                                            ...  ...  ...
# A/northern pintail/Interior Alaska/9BM8803R0/2009              ADT  ADT  ADT
# A/northern pintail/Interior Alaska/9BM8815R0/2009              FLG  FLG  FLG
# A/mallard/Interior Alaska/9BM8829R0/2009                       FLG  FLG  FLG
# A/northern pintail/Interior Alaska/9BM8907R0/2009              FLG  FLG  FLG
# A/mallard/Interior Alaska/9BM8921R0/2009                       ADT  ADT  ADT
# A/mallard/Interior Alaska/9BM8935R0/2009                       FLG  FLG  FLG
# A/northern pintail/Interior Alaska/9BM8967R0/2009              FLG  FLG  FLG
# A/northern pintail/Interior Alaska/9BM9005R0/2009              FLG  FLG  FLG
# A/northern pintail/Interior Alaska/9BM9037R0/2009              FLG  FLG  FLG
# A/mallard/Interior Alaska/9BM9049R0/2009                       ADT  ADT  ADT
# A/northern pintail/Interior Alaska/9BM9065R0/2009              FLG  FLG  FLG
# A/northern pintail/Interior Alaska/9BM9129R0/2009              FLG  FLG  FLG
# A/northern pintail/Interior Alaska/9BM9153R0/2009              FLG  FLG  FLG
# A/mallard/Interior Alaska/9BM9201R0/2009                       FLG  FLG  FLG
# A/mallard/Interior Alaska/9BM9335R0/2009                       ADT  ADT  ADT
# A/northern pintail/Interior Alaska/9BM9383R0/2009              ADT  ADT  ADT
# A/northern pintail/Interior Alaska/9BM9447R0/2009              FLG  FLG  FLG
# A/mallard/Interior Alaska/9BM9601R0/2009                       ADT  ADT  ADT
# A/northern pintail/Interior Alaska/9BM9611R0/2009              FLG  FLG  FLG
# A/northern pintail/Interior Alaska/9BM9663R0/2009              FLG  FLG  FLG
# A/mallard/Interior Alaska/9BM9683R2/2009                       ADT  ADT  ADT
# A/mallard/Interior Alaska/9BM9717R0/2009                       FLG  FLG  FLG
# A/mallard/Interior Alaska/9BM9755R0/2009                       FLG  FLG  FLG
# A/northern pintail/Interior Alaska/9BM9955R0/2009              FLG  FLG  FLG
# A/northern pintail/Interior Alaska/9BM9973R0/2009              FLG  FLG  FLG
# A/northern pintail/Interior Alaska/9BM9975R0/2009              FLG  FLG  FLG
# A/mallard/Interior Alaska/9BM9983R0/2009                       FLG  FLG  FLG
# A/mallard/Interior Alaska/9BM9984R0/2009                       FLG  FLG  FLG
# A/mallard/Interior Alaska/9BM9985R0/2009                       ADT  ADT  ADT
# A/northern pintail/Interior Alaska/9BM9989R0/2009              FLG  FLG  FLG
#
# [520 rows x 3 columns]

# %%
# We will load the undirected version of the transmission graph and use the links to plot the arc plots.

# Load data:
data = pd.read_csv('3.10 - Full Transmission as CSV/Undirected Full Transmissions.csv', 
                   index_col=0, 
                   parse_dates=['Isolation Date1', 'Isolation Date2'])

# Filter data such that we only consider isolates in Interior Alaska
data = data[(data['State1'] == 'Interior Alaska') & (data['State2'] == 'Interior Alaska')]

# To perform merge, set index of data to be Isolate1.
data = data.set_index("Isolate1").join(duck_ages['Age1'])
data.index.name = 'Isolate1'
data = data.reset_index().set_index("Isolate2").join(duck_ages['Age2'])
data.index.name = "Isolate2"
data = data.reset_index()

# Impute missing age data with adult ages by default.
data['Age1'] = data['Age1'].fillna('ADT')
data['Age2'] = data['Age2'].fillna('ADT')

# %%
# Create NetworkX Graph
G = nx.DiGraph()

# Add in node information
for row in data.iterrows():
    G.add_node(row[1]['Isolate1'], 
               host = row[1]['Host1'],
               isolation_date = row[1]['Isolation Date1'],
               state = row[1]['State1'],
               subtype = row[1]['Subtype1'],
               age = row[1]['Age1'])
    G.add_node(row[1]['Isolate2'],
               host = row[1]['Host2'],
               isolation_date = row[1]['Isolation Date2'],
               state = row[1]['State2'],
               subtype = row[1]['Subtype2'],
               age = row[1]['Age2'])
    
    G.add_edge(row[1]['Isolate1'],
               row[1]['Isolate2'],
               tr_timeclass = row[1]['Time Class'],
               time_delta = row[1]['Time Delta'],
               trtype = row[1]['Transmission Type'],
               weight = row[1]['Weight'])

# %%
for edge in G.edges(data=True):
    node1 = edge[0]
    node2 = edge[1]
    if G.node[node1]['age'] == 'DKL' and G.node[node2]['age'] == 'DKL':
        edge[2]['tr_age'] = 'DD'
    elif G.node[node1]['age'] == 'DKL' and G.node[node2]['age'] == 'FLG':
        edge[2]['tr_age'] = 'DF'
    elif G.node[node1]['age'] == 'DKL' and G.node[node2]['age'] == 'ADT':
        edge[2]['tr_age'] = 'DA'
    elif G.node[node1]['age'] == 'FLG' and G.node[node2]['age'] == 'FLG':
        edge[2]['tr_age'] = 'FF'
    elif G.node[node1]['age'] == 'FLG' and G.node[node2]['age'] == 'ADT':
        edge[2]['tr_age'] = 'FA'
    elif G.node[node1]['age'] == 'ADT' and G.node[node2]['age'] == 'ADT':
        edge[2]['tr_age'] = 'AA'
    else:
        edge[2]['tr_age'] = 'NA'

# %%
G.edges(data=True)
# Out:
# [('A/mallard/Interior Alaska/9BM1949/2009',
#   'A/mallard/Interior Alaska/9BM1974/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.999567999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM1949/2009',
#   'A/mallard/Interior Alaska/9BM2250R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 7.0,
#    'weight': 7.997994999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10835R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10813R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.983961999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12178R0/2010',
#   'A/mallard/Interior Alaska/10BM11416R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.998864,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/9BM6223R0/2009',
#   'A/American green-winged teal/Interior Alaska/9BM6225R0/2009',
#   {'tr_age': 'AA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/9BM6223R0/2009',
#   'A/American green-winged teal/Interior Alaska/9BM6222R0/2009',
#   {'tr_age': 'AA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/9BM6223R0/2009',
#   'A/northern pintail/Interior Alaska/9BM5376R0/2009',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 4.0,
#    'weight': 7.999567999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/9BM6223R0/2009',
#   'A/northern pintail/Interior Alaska/9BM9005R0/2009',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 8.0,
#    'weight': 7.995710000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/9BM6223R0/2009',
#   'A/northern pintail/Interior Alaska/9BM7696R0/2009',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 5.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM4347R0/2009',
#   'A/American green-winged teal/Interior Alaska/9BM5041R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 2.0,
#    'weight': 7.993006000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM4347R0/2009',
#   'A/northern pintail/Interior Alaska/9BM4660R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM4347R0/2009',
#   'A/northern shoveler/Interior Alaska/9BM4905R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 2.0,
#    'weight': 7.993804000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM4347R0/2009',
#   'A/northern pintail/Interior Alaska/9BM4641R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.997361,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM09539R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09481R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.999133,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM09539R0/2010',
#   'A/mallard/Interior Alaska/10BM09548R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.996372,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM09539R0/2010',
#   'A/mallard/Interior Alaska/10BM09528R0/2010',
#   {'tr_age': 'AA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.9995350000000025,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/10BM08134R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 7.9951050000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/10BM08134R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 7.9951050000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11317R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10287R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.998075,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM1957/2009',
#   'A/mallard/Interior Alaska/9BM2259/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta':
0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM8448R0/2009',
#   'A/northern pintail/Interior Alaska/10BM00849R2/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Intra-Species',
#    'time_delta': 286.0,
#    'weight': 7.997935999999997,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern pintail/Interior Alaska/9BM8448R0/2009',
#   'A/mallard/Interior Alaska/9BM8474R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM2750R0/2009',
#   'A/mallard/Interior Alaska/9BM3076R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 3.0,
#    'weight': 7.999547,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM2750R0/2009',
#   'A/mallard/Interior Alaska/9BM3357R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 6.0,
#    'weight': 7.999547,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12177R0/2010',
#   'A/American green-winged teal/Interior Alaska/10BM08422R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 9.0,
#    'weight': 7.989471000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12177R0/2010',
#   'A/northern pintail/Interior Alaska/10BM12163R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 7.9989820000000025,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM09159R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09101R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.997975,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM09159R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09102R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.997975,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM09159R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09104R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.997975,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11151R0/2009',
#   'A/American green-winged teal/Interior Alaska/9BM4407R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 22.0,
#    'weight': 7.9986039999999985,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern pintail/Interior Alaska/9BM11151R0/2009',
#   'A/mallard/Interior Alaska/9BM11351R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/9BM2925R0/2009',
#   'A/mallard/Interior Alaska/9BM2388R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Inter-Species',
#    'time_delta': 3.0,
#    'weight': 7.998985,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/9BM2925R0/2009',
#   'A/mallard/Interior Alaska/9BM2351R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Inter-Species',
#    'time_delta': 4.0,
#    'weight': 7.999417,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/9BM4905R0/2009',
#   'A/northern pintail/Interior Alaska/9BM8803R0/2009',
#   {'tr_age': 'AA',
#    'trtype': 'Inter-Species',
#    'time_delta': 13.0,
#    'weight': 7.9981490000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM1964/2009',
#   'A/mallard/Interior Alaska/9BM1959/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.996810000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM00849R2/2010',
#   'A/northern pintail/Interior Alaska/9BM10525R2/2009',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 280.0,
#    'weight': 7.997935999999997,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/mallard/Interior Alaska/9BM2259/2009',
#   'A/mallard/Interior Alaska/9BM2535R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.997216000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM11351R0/2009',
#   'A/American green-winged teal/Interior Alaska/9BM4407R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 22.0,
#    'weight': 7.9986039999999985,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern pintail/Interior Alaska/9BM7118R1/2009',
#   'A/northern pintail/Interior Alaska/9BM8553R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 4.0,
#    'weight': 7.996977,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM7118R1/2009',
#   'A/mallard/Interior Alaska/9BM10051R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 9.0,
#    'weight': 7.997242,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM8459R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10525R2/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 6.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM8459R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10146R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 5.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM8459R0/2009',
#   'A/northern pintail/Interior Alaska/9BM11325R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 8.0,
#    'weight': 7.999567999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM8459R0/2009',
#   'A/northern pintail/Interior Alaska/10BM00849R2/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Intra-Species',
#    'time_delta': 286.0,
#    'weight': 7.997935999999997,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern pintail/Interior Alaska/9BM8459R0/2009',
#   'A/mallard/Interior Alaska/9BM8474R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12534R0/2010',
#   'A/mallard/Interior Alaska/10BM07072R0/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Intra-Species',
#    'time_delta': 13.0,
#    'weight': 7.995495999999997,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12049R0/2010',
#   'A/mallard/Interior Alaska/10BM11420R0/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.998993,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12049R0/2010',
#   'A/mallard/Interior Alaska/10BM11414R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.998993,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM10166R0/2010',
#   'A/mallard/Interior Alaska/10BM09818R0/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.999414,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11358R1/2009',
#   'A/American green-winged teal/Interior Alaska/9BM4407R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 22.0,
#    'weight': 7.997737000000001,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/mallard/Interior Alaska/10BM05797R0/2010',
#   'A/mallard/Interior Alaska/10BM06828R0/2010',
#   {'tr_age': 'DF',
#    'trtype': 'Intra-Species',
#    'time_delta': 5.0,
#    'weight': 7.989933999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM05797R0/2010',
#   'A/mallard/Interior Alaska/10BM10000R0/2010',
#   {'tr_age': 'DF',
#    'trtype': 'Intra-Species',
#    'time_delta': 13.0,
#    'weight': 7.990054999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM05797R0/2010',
#   'A/northern pintail/Interior Alaska/10BM07597R0/2010',
#   {'tr_age': 'DF',
#    'trtype': 'Inter-Species',
#    'time_delta': 7.0,
#    'weight': 7.984493,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM05337R0/2010',
#   'A/mallard/Interior Alaska/10BM05249R0/2010',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.997160000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM12326R0/2009',
#   'A/northern pintail/Interior Alaska/9BM11757R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 14.0,
#    'weight': 7.976176,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11325R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10525R2/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.999567999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11325R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10146R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 3.0,
#    'weight': 7.999567999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11325R0/2009',
#   'A/mallard/Interior Alaska/9BM8474R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 8.0,
#    'weight': 7.999567999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11917R0/2009',
#   'A/northern shoveler/Interior Alaska/9BM4787R0/2009',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 21.0,
#    'weight': 7.990690999999999,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10222R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10224R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10238R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10218R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.999547,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10210R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM11179R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.999115,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10236R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10234R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM10563R2/2009',
#   'A/northern pintail/Interior Alaska/9BM7620R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 8.0,
#    'weight': 7.9804650000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM8935R0/2009',
#   'A/northern pintail/Interior Alaska/9BM7799R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 3.0,
#    'weight': 7.996874000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM09164R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09101R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.999425,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM09164R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09102R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.999425,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM09164R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09104R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.999425,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM6290R0/2009',
#   'A/mallard/Interior Alaska/9BM11867R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 16.0,
#    'weight': 7.985789,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern pintail/Interior Alaska/9BM6290R0/2009',
#   'A/northern pintail/Interior Alaska/9BM8907R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 8.0,
#    'weight': 7.979068000000002,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11231R0/2009',
#   'A/northern pintail/Interior Alaska/9BM12211R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 3.0,
#    'weight': 7.9985490000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11231R0/2009',
#   'A/northern pintail/Interior Alaska/9BM12210R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 3.0,
#    'weight': 7.9985490000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/10BM05165R0/2010',
#   'A/northern shoveler/Interior Alaska/10BM02593R0/2010',
#   {'tr_age': 'DA',
#    'trtype': 'Inter-Species',
#    'time_delta': 29.0,
#    'weight': 7.989718999999999,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern shoveler/Interior Alaska/10BM05408R0/2010',
#   'A/mallard/Interior Alaska/10BM05249R0/2010',
#   {'tr_age': 'DD',
#    'trtype': 'Inter-Species',
#    'time_delta': 2.0,
#    'weight': 7.996676,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/10BM05408R0/2010',
#   'A/ring-necked duck/Interior Alaska/10BM05617R0/2010',
#   {'tr_age': 'DA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.995486,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/10BM05408R0/2010',
#   'A/mallard/Interior Alaska/10BM05247R0/2010',
#   {'tr_age': 'DD',
#    'trtype': 'Inter-Species',
#    'time_delta': 2.0,
#    'weight': 7.996488999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/10BM05408R0/2010',
#   'A/northern pintail/Interior Alaska/10BM07040R0/2010',
#   {'tr_age': 'DF',
#    'trtype': 'Inter-Species',
#    'time_delta': 7.0,
#    'weight': 7.990434,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/10BM05408R0/2010',
#   'A/American green-winged teal/Interior Alaska/10BM05165R0/2010',
#   {'tr_age': 'DD',
#    'trtype': 'Inter-Species',
#    'time_delta': 3.0,
#    'weight': 7.995918,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11583R0/2009',
#   'A/northern pintail/Interior Alaska/9BM11358R1/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM11420R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 8.0,
#    'weight': 7.996035000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM11420R0/2010',
#   'A/mallard/Interior Alaska/10BM11415R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.9985399999999975,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM11420R0/2010',
#   'A/mallard/Interior Alaska/10BM11418R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.999136,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM11420R0/2010',
#   'A/mallard/Interior Alaska/10BM11419R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.998683,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM11420R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 8.0,
#    'weight': 7.996035000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM11420R0/2010',
#   'A/mallard/Interior Alaska/10BM11414R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM07993R0/2010',
#   'A/mallard/Interior Alaska/10BM04626R0/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 16.0,
#    'weight': 7.991765999999997,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern pintail/Interior Alaska/9BM9975R0/2009',
#   'A/mallard/Interior Alaska/9BM8471R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 5.0,
#    'weight': 7.9342510000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM11065R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10287R0/2009',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 2.0,
#    'weight': 7.997057000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM11416R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 8.0,
#    'weight': 7.995331,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM12180R0/2009',
#   'A/northern pintail/Interior Alaska/9BM12176R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM12180R0/2009',
#   'A/northern pintail/Interior Alaska/9BM8907R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 9.0,
#    'weight': 7.975417999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM12180R0/2009',
#   'A/mallard/Interior Alaska/9BM11965R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 7.998683,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM12552R0/2010',
#   'A/American green-winged teal/Interior Alaska/10BM08422R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 10.0,
#    'weight': 7.991981,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM06872R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 4.0,
#    'weight': 7.9937960000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM06872R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 4.0,
#    'weight': 7.9937960000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/10BM05649R0/2010',
#   'A/mallard/Interior Alaska/10BM05900R0/2010',
#   {'tr_age': 'DA',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 7.999134,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/10BM05649R0/2010',
#   'A/ring-necked duck/Interior Alaska/10BM05792R0/2010',
#   {'tr_age': 'DA',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM07971R0/2010',
#   'A/mallard/Interior Alaska/10BM02530R0/2010',
#   {'tr_age': 'AA',
#    'trtype': 'Intra-Species',
#    'time_delta': 42.0,
#    'weight': 7.990558,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/mallard/Interior Alaska/10BM10176R0/2010',
#   'A/mallard/Interior Alaska/10BM10173R0/2010',
#   {'tr_age': 'AA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.9991020000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM10176R0/2010',
#   'A/northern pintail/Interior Alaska/10BM04704R0/2010',
#   {'tr_age': 'AA',
#    'trtype': 'Inter-Species',
#    'time_delta': 21.0,
#    'weight': 7.999567,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern pintail/Interior Alaska/9BM10146R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10525R2/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10146R0/2009',
#   'A/northern pintail/Interior Alaska/10BM00849R2/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Intra-Species',
#    'time_delta': 281.0,
#    'weight': 7.997935999999997,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern pintail/Interior Alaska/9B
2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'})]

# %%
# This is a custom function for serializing dates such that it is JSON compatible. 
# It gets used right at the last step prior to the JSON dump.
from dateutil.tz import tzutc

UTC = tzutc()

def serialize_date(dt):
    """
    Serialize a date/time value into an ISO8601 text representation
    adjusted (if needed) to UTC timezone.

    For instance:
    >>> serialize_date(datetime(2012, 4, 10, 22, 38, 20, 604391))
    '2012-04-10T22:38:20.604391Z'
    """
    #if dt.tzinfo:
    #    dt = dt.astimezone(UTC)
    return dt.isoformat()

# %%
# Dump the graph as a JSON node-link file.
# Prior to doing this, serialize all of the node dates to be JSON serializable.
G_serialized = deepcopy(G)

for node in G_serialized.nodes(data=True):
    node[1]['isolation_date'] = serialize_date(node[1]['isolation_date'])

jsongraph = json_graph.node_link_data(G_serialized) # node-link format to serialize
json.dump(jsongraph, open('viz/arcage.json','w'))

# %%
G_serialized.edges(data=True)
# Out:
# [('A/mallard/Interior Alaska/9BM1949/2009',
#   'A/mallard/Interior Alaska/9BM1974/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.999567999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM1949/2009',
#   'A/mallard/Interior Alaska/9BM2250R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 7.0,
#    'weight': 7.997994999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10835R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10813R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.983961999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12178R0/2010',
#   'A/mallard/Interior Alaska/10BM11416R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.998864,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/9BM6223R0/2009',
#   'A/American green-winged teal/Interior Alaska/9BM6225R0/2009',
#   {'tr_age': 'AA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/9BM6223R0/2009',
#   'A/American green-winged teal/Interior Alaska/9BM6222R0/2009',
#   {'tr_age': 'AA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/9BM6223R0/2009',
#   'A/northern pintail/Interior Alaska/9BM5376R0/2009',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 4.0,
#    'weight': 7.999567999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/9BM6223R0/2009',
#   'A/northern pintail/Interior Alaska/9BM9005R0/2009',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 8.0,
#    'weight': 7.995710000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/9BM6223R0/2009',
#   'A/northern pintail/Interior Alaska/9BM7696R0/2009',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 5.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM4347R0/2009',
#   'A/American green-winged teal/Interior Alaska/9BM5041R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 2.0,
#    'weight': 7.993006000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM4347R0/2009',
#   'A/northern pintail/Interior Alaska/9BM4660R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM4347R0/2009',
#   'A/northern shoveler/Interior Alaska/9BM4905R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 2.0,
#    'weight': 7.993804000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM4347R0/2009',
#   'A/northern pintail/Interior Alaska/9BM4641R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.997361,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM3016R0/2009',
#   'A/mallard/Interior Alaska/9BM3078R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM3016R0/2009',
#   'A/mallard/Interior Alaska/9BM3361R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 4.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM3016R0/2009',
#   'A/mallard/Interior Alaska/9BM3076R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM3016R0/2009',
#   'A/mallard/Interior Alaska/9BM2751R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.997020000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM3016R0/2009',
#   'A/mallard/Interior Alaska/9BM2750R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.999547,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM3016R0/2009',
#   'A/mallard/Interior Alaska/9BM3075R2/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.998437000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM3016R0/2009',
#   'A/mallard/Interior Alaska/9BM3355R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 4.0,
#    'weight': 7.999413,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM3016R0/2009',
#   'A/American green-winged teal/Interior Alaska/9BM3595R1/2009',
#   {'tr_age': 'DA',
#    'trtype': 'Inter-Species',
#    'time_delta': 6.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM3016R0/2009',
#   'A/mallard/Interior Alaska/9BM3379R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 5.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM3016R0/2009',
#   'A/mallard/Interior Alaska/9BM3357R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 4.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/10BM08134R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 7.9951050000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/10BM08134R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 7.9951050000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11317R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10287R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.998075,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM1957/2009',
#   'A/mallard/Interior Alaska/9BM2259/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 7.0,
#    'weight': 7.998984,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12311R0/2010',
#   'A/mallard/Interior Alaska/10BM12179R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.999547,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12311R0/2010',
#   'A/mallard/Interior Alaska/10BM12178R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.999547,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM2256/2009',
#   'A/mallard/Interior Alaska/9BM1974/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 5.0,
#    'weight': 7.999547,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM6095R0/2009',
#   'A/northern pintail/Interior Alaska/9BM6094R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM6095R0/2009',
#   'A/northern pintail/Interior Alaska/9BM7632R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 6.0,
#    'weight': 7.996047,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM6095R0/2009',
#   'A/mallard/Interior Alaska/9BM8829R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 9.0,
#    'weight': 7.9940760000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM6095R0/2009',
#   'A/American green-winged teal/Interior Alaska/9BM6258R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.996753,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM6095R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10813R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 15.0,
#    'weight': 7.9967320000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM10853R0/2010',
#   'A/mallard/Interior Alaska/10BM10876R0/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM10853R0/2010',
#   'A/mallard/Interior Alaska/10BM10859R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10B

#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM6290R0/2009',
#   'A/mallard/Interior Alaska/9BM11867R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 16.0,
#    'weight': 7.985789,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern pintail/Interior Alaska/9BM6290R0/2009',
#   'A/northern pintail/Interior Alaska/9BM8907R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 8.0,
#    'weight': 7.979068000000002,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM00849R2/2010',
#   'A/northern pintail/Interior Alaska/9BM10525R2/2009',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 280.0,
#    'weight': 7.997935999999997,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/mallard/Interior Alaska/9BM2259/2009',
#   'A/mallard/Interior Alaska/9BM2535R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.997216000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM11351R0/2009',
#   'A/American green-winged teal/Interior Alaska/9BM4407R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 22.0,
#    'weight': 7.9986039999999985,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern pintail/Interior Alaska/9BM7118R1/2009',
#   'A/northern pintail/Interior Alaska/9BM8553R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 4.0,
#    'weight': 7.996977,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM7118R1/2009',
#   'A/mallard/Interior Alaska/9BM10051R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 9.0,
#    'weight': 7.997242,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12534R0/2010',
#   'A/mallard/Interior Alaska/10BM07072R0/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Intra-Species',
#    'time_delta': 13.0,
#    'weight': 7.995495999999997,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12049R0/2010',
#   'A/mallard/Interior Alaska/10BM11414R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.998993,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12049R0/2010',
#   'A/mallard/Interior Alaska/10BM11420R0/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.998993,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM10166R0/2010',
#   'A/mallard/Interior Alaska/10BM09818R0/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.999414,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11358R1/2009',
#   'A/American green-winged teal/Interior Alaska/9BM4407R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 22.0,
#    'weight': 7.997737000000001,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/mallard/Interior Alaska/10BM05797R0/2010',
#   'A/mallard/Interior Alaska/10BM06828R0/2010',
#   {'tr_age': 'DF',
#    'trtype': 'Intra-Species',
#    'time_delta': 5.0,
#    'weight': 7.989933999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM05797R0/2010',
#   'A/mallard/Interior Alaska/10BM10000R0/2010',
#   {'tr_age': 'DF',
#    'trtype': 'Intra-Species',
#    'time_delta': 13.0,
#    'weight': 7.990054999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM05797R0/2010',
#   'A/northern pintail/Interior Alaska/10BM07597R0/2010',
#   {'tr_age': 'DF',
#    'trtype': 'Inter-Species',
#    'time_delta': 7.0,
#    'weight': 7.984493,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM05337R0/2010',
#   'A/mallard/Interior Alaska/10BM05249R0/2010',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.997160000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11325R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10525R2/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.999567999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11325R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10146R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 3.0,
#    'weight': 7.999567999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11325R0/2009',
#   'A/mallard/Interior Alaska/9BM8474R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 8.0,
#    'weight': 7.999567999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11917R0/2009',
#   'A/northern shoveler/Interior Alaska/9BM4787R0/2009',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 21.0,
#    'weight': 7.990690999999999,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10222R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10224R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10238R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10218R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.999547,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10210R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM11179R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.999115,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10236R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10244R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10234R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM8935R0/2009',
#   'A/northern pintail/Interior Alaska/9BM7799R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 3.0,
#    'weight': 7.996874000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM09164R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09101R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.999425,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM09164R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09102R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.999425,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM09164R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09104R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.999425,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/10BM05376R0/2010',
#   'A/northern shoveler/Interior Alaska/10BM05491R0/2010',
#   {'tr_age': 'DD',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.993067,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11231R0/2009',
#   'A/northern pintail/Interior Alaska/9BM12211R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 3.0,
#    'weight': 7.9985490000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11231R0/2009',
#   'A/northern pintail/Interior Alaska/9BM12210R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 3.0,
#    'weight': 7.9985490000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/10BM05165R0/2010',
#   'A/northern shoveler/Interior Alaska/10BM02593R0/2010',
#   {'tr_age': 'DA',
#    'trtype': 'Inter-Species',
#    'time_delta': 29.0,
#    'weight': 7.989718999999999,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern shoveler/Interior Alaska/10BM05408R0/2010',
#   'A/mallard/Interior Alaska/10BM05249R0/2010',
#   {'tr_age': 'DD',
#    'trtype': 'Inter-Species',
#    'time_delta': 2.0,
#    'weight': 7.996676,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/10BM05408R0/2010',
#   'A/ring-necked duck/Interior Alaska/10BM05617R0/2010',
#   {'tr_age': 'DA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.995486,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/10BM05408R0/2010',
#   'A/American green-winged teal/Interior Alaska/10BM05165R0/2010',
#   {'tr_age': 'DD',
#    'trtype': 'Inter-Species',
#    'time_delta': 3.0,
#    'weight': 7.995918,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/10BM05408R0/2010',
#   'A/mallard/Interior Alaska/10BM05247R0/2010',
#   {'tr_age': 'DD',
#    'trtype': 'Inter-Species',
#    'time_delta': 2.0,
#    'weight': 7.996488999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/10BM05408R0/2010',
#   'A/northern pintail/Interior Alaska/10BM07040R0/2010',
#   {'tr_age': 'DF',
#    'trtype': 'Inter-Species',
#    'time_delta': 7.0,
#    'weight': 7.990434,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM11583R0/2009',
#   'A/northern pintail/Interior Alaska/9BM11358R1/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM11420R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 8.0,
#    'weight': 7.996035000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM11420R0/2010',
#   'A/mallard/Interior Alaska/10BM11415R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.9985399999999975,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM11420R0/2010',
#   'A/mallard/Interior Alaska/10BM11418R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.999136,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM11420R0/2010',
#   'A/mallard/Interior Alaska/10BM11419R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.998683,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM11420R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 8.0,
#    'weight': 7.996035000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM11420R0/2010',
#   'A/mallard/Interior Alaska/10BM11414R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM07993R0/2010',
#   'A/mallard/Interior Alaska/10BM04626R0/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 16.0,
#    'weight': 7.991765999999997,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern pintail/Interior Alaska/9BM9975R0/2009',
#   'A/mallard/Interior Alaska/9BM8471R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 5.0,
#    'weight': 7.9342510000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM11989R0/2010',
#   'A/northern pintail/Interior Alaska/10BM11694R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.995481000000002,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM11989R0/2010',
#   'A/northern pintail/Interior Alaska/9BM8907R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 367.0,
#    'weight': 7.971804,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/mallard/Interior Alaska/10BM11416R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 8.0,
#    'weight': 7.995331,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM12180R0/2009',
#   'A/mallard/Interior Alaska/9BM11965R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 7.998683,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM12180R0/2009',
#   'A/northern pintail/Interior Alaska/9BM8907R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 9.0,
#    'weight': 7.975417999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM12180R0/2009',
#   'A/northern pintail/Interior Alaska/9BM12176R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM12552R0/2010',
#   'A/American green-winged teal/Interior Alaska/10BM08422R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 10.0,
#    'weight': 7.991981,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM06872R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 4.0,
#    'weight': 7.9937960000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM06872R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 4.0,
#    'weight': 7.9937960000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12363R0/2010',
#   'A/mallard/Interior Alaska/10BM12352R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.999351,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12363R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 10.0,
#    'weight': 7.9975429999999985,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12363R0/2010',
#   'A/mallard/Interior Alaska/10BM12350R0/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM12363R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 10.0,
#    'weight': 7.9975429999999985,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/10BM05649R0/2010',
#   'A/mallard/Interior Alaska/10BM05900R0/2010',
#   {'tr_age': 'DA',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 7.999134,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/10BM05649R0/2010',
#   'A/ring-necked duck/Interior Alaska/10BM05792R0/2010',
#   {'tr_age': 'DA',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM07971R0/2010',
#   'A/mallard/Interior Alaska/10BM02530R0/2010',
#   {'tr_age': 'AA',
#    'trtype': 'Intra-Species',
#    'time_delta': 42.0,
#    'weight': 7.990558,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/mallard/Interior Alaska/10BM10176R0/2010',
#   'A/mallard/Interior Alaska/10BM10173R0/2010',
#   {'tr_age': 'AA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.9991020000000015,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM10176R0/2010',
#   'A/northern pintail/Interior Alaska/10BM04704R0/2010',
#   {'tr_age': 'AA',
#    'trtype': 'Inter-Species',
#    'time_delta': 21.0,
#    'weight': 7.999567,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern pintail/Interior Alaska/9BM10146R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10525R2/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10146R0/2009',
#   'A/northern pintail/Interior Alaska/10BM00849R2/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Intra-Species',
#    'time_delta': 281.0,
#    'weight': 7.997935999999997,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/northern pintail/Interior Alaska/9BM10146R0/2009',
#   'A/mallard/Interior Alaska/9BM8474R0/2009',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 5.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10790R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 16.0,
#    'weight': 7.995471999999999,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM10859R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 16.0,
#    'weight': 7.9966279999999985,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08400R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 10.0,
#    'weight': 7.9972460000000005,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10853R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 16.0,
#    'weight': 7.9966279999999985,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM10811R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 16.0,
#    'weight': 7.9969160000000015,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM09818R0/2010',
#   {'tr_age': 'AA',
#    'trtype': 'Intra-Species',
#    'time_delta': 13.0,
#    'weight': 7.997846000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09481R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 12.0,
#    'weight': 7.997961,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09348R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 12.0,
#    'weight': 7.996382,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM11208R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 17.0,
#    'weight': 7.9970300000000005,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM07072R0/2010',
#   {'tr_age': 'AA',
#    'trtype': 'Intra-Species',
#    'time_delta': 7.0,
#    'weight': 7.9975270000000025,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM05860R0/2010',
#   {'tr_age': 'AA',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09347R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 12.0,
#    'weight': 7.996382,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM10876R0/2010',
#   {'tr_age': 'AA',
#    'trtype': 'Intra-Species',
#    'time_delta': 16.0,
#    'weight': 7.9966279999999985,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10801R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 16.0,
#    'weight': 7.9964830000000005,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/American green-winged teal/Interior Alaska/9BM4407R0/2009',
#   'A/mallard/Interior Alaska/9BM3205R0/2009',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta':

#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM08920R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09102R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.992619,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM08920R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09104R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.992619,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM08899R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08903R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM08899R0/2010',
#   'A/northern shoveler/Interior Alaska/10BM02593R0/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 43.0,
#    'weight': 7.976656,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/mallard/Interior Alaska/10BM07085R0/2010',
#   'A/northern pintail/Interior Alaska/10BM07114R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 7.999414,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM07085R0/2010',
#   'A/mallard/Interior Alaska/10BM06911R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.999414,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM07085R0/2010',
#   'A/mallard/Interior Alaska/10BM07501R0/2010',
#   {'tr_age': 'AA',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.999414,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM07085R0/2010',
#   'A/mallard/Interior Alaska/10BM06905R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.999414,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM07085R0/2010',
#   'A/northern pintail/Interior Alaska/10BM06524R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 2.0,
#    'weight': 7.999414,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM07085R0/2010',
#   'A/northern pintail/Interior Alaska/10BM06899R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.999414,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM07085R0/2010',
#   'A/mallard/Interior Alaska/10BM07092R0/2010',
#   {'tr_age': 'AA',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.999414,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM3355R0/2009',
#   'A/American green-winged teal/Interior Alaska/9BM3595R1/2009',
#   {'tr_age': 'DA',
#    'trtype': 'Inter-Species',
#    'time_delta': 2.0,
#    'weight': 7.999413,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM3355R0/2009',
#   'A/mallard/Interior Alaska/9BM3379R0/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.999413,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10236R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10218R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.999547,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10236R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10210R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM12390R0/2009',
#   'A/northern shoveler/Interior Alaska/9BM12332R0/2009',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 7.99403,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM7836R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10819R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 9.0,
#    'weight': 7.988417,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10210R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10218R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.999547,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM07072R0/2010',
#   'A/mallard/Interior Alaska/10BM08120R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Intra-Species',
#    'time_delta': 3.0,
#    'weight': 7.998394999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM07072R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09181R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 5.0,
#    'weight': 7.998013,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM10877R0/2009',
#   'A/northern pintail/Interior Alaska/9BM6039R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 15.0,
#    'weight': 7.995867999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM8657R1/2009',
#   'A/northern pintail/Interior Alaska/9BM6290R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 7.0,
#    'weight': 7.989717999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/9BM12210R0/2009',
#   'A/northern pintail/Interior Alaska/9BM12211R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/10BM05382R0/2010',
#   'A/northern shoveler/Interior Alaska/10BM05491R0/2010',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 7.996964,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM07114R0/2010',
#   'A/northern pintail/Interior Alaska/10BM07106R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 7.998714,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM07114R0/2010',
#   'A/mallard/Interior Alaska/10BM06905R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM07114R0/2010',
#   'A/mallard/Interior Alaska/10BM08100R0/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 3.0,
#    'weight': 7.9977839999999984,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM07114R0/2010',
#   'A/mallard/Interior Alaska/10BM07092R0/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM07114R0/2010',
#   'A/northern pintail/Interior Alaska/10BM06899R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 1.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM07114R0/2010',
#   'A/mallard/Interior Alaska/10BM06909R0/2010',
#   {'tr_age': 'NA',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.998234999999997,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/10BM07000R0/2010',
#   'A/American green-winged teal/Interior Alaska/10BM07863R0/2010',
#   {'tr_age': 'FA',
#    'trtype': 'Inter-Species',
#    'time_delta': 3.0,
#    'weight': 7.999414999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern shoveler/Interior Alaska/9BM12298R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10819R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 15.0,
#    'weight': 7.993942,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/10BM11414R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 8.0,
#    'weight': 7.996035000000001,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/northern pintail/Interior Alaska/10BM11694R0/2010',
#   'A/northern pintail/Interior Alaska/9BM8907R0/2009',
#   {'tr_age': 'FF',
#    'trtype': 'Intra-Species',
#    'time_delta': 367.0,
#    'weight': 7.973725,
#    'tr_timeclass': 'Environmental Persistence'}),
#  ('A/mallard/Interior Alaska/9BM6886R0/2009',
#   'A/northern pintail/Interior Alaska/9BM7620R0/2009',
#   {'tr_age': 'DF',
#    'trtype': 'Inter-Species',
#    'time_delta': 2.0,
#    'weight': 7.994963,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/American green-winged teal/Interior Alaska/10BM08228R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09101R0/2010',
#   {'tr_age': 'FF',
#    'trtype': 'Inter-Species',
#    'time_delta': 1.0,
#    'weight': 7.994491999999997,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM1947/2009',
#   'A/mallard/Interior Alaska/9BM2168/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 6.0,
#    'weight': 7.998919,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM1947/2009',
#   'A/mallard/Interior Alaska/9BM1809/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.997959,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM1947/2009',
#   'A/mallard/Interior Alaska/9BM2254/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 7.0,
#    'weight': 7.998417999999999,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM1947/2009',
#   'A/mallard/Interior Alaska/9BM1962/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM1947/2009',
#   'A/mallard/Interior Alaska/9BM1864/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 3.0,
#    'weight': 7.999416,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM1947/2009',
#   'A/mallard/Interior Alaska/9BM1807/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.999416,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM1947/2009',
#   'A/mallard/Interior Alaska/9BM1958/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM1958/2009',
#   'A/mallard/Interior Alaska/9BM1809/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 2.0,
#    'weight': 7.997959,
#    'tr_timeclass': 'Direct Transmission'}),
#  ('A/mallard/Interior Alaska/9BM1958/2009',
#   'A/mallard/Interior Alaska/9BM1962/2009',
#   {'tr_age': 'DD',
#    'trtype': 'Intra-Species',
#    'time_delta': 0.0,
#    'weight': 8.0,
#    'tr_timeclass': 'Direct Transmission'})]

# %%
tr_ages = [edge[2]['tr_age'] for edge in G_serialized.edges(data=True)]
# tr_ages = [item['tr_age'] for item in tr_ages]
tr_ages
# Out:
# ['DD',
#  'DD',
#  'FF',
#  'FF',
#  'AA',
#  'AA',
#  'NA',
#  'NA',
#  'NA',
#  'FA',
#  'FA',
#  'FA',
#  'FA',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DA',
#  'DD',
#  'DD',
#  'FF',
#  'FF',
#  'FF',
#  'DD',
#  'NA',
#  'NA',
#  'DD',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FF',
#  'FA',
#  'FF',
#  'FF',
#  'NA',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'NA',
#  'NA',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'NA',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'FF',
#  'DD',
#  'DD',
#  'AA',
#  'FF',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FA',
#  'DD',
#  'DD',
#  'NA',
#  'NA',
#  'NA',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'DD',
#  'DD',
#  'FF',
#  'FF',
#  'NA',
#  'DD',
#  'FA',
#  'FF',
#  'FF',
#  'FA',
#  'FF',
#  'FA',
#  'FA',
#  'FA',
#  'DF',
#  'DF',
#  'DF',
#  'DD',
#  'FF',
#  'FF',
#  'FA',
#  'NA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'NA',
#  'NA',
#  'NA',
#  'DD',
#  'FF',
#  'FF',
#  'DA',
#  'DD',
#  'DA',
#  'DD',
#  'DD',
#  'DF',
#  'FF',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FF',
#  'DA',
#  'DA',
#  'AA',
#  'AA',
#  'AA',
#  'FF',
#  'FA',
#  'FA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'AA',
#  'NA',
#  'NA',
#  'NA',
#  'AA',
#  'AA',
#  'NA',
#  'AA',
#  'NA',
#  'NA',
#  'FA',
#  'NA',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'FF',
#  'FF',
#  'NA',
#  'NA',
#  'NA',
#  'FF',
#  'NA',
#  'AA',
#  'NA',
#  'FF',
#  'FF',
#  'FA',
#  'DD',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'AA',
#  'AA',
#  'NA',
#  'NA',
#  'NA',
#  'AA',
#  'NA',
#  'DD',
#  'DD',
#  'AA',
#  'AA',
#  'AA',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'NA',
#  'FF',
#  'NA',
#  'NA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FF',
#  'FF',
#  'FA',
#  'FF',
#  'DD',
#  'AA',
#  'AA',
#  'AA',
#  'DD',
#  'DA',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'NA',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FA',
#  'FF',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'FF',
#  'FA',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FA',
#  'FF',
#  'NA',
#  'NA',
#  'DF',
#  'DF',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DF',
#  'DA',
#  'DF',
#  'NA',
#  'AA',
#  'NA',
#  'AA',
#  'NA',
#  'FF',
#  'FF',
#  'FA',
#  'FF',
#  'FA',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DA',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DA',
#  'FF',
#  'FF',
#  'FF',
#  'AA',
#  'NA',
#  'NA',
#  'AA',
#  'NA',
#  'AA',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'NA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'DD',
#  'DD',
#  'FF',
#  'FF',
#  'AA',
#  'NA',
#  'NA',
#  'NA',
#  'AA',
#  'NA',
#  'NA',
#  'AA',
#  'NA',
#  'FF',
#  'NA',
#  'FF',
#  'FF',
#  'FA',
#  'NA',
#  'DD',
#  'FF',
#  'AA',
#  'AA',
#  'NA',
#  'AA',
#  'FF',
#  'FA',
#  'DA',
#  'FA',
#  'FF',
#  'FF',
#  'NA',
#  'DD',
#  'DD',
#  'FA',
#  'FF',
#  'NA',
#  'FF',
#  'DF',
#  'FF',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'DD',
#  'FF',
#  'FF',
#  'NA',
#  'AA',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DA',
#  'DD',
#  'AA',
#  'AA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'NA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'DD',
#  'DA',
#  'AA',
#  'NA',
#  'FF',
#  'DD',
#  'FF',
#  'DD',
#  'DD',
#  'DD',
#  'AA',
#  'FF',
#  'FF',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DA',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'FA',
#  'FF',
#  'FF',
#  'NA',
#  'DD',
#  'DD',
#  'NA',
#  'NA',
#  'NA',
#  'FF',
#  'FA',
#  'FF',
#  'FF',
#  'FA',
#  'FF',
#  'FA',
#  'FF',
#  'FA',
#  'FF',
#  'FF',
#  'DA',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'NA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FA',
#  'FA',
#  'FF',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FA',
#  'FA',
#  'FF',
#  'NA',
#  'AA',
#  'AA',
#  'FA',
#  'FF',
#  'NA',
#  'AA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'NA',
#  'AA',
#  'NA',
#  'FA',
#  'FF',
#  'FF',
#  'FA',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'NA',
#  'AA',
#  'FF',
#  'FF',
#  'FF',
#  'NA',
#  'FF',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DA',
#  'DD',
#  'FF',
#  'DD',
#  'NA',
#  'NA',
#  'NA',
#  'DD',
#  'FF',
#  'NA',
#  'NA',
#  'NA',
#  'AA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'AA',
#  'NA',
#  'NA',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'NA',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FA',
#  'FF',
#  'FF',
#  'DD',
#  'DD',
#  'DD',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'DD',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'FF',
#  'FF',
#  'FF',
#  'DA',
#  'FF',
#  'FA',
#  'NA',
#  'NA',
#  'AA',
#  'NA',
#  'AA',
#  'NA',
#  'NA',
#  'AA',
#  'NA',
#  'NA',
#  'NA',
#  'AA',
#  'NA',
#  'AA',
#  'NA',
#  'FA',
#  'FA',
#  'FF',
#  'FA',
#  'AA',
#  'NA',
#  'NA',
#  'NA',
#  'DA',
#  'DD',
#  'FF',
#  'FF',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'NA',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FA',
#  'FF',
#  'FA',
#  'FF',
#  'NA',
#  'FF',
#  'FF',
#  'FA',
#  'FA',
#  'FA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'AA',
#  'AA',
#  'AA',
#  'NA',
#  'NA',
#  'FA',
#  'FF',
#  'NA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'NA',
#  'DD',
#  'FF',
#  'FA',
#  'FF',
#  'FA',
#  'FF',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DA',
#  'FF',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'FF',
#  'FF',
#  'NA',
#  'FF',
#  'DD',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'NA',
#  'NA',
#  'AA',
#  'NA',
#  'NA',
#  'NA',
#  'AA',
#  'NA',
#  'FF',
#  'FF',
#  'NA',
#  'FF',
#  'NA',
#  'NA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'NA',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FF',
#  'FA',
#  'NA',
#  'NA',
#  'AA',
#  'NA',
#  'NA',
#  'NA',
#  'AA',
#  'DA',
#  'DD',
#  'FF',
#  'FF',
#  'NA',
#  'FF',
#  'FF',
#  'NA',
#  'NA',
#  'FF',
#  'FF',
#  'FF',
#  'DD',
#  'FF',
#  'FF',
#  'FA',
#  'FA',
#  'FF',
#  'NA',
#  'FA',
#  'FF',
#  'FF',
#  'FF',
#  'DF',
#  'FF',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD',
#  'DD']
