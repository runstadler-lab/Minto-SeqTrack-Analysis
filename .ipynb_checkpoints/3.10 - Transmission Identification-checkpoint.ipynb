# %%
import networkx as nx
import numpy as np
import pandas as pd
from networkx.readwrite import json_graph
import json
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import math

from time import time
from datetime import timedelta, datetime
from copy import deepcopy, copy
from __future__ import division
from custom_funcs import *

# %%
# Load the data
starttime = time()
data = pd.read_csv('3.0 - Transmissions/Minto Plus North America All Transmissions.csv', index_col=0, parse_dates=['Collection Date', 'Collection Date2'])
data['Time Delta'] = data['Collection Date2'] - data['Collection Date']
data['Time Delta'] = data['Time Delta'].astype('timedelta64[D]')
endtime = time()
print('%s seconds' % (endtime - starttime))
# Longest recorded time: 18 seconds.
len(data)
# Out:
# 18.6316039562 seconds
# 3191582

# %%
# There should be 1186 isolates.
# 22 September 2014: After filtering out isolates from 2011, there are only 1169 isolates, consistent with what I had
# counted when doing data removal earlier on.
# 23 September 2014: After chat with Nichola, we are including everything from 2008 to 2011. There should be 1756 isolates.
# 25 September 2014: Update - after figuring out how many isolates were dropped incorrectly, there should be 1787 isoaltes
len(data.groupby('Isolate1'))
# Out:
# 1787

# %%
# Initialize the graph that will be used to store the transmission network
G = nx.DiGraph()

# Initialize a graph that will hold all of the discarded edges from G. This is used to
# add back edges that are sources for isolates that may have been implicated in bi-directional
# reconstructions as a result of the "-6 to +15" rule.
G_discarded = nx.DiGraph()

# %%
starttime = time()

# Add nodes into the graph, along with metadata.
for group in data.groupby(['Isolate1', 'Collection Date', 'Subtype', 'Host Species','State/Province']):
    G.add_node(group[0][0],
               isolation_date=group[0][1],
               subtype=group[0][2],
               host=group[0][3],
               state=group[0][4])
    
for group in data.groupby(['Isolate2', 'Collection Date2', 'Subtype2', 'Host Species2','State/Province2']):
    G.add_node(group[0][0],
               isolation_date=group[0][1],
               subtype=group[0][2],
               host=group[0][3],
               state=group[0][4])

endtime = time()
print('%s seconds' % (endtime - starttime))

# Longest recorded time: 6 seconds.
# Out:
# 7.78239393234 seconds

# %%
# Inspect the first node to make sure the data were entered correctly.
G.nodes(data=True)[1]
# Out:
# ('A/mallard/California/2542V/2011',
#  {'host': 'IRD:Mallard/Avian',
#   'isolation_date': Timestamp('2011-08-12 00:00:00'),
#   'state': 'California',
#   'subtype': 'H5N1'})

# %%
# There should be the same number of nodes as in the cell with len(data.groupby("Isolate1")).
len(G.nodes())
# Out:
# 1787

# %%
# There should be no edges right now.
G.edges(data=True)
# Out:
# []

# %%
data[(data['PWI'] > 7) & \
     ((data['Isolate2'] == 'A/mallard/Interior Alaska/10BM05860R0/2010') |\
      (data['Isolate1'] == 'A/mallard/Interior Alaska/10BM05860R0/2010')) &\
     (data['Time Delta'] >= -6)]
# Out:
#                                                   Isolate2  \
# 1152616         A/mallard/Interior Alaska/10BM05347R0/2010
# 1156187         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156204         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156205         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156206         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156207         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156208         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156209         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156210         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156211         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156738         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156739         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156740         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156742         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156744         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156745         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156746         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156748         A/mallard/Interior Alaska/10BM05860R0/2010
# 1156749         A/mallard/Interior Alaska/10BM05860R0/2010
# 1
# 2159921      2010-07-26                   IRD:Avian    H7N3     USA
# 2161707      2010-07-26                   IRD:Avian    H7N3     USA
# 2165279      2010-07-26                   IRD:Avian    H7N3     USA
# 2167065      2010-07-26                   IRD:Avian    H7N3     USA
# 2168851      2010-07-26                   IRD:Avian    H7N3     USA
# 2174209      2010-07-26                   IRD:Avian    H7N3     USA
# 2177781      2010-07-26                   IRD:Avian    H7N3     USA
# 2190283      2010-07-26                   IRD:Avian    H7N3     USA
# 2195641      2010-07-26                   IRD:Avian    H7N3     USA
# 2209929      2010-07-26                   IRD:Avian    H7N3     USA
# 2211715      2010-07-26                   IRD:Avian    H7N3     USA
# 2213501      2010-07-26                   IRD:Avian    H7N3     USA
# 2215287      2010-07-26                   IRD:Avian    H7N3     USA
# 2217073      2010-07-26                   IRD:Avian    H7N3     USA
# 2218859      2010-07-26                   IRD:Avian    H7N3     USA
# 2222431      2010-07-26                   IRD:Avian    H7N3     USA
# 2226003      2010-07-26                   IRD:Avian    H7N3     USA
# 2227789      2010-07-26                   IRD:Avian    H7N3     USA
# 2229575      2010-07-26                   IRD:Avian    H7N3     USA
# 2231361      2010-07-26                   IRD:Avian    H7N3     USA
# 2233147      2010-07-26                   IRD:Avian    H7N3     USA
# 2234933      2010-07-26                   IRD:Avian    H7N3     USA
# 2236719      2010-07-26                   IRD:Avian    H7N3     USA
# 2242077      2010-07-26                   IRD:Avian    H7N3     USA
# 2251007      2010-07-26                   IRD:Avian    H7N3     USA
#
#         State/Province Collection Date2               Host Species2 Subtype2  \
# 1152616         Alaska       2010-07-25           IRD:Mallard/Avian     H7N3
# 1156187         Alaska       2010-07-26                   IRD:Avian     H7N3
# 1156204         Alaska       2010-07-26                   IRD:Avian     H7N3
# 1156205         Alaska       2010-07-26                   IRD:Avian     H7N3
# 1156206         Alaska       2010-07-26                   IRD:Avian     H7N3
# 1156207         Alaska       2010-07-26                   IRD:Avian     H7N3
# 1156208            NaN       2010-07-26                   IRD:Avian     H7N3
# 1156209            NaN       2010-07-26                   IRD:Avian     H7N3
# 1156210            NaN       2010-07-26                   IRD:Avian     H7N3
# 1156211            NaN       2010-07-26                   IRD:Avian     H7N3
# 1156738         Alaska       2010-07-26                   IRD:Avian     H7N3
# 1156739         Alaska       2010-07-26                   IRD:Avian     H7N3
# 1156740         Alaska       2010-07-26                   IRD:Avian     H7N3
# 1156742         Alaska       2010-07-26                   IRD:Avian     H7N3
# 1156744         Alaska       2010-07-26                   IRD:Avian     H7N3
# 1156745         Alaska       2010-07-26                   IRD:Avian     H7N3
# 1156746            NaN       2010-07-26                   IRD:Avian     H7N3
# 1156748            NaN       2010-07-26                   IRD:Avian     H7N3
# 1156749            NaN       2010-07-26                   IRD:Avian     H7N3
# 1156750            NaN       2010-07-26                   IRD:Avian     H7N3
# 1156751            NaN       2010-07-26                   IRD:Avian     H7N3
# 1184765         Alaska       2010-07-31                   IRD:Avian     H7N3
# 1186551         Alaska       2010-07-31                   IRD:Avian     H7N3
# 1188337         Alaska       2010-07-31                   IRD:Avian     H7N3
# 1190123         Alaska       2010-07-31                   IRD:Avian     H7N3
# 1191909         Alaska       2010-08-01           IRD:Mallard/Avian     H7N3
# 1193695         Alaska       2010-08-01           IRD:Mallard/Avian     H7N3
# 1195481         Alaska       2010-08-01           IRD:Mallard/Avian     H7N3
# 1197267         Alaska       2010-08-01           IRD:Mallard/Avian     H7N3
# 1199053         Alaska       2010-08-02           IRD:Mallard/Avian     H7N3
# ...                ...              ...                         ...      ...
# 2149205         Alaska       2010-07-31                   IRD:Avian     H7N3
# 2150991         Alaska       2010-07-31                   IRD:Avian     H7N3
# 2152777         Alaska       2010-08-01  IRD:Northern Pintail/Avian     H7N3
# 2156349         Alaska       2010-08-01  IRD:Northern Pintail/Avian     H7N3
# 2158135         Alaska       2010-08-01  IRD:Northern Pintail/Avian     H7N3
# 2159921         Alaska       2010-08-01  IRD:Northern Pintail/Avian     H7N3
# 1156750      USA  Interior Alaska          -6  Interior Alaska
# 1156751      USA  Interior Alaska          -6  Interior Alaska
# 1184765      USA  Interior Alaska           5  Interior Alaska
# 1186551      USA  Interior Alaska           5  Interior Alaska
# 1188337      USA  Interior Alaska           5  Interior Alaska
# 1190123      USA  Interior Alaska           5  Interior Alaska
# 1191909      NaN  Interior Alaska           6  Interior Alaska
# 1193695      NaN  Interior Alaska           6  Interior Alaska
# 1195481      NaN  Interior Alaska           6  Interior Alaska
# 1197267      NaN  Interior Alaska           6  Interior Alaska
# 1199053      NaN  Interior Alaska           7  Interior Alaska
# ...          ...              ...         ...              ...
# 2149205      USA  Interior Alaska           5  Interior Alaska
# 2150991      USA  Interior Alaska           5  Interior Alaska
# 2152777      NaN  Interior Alaska           6  Interior Alaska
# 2156349      NaN  Interior Alaska           6  Interior Alaska
# 2158135      NaN  Interior Alaska           6  Interior Alaska
# 2159921      NaN  Interior Alaska           6  Interior Alaska
# 2161707      NaN  Interior Alaska           6  Interior Alaska
# 2165279      NaN  Interior Alaska           7  Interior Alaska
# 2167065      NaN  Interior Alaska           7  Interior Alaska
# 2168851      NaN  Interior Alaska           7  Interior Alaska
# 2174209      NaN  Interior Alaska           8  Interior Alaska
# 2177781      NaN  Interior Alaska           9  Interior Alaska
# 2190283      NaN  Interior Alaska           9  Interior Alaska
# 2195641      NaN  Interior Alaska          10  Interior Alaska
# 2209929      NaN  Interior Alaska          11  Interior Alaska
# 2211715      NaN  Interior Alaska          11  Interior Alaska
# 2213501      NaN  Interior Alaska          11  Interior Alaska
# 2215287      NaN  Interior Alaska          11  Interior Alaska
# 2217073      NaN  Interior Alaska          12  Interior Alaska
# 2218859      NaN  Interior Alaska          13  Interior Alaska
# 2222431      NaN  Interior Alaska          14  Interior Alaska
# 2226003      NaN  Interior Alaska          15  Interior Alaska
# 2227789      NaN  Interior Alaska          15  Interior Alaska
# 2229575      NaN  Interior Alaska          15  Interior Alaska
# 2231361      NaN  Interior Alaska          15  Interior Alaska
# 2233147      NaN  Interior Alaska          15  Interior Alaska
# 2234933      NaN  Interior Alaska          15  Interior Alaska
# 2236719      NaN  Interior Alaska          15  Interior Alaska
# 2242077      NaN  Interior Alaska          16  Interior Alaska
# 2251007      NaN  Interior Alaska          18  Interior Alaska
#
# [83 rows x 15 columns]

# %%
# Add in edges to the graph, and classify them as intra-species or inter-species.
for row in data[data['PWI'] > 7.0].iterrows():
    # 12 September 2014: I just noticed here that 
    #     if Time Delta >= -7 
    # should have been:
    #     if Time Delta >= -6.
    # Made the change here.
    if row[1]['Time Delta'] >= -6:
        if row[1]['Host Species'] == row[1]['Host Species2']:
            G.add_edge(row[1]['Isolate1'], 
                       row[1]['Isolate2'], 
                       time_delta=timedelta(row[1]['Time Delta']), 
                       weight=row[1]['PWI'], 
                       trtype='Intra-Species')
        if row[1]['Host Species'] != row[1]['Host Species2']:
            G.add_edge(row[1]['Isolate1'], 
                       row[1]['Isolate2'], 
                       time_delta=timedelta(row[1]['Time Delta']), 
                       weight=row[1]['PWI'], 
                       trtype='Inter-Species')

# %%
# Inspect the first edge in the graph, to make sure the data are added in correctly.
G.edges(data=True)[2]
# Out:
# ('A/mallard/California/2542V/2011',
#  'A/mallard/California/2531P/2011',
#  {'time_delta': datetime.timedelta(0),
#   'trtype': 'Intra-Species',
#   'weight': 7.995221000000001})

# %%
len([edge for edge in G.edges() if 'A/mallard/Interior Alaska/10BM05860R0/2010' in edge])
# Out:
# 83

# %%
# With Time Delta >= -7, there should be 13414 edges.
# With Time Delta >= -6, there should be 13092 edges. 
# 12 September 2014: The latter should be correct.
# 22 September 2014: With 2011 isolates filtered out, now there are only 13083 edges.
# 23 September 2014: With expanded dataset including 2008 to 2011, there are 17379 edges that involve all 8 segments and
# fulfill the time requirement
print(len(G.edges()))
# Out:
# 18701

# %%
# Prune away any edges not equal to max_weight.
# Add those discarded edges to a separate graph that has 

for node in G.nodes(data=True):
    G_discarded.add_node(node[0], attr_dict=node[1])
    edges = G.in_edges(node[0], data=True)
    if len(edges) > 0:
        max_weight = max([edge[2]['weight'] for edge in edges])
        for edge in edges:
            if edge[2]['weight'] < max_weight:
                G.remove_edge(edge[0], edge[1])
                G_discarded.add_edge(edge[0], edge[1], attr_dict=edge[2])

# %%
[edge for edge in G.edges() if 'A/mallard/Interior Alaska/10BM05860R0/2010' in edge]
# Out:
# [('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM05860R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08400R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM05347R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08586R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM11208R0/2010')]

# %%
# Inspect one of the discarded edges
G_discarded.edges(data=True)[0]
# Out:
# ('A/mallard/California/2542V/2011',
#  'A/mallard/California/2527V/2011',
#  {'time_delta': datetime.timedelta(0),
#   'trtype': 'Intra-Species',
#   'weight': 7.996829999999999})

# %%
# Check to see how many discarded edges are present
len(G_discarded.edges())
# Out:
# 16779

# %%
# Check to see that the number of discarded edges and the number of retained edges = original # of edges (i.e. 13083)
# 23 September 2014: Update - should be 17379
len(G_discarded.edges()) + len(G.edges())
# Out:
# 18701

# %%
# This cell is used for querying the data, to make sure that the edges are correct.
G.in_edges('A/ruddy turnstone/New Jersey/AI09-775/2009', data=True)
# G.edges(['A/American green-winged teal/Interior Alaska/10BM04207R0/2010'], data=True)
# Out:
# [('A/ruddy turnstone/New Jersey/AI09-841/2009',
#   'A/ruddy turnstone/New Jersey/AI09-775/2009',
#   {'time_delta': datetime.timedelta(7),
#    'trtype': 'Intra-Species',
#    'weight': 7.995798})]

# %%
# Identify the potential reassortants in the graph. 
# These guys are the ones without any in_edges going into them.
reassortants = []
for node in G.nodes():
    if len(G.in_edges(node)) == 0:
        reassortants.append(node)
pd.Series(reassortants).to_csv('Reassortants by Network Analysis.csv')

# %%
# There should be 1377 edges.
# 23 September 2014: There should be 1922 full transmission edges when 2008-2011 is considered.
print(len(G.edges()))
# Out:
# 1922

# %%
[edge for edge in G.edges() if 'A/mallard/Interior Alaska/10BM05860R0/2010' in edge]
# Out:
# [('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM05860R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08400R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM05347R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08586R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM11208R0/2010')]

# %%
len([edge for edge in G_discarded.edges() if 'A/mallard/Interior Alaska/10BM05860R0/2010' in edge])
# Out:
# 78

# %%
# Check to ensure that the metadata for each node are added in correctly.
G.nodes(data=True)[15]
# Out:
# ('A/blue-winged teal/North Dakota/Sg-00740/2008',
#  {'host': 'IRD:Avian',
#   'isolation_date': Timestamp('2008-09-07 00:00:00'),
#   'state': 'North Dakota',
#   'subtype': 'H3N8'})

# %%
# Sandbox cell: Check to see if we can do a "min" operation on date objects.

from datetime import date

datelist = [date(2010, 8, 12), 
            date(2010, 8, 7),
            date(2010, 7, 3)]

min(datelist)
# Out:
# datetime.date(2010, 7, 3)

# %%
# Find all subgraphs of G, and then add in edges that explain the earliest isolate of each subgraph.
# Prior to adding them back in, there should be 539 subgraphs.
# 22 September 2014: Update - after removal of 2011 isolates, there should only be 525.
starttime = time()
subgraphs = list(nx.connected_component_subgraphs(G.to_undirected()))
print("Initially, we had %s subgraphs." % len(subgraphs))

# for subgraph in subgraphs:
#     if len(subgraph.nodes()) == 1:
#         print(subgraph.nodes())

edges_to_add = []

for i in range(len(subgraphs)):
    earliest_nodes_in_subgraph = find_earliest_nodes(subgraphs[i])
    
    for node in earliest_nodes_in_subgraph:
    
        new_edges = find_source_node(node, G_discarded)
        if node[0] == 'A/mallard/Interior Alaska/10BM08884R0/2010':
            print(node)
            print(new_edges)
            
        if len(new_edges) > 0:
            edges_to_add.extend(new_edges)
G.add_edges_from(edges_to_add)


print("An additional %s edges were added back." % len(edges_to_add))
print("We now have %s edges." % len(G.edges()))
endtime = time()
print("%s seconds" % (endtime - starttime))
# Out:
# Initially, we had 765 subgraphs.
# ('A/mallard/Interior Alaska/10BM08884R0/2010', {'subtype': 'H7N3', 'host': 'IRD:Mallard/Avian', 'isolation_date': Timestamp('2010-08-05 00:00:00'), 'state': 'Interior Alaska'})
# [('A/mallard/Interior Alaska/10BM05347R0/2010', 'A/mallard/Interior Alaska/10BM08884R0/2010', {'trtype': 'Intra-Species', 'weight': 7.995813, 'time_delta': datetime.timedelta(11)}), ('A/mallard/Interior Alaska/10BM05860R0/2010', 'A/mallard/Interior Alaska/10BM08884R0/2010', {'trtype': 'Inter-Species', 'weight': 7.995813, 'time_delta': datetime.timedelta(10)})]
# An additional 292 edges were added back.
# We now have 2214 edges.
# 0.6430580616 seconds

# %%
[edge for edge in G.edges() if 'A/mallard/Interior Alaska/10BM05860R0/2010' in edge]
# Out:
# [('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM05860R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09348R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09481R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM10829R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM08884R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10801R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM10811R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09832R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10805R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10790R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM10861R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM08883R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10807R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM10876R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08400R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM08874R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10853R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09347R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10809R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM09818R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM05347R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08586R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM10859R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM09563R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM11208R0/2010'),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM07458R0/2010')]

# %%
print(len(edges_to_add))
edges_to_add
# Out:
# 292
# [('A/American black duck/Prince Edward Island/00788/2010',
#   'A/blue-winged teal/Nova Scotia/00077/2010',
#   {'time_delta': datetime.timedelta(13),
#    'trtype': 'Intra-Species',
#    'weight': 7.999347}),
#  ('A/American black duck/Prince Edward Island/00788/2010',
#   'A/mallard/Nova Scotia/00778/2010',
#   {'time_delta': datetime.timedelta(13),
#    'trtype': 'Intra-Species',
#    'weight': 7.998914999999998}),
#  ('A/American black duck/Prince Edward Island/00788/2010',
#   'A/blue-winged teal/Nova Scotia/00074/2010',
#   {'time_delta': datetime.timedelta(13),
#    'trtype': 'Intra-Species',
#    'weight': 7.999347}),
#  ('A/snow goose/Nunavet/03438/2010',
#   'A/blue-winged teal/Nova Scotia/00072/2010',
#   {'time_delta': datetime.timedelta(49),
#    'trtype': 'Intra-Species',
#    'weight': 7.997534}),
#  ('A/snow goose/Nunavet/03438/2010',
#   'A/blue-winged teal/Nova Scotia/00071/2010',
#   {'time_delta': datetime.timedelta(49),
#    'trtype': 'Intra-Species',
#    'weight': 7.996646000000001}),
#  ('A/snow goose/Nunavet/03438/2010',
#   'A/blue-winged teal/Nova Scotia/00081/2010',
#   {'time_delta': datetime.timedelta(49),
#    'trtype': 'Intra-Species',
#    'weight': 7.997534}),
#  ('A/snow goose/Nunavet/03438/2010',
#   'A/blue-winged teal/Nova Scotia/00079/2010',
#   {'time_delta': datetime.timedelta(49),
#    'trtype': 'Intra-Species',
#    'weight': 7.997102000000001}),
#  ('A/American black duck/Prince Edward Island/00788/2010',
#   'A/gadwall/Nova Scotia/00786/2010',
#   {'time_delta': datetime.timedelta(13),
#    'trtype': 'Intra-Species',
#    'weight': 7.999347}),
#  ('A/snow goose/Nunavet/03438/2010',
#   'A/blue-winged teal/Nova Scotia/00076/2010',
#   {'time_delta': datetime.timedelta(49),
#    'trtype': 'Intra-Species',
#    'weight': 7.9975330000000024}),
#  ('A/American black duck/Prince Edward Island/00788/2010',
#   'A/blue-winged teal/Nova Scotia/00075/2010',
#   {'time_delta': datetime.timedelta(13),
#    'trtype': 'Intra-Species',
#    'weight': 7.998175999999999}),
#  ('A/American black duck/Prince Edward Island/00788/2010',
#   'A/blue-winged teal/Nova Scotia/00073/2010',
#   {'time_delta': datetime.timedelta(13),
#    'trtype': 'Intra-Species',
#    'weight': 7.998175999999999}),
#  ('A/American black duck/Prince Edward Island/00788/2010',
#   'A/blue-winged teal/Nova Scotia/00078/2010',
#   {'time_delta': datetime.timedelta(13),
#    'trtype': 'Intra-Species',
#    'weight': 7.999347}),
#  ('A/American black duck/Prince Edward Island/00788/2010',
#   'A/gadwall/Nova Scotia/00783/2010',
#   {'time_delta': datetime.timedelta(13),
#    'trtype': 'Intra-Species',
#    'weight': 7.998639}),
#  ('A/American black duck/Prince Edward Island/00788/2010',
#   'A/blue-winged teal/Nova Scotia/00080/2010',
#   {'time_delta': datetime.timedelta(13),
#    'trtype': 'Intra-Species',
#    'weight': 7.998175999999999}),
#  ('A/mallard/Nova Scotia/01017/2010',
#   'A/mallard/Wisconsin/11OS3170/2011',
#   {'time_delta': datetime.timedelta(369),
#    'trtype': 'Inter-Species',
#    'weight': 7.766931}),
#  ('A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   'A/mallard/Interior Alaska/10BM12363R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.9975429999999985}),
#  ('A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   'A/mallard/Interior Alaska/10BM12363R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.9975429999999985}),
#  ('A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   'A/mallard/Interior Alaska/10BM12351R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.996974000000002}),
#  ('A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   'A/mallard/Interior Alaska/10BM12351R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.996974000000002}),
#  ('A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   'A/mallard/Interior Alaska/10BM12370R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.997547999999999}),
#  ('A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   'A/mallard/Interior Alaska/10BM12370R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.997547999999999}),
#  ('A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   'A/mallard/Interior Alaska/10BM12350R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.997547999999999}),
#  ('A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   'A/mallard/Interior Alaska/10BM12350R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.997547999999999}),
#  ('A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   'A/mallard/Interior Alaska/10BM12352R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.996899000000001}),
#  ('A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   'A/mallard/Interior Alaska/10BM12352R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.996899000000001}),
#  ('A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   'A/mallard/Interior Alaska/10BM12383R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.996391}),
#  ('A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   'A/mallard/Interior Alaska/10BM12383R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.996391}),
#  ('A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   'A/mallard/Interior Alaska/10BM12374R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.997547999999999}),
#  ('A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   'A/mallard/Interior Alaska/10BM12374R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.997547999999999}),
#  ('A/mallard/Interior Alaska/9BM3205R0/2009',
#   'A/American green-winged teal/Interior Alaska/9BM4407R0/2009',
#   {'time_delta': datetime.timedelta(7),
#    'trtype': 'Inter-Species',
#    'weight': 7.9880559999999985}),
#  ('A/blue-winged Teal/North Dakota/AI09-3881/2009',
#   'A/American black duck/New Brunswick/00470/2010',
#   {'time_delta': datetime.timedelta(333),
#    'trtype': 'Inter-Species',
#    'weight': 7.815088999999999}),
#  ('A/blue-winged Teal/North Dakota/AI09-3881/2009',
#   'A/American black duck/New Brunswick/00520/2010',
#   {'time_delta': datetime.timedelta(333),
#    'trtype': 'Inter-Species',
#    'weight': 7.813222}),
#  ('A/blue-winged Teal/North Dakota/AI09-3881/2009',
#   'A/American black duck/New Brunswick/00468/2010',
#   {'time_delta': datetime.timedelta(333),
#    'trtype': 'Inter-Species',
#    'weight': 7.8146809999999975}),
#  ('A/blue-winged Teal/North Dakota/AI09-3881/2009',
#   'A/American black duck/New Brunswick/00478/2010',
#   {'time_delta': datetime.timedelta(333),
#    'trtype': 'Inter-Species',
#    'weight': 7.815992}),
#  ('A/blue-winged Teal/North Dakota/AI09-3881/2009',
#   'A/mallard/New Brunswick/00494/2010',
#   {'time_delta': datetime.timedelta(333),
#    'trtype': 'Inter-Species',
#    'weight': 7.814097999999999}),
#  ('A/blue-winged Teal/North Dakota/AI09-3881/2009',
#   'A/American black duck/New Brunswick/00472/2010',
#   {'time_delta': datetime.timedelta(333),
#    'trtype': 'Inter-Species',
#    'weight': 7.813402000000001}),
#  ('A/blue-winged Teal/North Dakota/AI09-3881/2009',
#   'A/American black duck/New Brunswick/00481/2010',
#   {'time_delta': datetime.timedelta(333),
#    'trtype': 'Inter-Species',
#    'weight': 7.815586}),
#  ('A/blue-winged Teal/North Dakota/AI09-3881/2009',
#   'A/American black duck/New Brunswick/00464/2010',
#   {'time_delta': datetime.timedelta(333),
#    'trtype': 'Inter-Species',
#    'weight': 7.813395}),
#  ('A/blue-winged Teal/North Dakota/AI09-3881/2009',
#   'A/American black duck/New Brunswick/00469/2010',
#   {'time_delta': datetime.timedelta(333),
#    'trtype': 'Inter-Species',
#    'weight': 7.819539999999999}),
#  ('A/blue-winged Teal/North Dakota/AI09-3881/2009',
#   'A/American black duck/New Brunswick/00499/2010',
#   {'time_delta': datetime.timedelta(333),
#    'trtype': 'Inter-Species',
#    'weight': 7.813597999999999}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2569P/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.741256}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2569V/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.741256}),
#  ('A/American black duck/New Brunswick/00522/2010',
#   'A/blue-winged teal/New Brunswick/00765/2010',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Inter-Species',
#    'weight': 7.977514999999999}),
#  ('A/American black duck/New Brunswick/00522/2010',
#   'A/blue-winged teal/New Brunswick/00766/2010',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Inter-Species',
#    'weight': 7.978238000000001}),
#  ('A/American black duck/New Brunswick/00522/2010',
#   'A/blue-winged teal/New Brunswick/00775/2010',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Inter-Species',
#    'weight': 7.978506999999999}),
#  ('A/American black duck/New Brunswick/00522/2010',
#   'A/blue-winged teal/New Brunswick/00770/2010',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Inter-Species',
#    'weight': 7.976269999999999}),
#  ('A/American black duck/New Brunswick/00522/2010',
#   'A/blue-winged teal/New Brunswick/00768/2010',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Inter-Species',
#    'weight': 7.976514}),
#  ('A/American black duck/New Brunswick/00522/2010',
#   'A/blue-winged teal/New Brunswick/00767/2010',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Inter-Species',
#    'weight': 7.977514999999999}),
#  ('A/American black duck/New Brunswick/00522/2010',
#   'A/blue-winged teal/New Brunswick/00772/2010',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Inter-Species',
#    'weight': 7.977028999999999}),
#  ('A/American black duck/New Brunswick/00522/2010',
#   'A/blue-winged teal/New Brunswick/00771/2010',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Inter-Species',
#    'weight': 7.976348}),
#  ('A/American black duck/New Brunswick/00522/2010',
#   'A/blue-winged teal/New Brunswick/00769/2010',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Inter-Species',
#    'weight': 7.978401999999999}),
#  ('A/green-winged teal/Minnesota/Sg-00991/2008',
#   'A/mallard/Interior Alaska/10BM05968R0/2010',
#   {'time_delta': datetime.timedelta(684),
#    'trtype': 'Inter-Species',
#    'weight': 7.674227}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2549V/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.7402250000000015}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2540P/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.7416399999999985}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2540V/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Intra-Species',
#    'weight': 7.744361}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2561P/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.7408009999999985}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2521V/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.742727}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2521P/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.742727}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2578P/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.7403660000000025}),
#  ('A/ruddy turnstone/New Jersey/AI09-305/2009',
#   'A/shorebird/Delaware Bay/107/2009',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Inter-Species',
#    'weight': 7.997242999999999}),
#  ('A/ruddy turnstone/New Jersey/AI09-305/2009',
#   'A/shorebird/Delaware Bay/343/2009',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Inter-Species',
#    'weight': 7.996529}),
#  ('A/ruddy turnstone/New Jersey/AI09-305/2009',
#   'A/shorebird/Delaware Bay/281/2009',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Inter-Species',
#    'weight': 7.996701}),
#  ('A/ruddy turnstone/New Jersey/AI09-305/2009',
#   'A/shorebird/Delaware Bay/139/2009',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Inter-Species',
#    'weight': 7.9960049999999985}),
#  ('A/ruddy turnstone/New Jersey/AI09-305/2009',
#   'A/shorebird/Delaware Bay/240/2009',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Inter-Species',
#    'weight': 7.995316000000001}),
#  ('A/ruddy turnstone/New Jersey/AI09-305/2009',
#   'A/shorebird/Delaware Bay/322/2009',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Inter-Species',
#    'weight': 7.993592}),
#  ('A/green-winged teal/Minnesota/Sg-00991/2008',
#   'A/mallard/Interior Alaska/10BM05797R0/2010',
#   {'time_delta': datetime.timedelta(683),
#    'trtype': 'Inter-Species',
#    'weight': 7.6687689999999975}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09832R0/2010',
#   {'time_delta': datetime.timedelta(13),
#    'trtype': 'Inter-Species',
#    'weight': 7.995238}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09832R0/2010',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Inter-Species',
#    'weight': 7.995238}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM09818R0/2010',
#   {'time_delta': datetime.timedelta(13),
#    'trtype': 'Intra-Species',
#    'weight': 7.997846000000001}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM09818R0/2010',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Inter-Species',
#    'weight': 7.997846000000001}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM09563R0/2010',
#   {'time_delta': datetime.timedelta(13),
#    'trtype': 'Intra-Species',
#    'weight': 7.996361}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM09563R0/2010',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Inter-Species',
#    'weight': 7.996361}),
#  ('A/mallard/Minnesota/Sg-01030/2008',
#   'A/American green-winged teal/Illinois/08OS2713/2008',
#   {'time_delta': datetime.timedelta(44),
#    'trtype': 'Inter-Species',
#    'weight': 7.762811}),
#  ('A/mallard/Minnesota/Sg-01030/2008',
#   'A/mallard/Illinois/08OS2710/2008',
#   {'time_delta': datetime.timedelta(44),
#    'trtype': 'Inter-Species',
#    'weight': 7.762811}),
#  ('A/mallard/Minnesota/Sg-01030/2008',
#   'A/mallard/Illinois/08OS2711/2008',
#   {'time_delta': datetime.timedelta(44),
#    'trtype': 'Inter-Species',
#    'weight': 7.761838000000001}),
#  ('A/mallard/California/6768/2009',
#   'A/red-necked grebe/Minnesota/AI10-1954/2010',
#   {'time_delta': datetime.timedelta(255),
#    'trtype': 'Inter-Species',
#    'weight': 7.6444839999999985}),
#  ('A/mallard/California/6768/2009',
#   'A/red-necked grebe/Minnesota/AI10-1948/2010',
#   {'time_delta': datetime.timedelta(255),
#    'trtype': 'Inter-Species',
#    'weight': 7.641563}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM07072R0/2010',
#   {'time_delta': datetime.timedelta(7),
#    'trtype': 'Intra-Species',
#    'weight': 7.997527000000002}),
#  ('A/American green-winged teal/Interior Alaska/9BM4407R0/2009',
#   'A/northern pintail/Interior Alaska/9BM11387R0/2009',
#   {'time_delta': datetime.timedelta(22),
#    'trtype': 'Inter-Species',
#    'weight': 7.995412999999999}),
#  ('A/American green-winged teal/Interior Alaska/10BM08422R0/2010',
#   'A/mallard/Interior Alaska/10BM12177R0/2010',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Inter-Species',
#    'weight': 7.989471000000001}),
#  ('A/American green-winged teal/Interior Alaska/10BM08422R0/2010',
#   'A/northern pintail/Interior Alaska/10BM12163R0/2010',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Inter-Species',
#    'weight': 7.988461999999998}),
#  ('A/American green-winged teal/Interior Alaska/10BM08422R0/2010',
#   'A/mallard/Interior Alaska/10BM12172R0/2010',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Inter-Species',
#    'weight': 7.987881}),
#  ('A/northern shoveler/Interior Alaska/10BM02593R0/2010',
#   'A/mallard/Interior Alaska/10BM06456R0/2010',
#   {'time_delta': datetime.timedelta(37),
#    'trtype': 'Intra-Species',
#    'weight': 7.982297}),
#  ('A/northern shoveler/Interior Alaska/10BM02593R0/2010',
#   'A/mallard/Interior Alaska/10BM06455R0/2010',
#   {'time_delta': datetime.timedelta(37),
#    'trtype': 'Intra-Species',
#    'weight': 7.98245}),
#  ('A/northern shoveler/Interior Alaska/10BM02593R0/2010',
#   'A/mallard/Interior Alaska/10BM06461R0/2010',
#   {'time_delta': datetime.timedelta(37),
#    'trtype': 'Intra-Species',
#    'weight': 7.982883}),
#  ('A/northern shoveler/Interior Alaska/10BM02593R0/2010',
#   'A/mallard/Interior Alaska/10BM06448R0/2010',
#   {'time_delta': datetime.timedelta(37),
#    'trtype': 'Intra-Species',
#    'weight': 7.982883}),
#  ('A/northern shoveler/Interior Alaska/10BM02593R0/2010',
#   'A/mallard/Interior Alaska/10BM06452R0/2010',
#   {'time_delta': datetime.timedelta(37),
#    'trtype': 'Intra-Species',
#    'weight': 7.982883}),
#  ('A/northern shoveler/Interior Alaska/10BM02593R0/2010',
#   'A/mallard/Interior Alaska/10BM06454R0/2010',
#   {'time_delta': datetime.timedelta(37),
#    'trtype': 'Intra-Species',
#    'weight': 7.982862}),
#  ('A/northern shoveler/Interior Alaska/10BM02593R0/2010',
#   'A/mallard/Interior Alaska/10BM06459R0/2010',
#   {'time_delta': datetime.timedelta(37),
#    'trtype': 'Intra-Species',
#    'weight': 7.98245}),
#  ('A/northern shoveler/Interior Alaska/10BM02593R0/2010',
#   'A/mallard/Interior Alaska/10BM06460R0/2010',
#   {'time_delta': datetime.timedelta(37),
#    'trtype': 'Intra-Species',
#    'weight': 7.981874}),
#  ('A/northern shoveler/Interior Alaska/10BM02593R0/2010',
#   'A/mallard/Interior Alaska/10BM06450R0/2010',
#   {'time_delta': datetime.timedelta(37),
#    'trtype': 'Intra-Species',
#    'weight': 7.982883}),
#  ('A/northern pintail/Interior Alaska/9BM6095R0/2009',
#   'A/mallard/Interior Alaska/9BM8471R0/2009',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.876136}),
#  ('A/American wigeon/Interior Alaska/9BM2501R1/2009',
#   'A/northern pintail/Interior Alaska/9BM7254R0/2009',
#   {'time_delta': datetime.timedelta(26),
#    'trtype': 'Inter-Species',
#    'weight': 7.712579000000002}),
#  ('A/American wigeon/Interior Alaska/9BM2501R1/2009',
#   'A/northern pintail/Interior Alaska/9BM7252R0/2009',
#   {'time_delta': datetime.timedelta(26),
#    'trtype': 'Inter-Species',
#    'weight': 7.712147000000002}),
#  ('A/black scoter/New Brunswick/00002/2009',
#   'A/mallard/Nova Scotia/03271/2009',
#   {'time_delta': datetime.timedelta(96),
#    'trtype': 'Inter-Species',
#    'weight': 7.997974}),
#  ('A/black scoter/New Brunswick/00002/2009',
#   'A/American black duck/Nova Scotia/03273/2009',
#   {'time_delta': datetime.timedelta(96),
#    'trtype': 'Inter-Species',
#    'weight': 7.992533999999999}),
#  ('A/northern pintail/Interior Alaska/8BM3582/2008',
#   'A/northern pintail/Interior Alaska/9BM7118R1/2009',
#   {'time_delta': datetime.timedelta(326),
#    'trtype': 'Intra-Species',
#    'weight': 7.9679959999999985}),
#  ('A/mallard/Interior Alaska/10BM05797R0/2010',
#   'A/northern pintail/Interior Alaska/10BM07597R0/2010',
#   {'time_delta': datetime.timedelta(7),
#    'trtype': 'Inter-Species',
#    'weight': 7.984493}),
#  ('A/gadwall/Wisconsin/08OS2296/2008',
#   'A/northern shoveler/Mississippi/10OS4526/2010',
#   {'time_delta': datetime.timedelta(781),
#    'trtype': 'Inter-Species',
#    'weight': 7.709641}),
#  ('A/northern pintail/Interior Alaska/10BM07242R0/2010',
#   'A/blue-winged teal/Canada/3239/2011',
#   {'time_delta': datetime.timedelta(414),
#    'trtype': 'Inter-Species',
#    'weight': 7.722503999999999}),
#  ('A/northern pintail/Interior Alaska/10BM07242R0/2010',
#   'A/blue-winged teal/Canada/3241/2011',
#   {'time_delta': datetime.timedelta(414),
#    'trtype': 'Inter-Species',
#    'weight': 7.7210459999999985}),
#  ('A/northern pintail/Interior Alaska/10BM07242R0/2010',
#   'A/blue-winged teal/Canada/3240/2011',
#   {'time_delta': datetime.timedelta(414),
#    'trtype': 'Inter-Species',
#    'weight': 7.7234599999999975}),
#  ('A/northern pintail/Interior Alaska/10BM07242R0/2010',
#   'A/blue-winged teal/Canada/3237/2011',
#   {'time_delta': datetime.timedelta(414),
#    'trtype': 'Inter-Species',
#    'weight': 7.721315}),
#  ('A/northern pintail/Interior Alaska/9BM6494R0/2009',
#   'A/mallard/California/1154/2010',
#   {'time_delta': datetime.timedelta(358),
#    'trtype': 'Inter-Species',
#    'weight': 7.716034}),
#  ('A/mallard/Ohio/11OS2138/2011',
#   'A/mallard/Wisconsin/11OS3159/2011',
#   {'time_delta': datetime.timedelta(40),
#    'trtype': 'Intra-Species',
#    'weight': 7.671087000000001}),
#  ('A/mallard/Ohio/11OS2138/2011',
#   'A/mallard/Wisconsin/11OS3161/2011',
#   {'time_delta': datetime.timedelta(40),
#    'trtype': 'Intra-Species',
#    'weight': 7.6706530000000015}),
#  ('A/northern pintail/Interior Alaska/8BM3582/2008',
#   'A/northern pintail/Interior Alaska/9BM8907R0/2009',
#   {'time_delta': datetime.timedelta(331),
#    'trtype': 'Intra-Species',
#    'weight': 7.986150999999999}),
#  ('A/blue-winged teal/Wisconsin/10OS2862/2010',
#   'A/blue-winged teal/Wisconsin/11OS3301/2011',
#   {'time_delta': datetime.timedelta(364),
#    'trtype': 'Inter-Species',
#    'weight': 7.767531}),
#  ('A/blue-winged teal/Wisconsin/10OS2862/2010',
#   'A/mallard/Wisconsin/11OS3305/2011',
#   {'time_delta': datetime.timedelta(364),
#    'trtype': 'Inter-Species',
#    'weight': 7.767963000000001}),
#  ('A/blue-winged teal/Wisconsin/10OS2862/2010',
#   'A/blue-winged teal/Wisconsin/11OS3303/2011',
#   {'time_delta': datetime.timedelta(364),
#    'trtype': 'Inter-Species',
#    'weight': 7.767963000000001}),
#  ('A/northern pintail/Interior Alaska/9BM7050R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10471R0/2009',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Intra-Species',
#    'weight': 7.9923769999999985}),
#  ('A/northern pintail/Interior Alaska/9BM7055R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10471R0/2009',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Intra-Species',
#    'weight': 7.9923769999999985}),
#  ('A/northern pintail/Interior Alaska/9BM10819R0/2009',
#   'A/mallard/Interior Alaska/9BM12285R0/2009',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Inter-Species',
#    'weight': 7.994649000000001}),
#  ('A/northern pintail/Interior Alaska/9BM10819R0/2009',
#   'A/northern shoveler/Interior Alaska/9BM12298R0/2009',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Inter-Species',
#    'weight': 7.993942}),
#  ('A/northern pintail/Interior Alaska/9BM7836R0/2009',
#   'A/northern pintail/Interior Alaska/9BM10819R0/2009',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Intra-Species',
#    'weight': 7.988417}),
#  ('A/northern pintail/Interior Alaska/9BM6494R0/2009',
#   'A/mallard/California/1210/2010',
#   {'time_delta': datetime.timedelta(360),
#    'trtype': 'Inter-Species',
#    'weight': 7.713840999999999}),
#  ('A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   'A/mallard/Interior Alaska/10BM11414R0/2010',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.996035000000001}),
#  ('A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   'A/mallard/Interior Alaska/10BM11414R0/2010',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.996035000000001}),
#  ('A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   'A/mallard/Interior Alaska/10BM11419R0/2010',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.994719}),
#  ('A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   'A/mallard/Interior Alaska/10BM11419R0/2010',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.994719}),
#  ('A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   'A/mallard/Interior Alaska/10BM11415R0/2010',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.994575}),
#  ('A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   'A/mallard/Interior Alaska/10BM11415R0/2010',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.994575}),
#  ('A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   'A/mallard/Interior Alaska/10BM11418R0/2010',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.995171000000001}),
#  ('A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   'A/mallard/Interior Alaska/10BM11418R0/2010',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.995171000000001}),
#  ('A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   'A/mallard/Interior Alaska/10BM11420R0/2010',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.996035000000001}),
#  ('A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   'A/mallard/Interior Alaska/10BM11420R0/2010',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.996035000000001}),
#  ('A/mallard/New Brunswick/00349/2010',
#   'A/American black duck/Nova Scotia/00094/2010',
#   {'time_delta': datetime.timedelta(33),
#    'trtype': 'Intra-Species',
#    'weight': 7.999427000000002}),
#  ('A/mallard/New Brunswick/00349/2010',
#   'A/mallard/Nova Scotia/00088/2010',
#   {'time_delta': datetime.timedelta(33),
#    'trtype': 'Intra-Species',
#    'weight': 7.994263}),
#  ('A/mallard/New Brunswick/00349/2010',
#   'A/American black duck/Nova Scotia/00098/2010',
#   {'time_delta': datetime.timedelta(33),
#    'trtype': 'Intra-Species',
#    'weight': 7.999427000000002}),
#  ('A/American green-winged teal/Interior Alaska/10BM07917R0/2010',
#   'A/American black duck/New Brunswick/00500/2010',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Intra-Species',
#    'weight': 7.6824410000000025}),
#  ('A/American green-winged teal/Interior Alaska/10BM07917R0/2010',
#   'A/American black duck/New Brunswick/00484/2010',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Intra-Species',
#    'weight': 7.6759330000000014}),
#  ('A/American green-winged teal/Interior Alaska/10BM07917R0/2010',
#   'A/mallard/New Brunswick/00495/2010',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Intra-Species',
#    'weight': 7.681027999999999}),
#  ('A/mallard/Minnesota/Sg-00930/2008',
#   'A/mallard/New Jersey/AI09-5122/2009',
#   {'time_delta': datetime.timedelta(377),
#    'trtype': 'Intra-Species',
#    'weight': 7.72642}),
#  ('A/mallard/Minnesota/Sg-00930/2008',
#   'A/mallard/New Jersey/AI09-5361/2009',
#   {'time_delta': datetime.timedelta(377),
#    'trtype': 'Intra-Species',
#    'weight': 7.726739999999999}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM07458R0/2010',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.992866999999999}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM07458R0/2010',
#   {'time_delta': datetime.timedelta(7),
#    'trtype': 'Inter-Species',
#    'weight': 7.992866999999999}),
#  ('A/mallard/Wisconsin/2712/2009',
#   'A/mallard/Interior Alaska/10BM11485R0/2010',
#   {'time_delta': datetime.timedelta(305),
#    'trtype': 'Intra-Species',
#    'weight': 7.641762}),
#  ('A/mallard/Mississippi/329/2010',
#   'A/mallard-black duck hybrid/New Brunswick/00904/2010',
#   {'time_delta': datetime.timedelta(241),
#    'trtype': 'Inter-Species',
#    'weight': 7.826367999999999}),
#  ('A/mallard/Mississippi/329/2010',
#   'A/American black duck/New Brunswick/00909/2010',
#   {'time_delta': datetime.timedelta(241),
#    'trtype': 'Inter-Species',
#    'weight': 7.825141}),
#  ('A/mallard/Mississippi/329/2010',
#   'A/American black duck/New Brunswick/00906/2010',
#   {'time_delta': datetime.timedelta(241),
#    'trtype': 'Inter-Species',
#    'weight': 7.8263310000000015}),
#  ('A/blue-winged teal/Missouri/11OS2620/2011',
#   'A/blue-winged teal/Canada/3301/2011',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Intra-Species',
#    'weight': 7.7689070000000005}),
#  ('A/blue-winged teal/Missouri/11OS2583/2011',
#   'A/blue-winged teal/Canada/3301/2011',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Intra-Species',
#    'weight': 7.7689070000000005}),
#  ('A/blue-winged teal/Missouri/11OS2620/2011',
#   'A/blue-winged teal/Canada/3304/2011',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Intra-Species',
#    'weight': 7.769912}),
#  ('A/blue-winged teal/Missouri/11OS2583/2011',
#   'A/blue-winged teal/Canada/3304/2011',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Intra-Species',
#    'weight': 7.769912}),
#  ('A/blue-winged teal/Missouri/11OS2583/2011',
#   'A/blue-winged teal/Canada/3305/2011',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Intra-Species',
#    'weight': 7.769458999999999}),
#  ('A/blue-winged teal/Missouri/11OS2620/2011',
#   'A/blue-winged teal/Canada/3300/2011',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Intra-Species',
#    'weight': 7.768255}),
#  ('A/blue-winged teal/Missouri/11OS2583/2011',
#   'A/blue-winged teal/Canada/3300/2011',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Intra-Species',
#    'weight': 7.768255}),
#  ('A/ruddy turnstone/New Jersey/Sg-00496/2008',
#   'A/ruddy turnstone/New Jersey/Sg-00477/2008',
#   {'time_delta': datetime.timedelta(7),
#    'trtype': 'Intra-Species',
#    'weight': 7.99383}),
#  ('A/northern pintail/Interior Alaska/9BM8907R0/2009',
#   'A/northern pintail/Interior Alaska/10BM11694R0/2010',
#   {'time_delta': datetime.timedelta(367),
#    'trtype': 'Intra-Species',
#    'weight': 7.973725}),
#  ('A/northern pintail/Interior Alaska/9BM8907R0/2009',
#   'A/northern pintail/Interior Alaska/10BM11989R0/2010',
#   {'time_delta': datetime.timedelta(367),
#    'trtype': 'Intra-Species',
#    'weight': 7.971804}),
#  ('A/blue-winged teal/Louisiana/AI09-5159/2009',
#   'A/wood duck/Wisconsin/10OS2778/2010',
#   {'time_delta': datetime.timedelta(316),
#    'trtype': 'Inter-Species',
#    'weight': 7.768421000000001}),
#  ('A/blue-winged teal/Louisiana/AI09-5159/2009',
#   'A/mallard/Wisconsin/10OS2773/2010',
#   {'time_delta': datetime.timedelta(316),
#    'trtype': 'Intra-Species',
#    'weight': 7.769418999999999}),
#  ('A/mallard/California/5222/2009',
#   'A/mallard/California/5386/2009',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.9846660000000025}),
#  ('A/mallard/California/5222/2009',
#   'A/mallard/California/5359/2009',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.984058}),
#  ('A/ruddy turnstone/New Jersey/AI09-305/2009',
#   'A/shorebird/Delaware Bay/271/2009',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Inter-Species',
#    'weight': 7.9796179999999985}),
#  ('A/northern pintail/Interior Alaska/8BM3582/2008',
#   'A/northern pintail/Interior Alaska/9BM6290R0/2009',
#   {'time_delta': datetime.timedelta(323),
#    'trtype': 'Inter-Species',
#    'weight': 7.977597999999999}),
#  ('A/American green-winged teal/Interior Alaska/9BM4407R0/2009',
#   'A/mallard/Interior Alaska/9BM11351R0/2009',
#   {'time_delta': datetime.timedelta(22),
#    'trtype': 'Inter-Species',
#    'weight': 7.9986039999999985}),
#  ('A/American green-winged teal/Interior Alaska/9BM4407R0/2009',
#   'A/northern pintail/Interior Alaska/9BM11151R0/2009',
#   {'time_delta': datetime.timedelta(22),
#    'trtype': 'Inter-Species',
#    'weight': 7.9986039999999985}),
#  ('A/northern shoveler/Interior Alaska/9BM2943R1/2009',
#   'A/mallard/Wisconsin/10OS2918/2010',
#   {'time_delta': datetime.timedelta(444),
#    'trtype': 'Intra-Species',
#    'weight': 7.725905}),
#  ('A/northern shoveler/Interior Alaska/9BM2943R1/2009',
#   'A/mallard/Wisconsin/10OS2917/2010',
#   {'time_delta': datetime.timedelta(444),
#    'trtype': 'Intra-Species',
#    'weight': 7.725905}),
#  ('A/northern pintail/Interior Alaska/9BM7050R0/2009',
#   'A/mallard/Interior Alaska/9BM10851R0/2009',
#   {'time_delta': datetime.timedelta(11),
#    'trtype': 'Inter-Species',
#    'weight': 7.9867029999999986}),
#  ('A/northern pintail/Interior Alaska/9BM7055R0/2009',
#   'A/mallard/Interior Alaska/9BM10851R0/2009',
#   {'time_delta': datetime.timedelta(11),
#    'trtype': 'Inter-Species',
#    'weight': 7.9867029999999986}),
#  ('A/ruddy turnstone/New Jersey/AI09-294/2009',
#   'A/hooded merganser/New Brunswick/03750/2009',
#   {'time_delta': datetime.timedelta(126),
#    'trtype': 'Inter-Species',
#    'weight': 7.933623}),
#  ('A/ruddy turnstone/New Jersey/AI09-294/2009',
#   'A/mallard-black duck hybrid/New Brunswick/03736/2009',
#   {'time_delta': datetime.timedelta(126),
#    'trtype': 'Inter-Species',
#    'weight': 7.93115}),
#  ('A/mallard/Nova Scotia/00346/2010',
#   'A/mallard/Nova Scotia/00093/2010',
#   {'time_delta': datetime.timedelta(33),
#    'trtype': 'Intra-Species',
#    'weight': 7.999297}),
#  ('A/mallard/Nova Scotia/00346/2010',
#   'A/mallard/Nova Scotia/00085/2010',
#   {'time_delta': datetime.timedelta(33),
#    'trtype': 'Intra-Species',
#    'weight': 7.999297}),
#  ('A/American green-winged teal/Interior Alaska/9BM4407R0/2009',
#   'A/mallard/Interior Alaska/9BM9201R0/2009',
#   {'time_delta': datetime.timedelta(16),
#    'trtype': 'Inter-Species',
#    'weight': 7.998849000000001}),
#  ('A/shorebird/Delaware Bay/226/2009',
#   'A/ruddy turnstone/New Jersey/AI09-1233/2009',
#   {'time_delta': datetime.timedelta(14),
#    'trtype': 'Inter-Species',
#    'weight': 7.9575460000000025}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09481R0/2010',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Inter-Species',
#    'weight': 7.997961}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09481R0/2010',
#   {'time_delta': datetime.timedelta(11),
#    'trtype': 'Inter-Species',
#    'weight': 7.997961}),
#  ('A/northern pintail/Interior Alaska/9BM7620R0/2009',
#   'A/mallard/Interior Alaska/9BM9983R0/2009',
#   {'time_delta': datetime.timedelta(7),
#    'trtype': 'Inter-Species',
#    'weight': 7.985652}),
#  ('A/northern pintail/Interior Alaska/9BM7620R0/2009',
#   'A/mallard/Interior Alaska/9BM9984R0/2009',
#   {'time_delta': datetime.timedelta(7),
#    'trtype': 'Inter-Species',
#    'weight': 7.984180999999999}),
#  ('A/northern pintail/Interior Alaska/9BM7620R0/2009',
#   'A/mallard/Interior Alaska/9BM9985R0/2009',
#   {'time_delta': datetime.timedelta(7),
#    'trtype': 'Inter-Species',
#    'weight': 7.985652}),
#  ('A/ruddy turnstone/New Jersey/AI09-305/2009',
#   'A/ruddy turnstone/New Jersey/AI09-342/2009',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Intra-Species',
#    'weight': 7.9857429999999985}),
#  ('A/northern pintail/Interior Alaska/8BM3582/2008',
#   'A/northern pintail/Interior Alaska/9BM6960R0/2009',
#   {'time_delta': datetime.timedelta(325),
#    'trtype': 'Intra-Species',
#    'weight': 7.9687350000000015}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10853R0/2010',
#   {'time_delta': datetime.timedelta(16),
#    'trtype': 'Inter-Species',
#    'weight': 7.9966279999999985}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10853R0/2010',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Inter-Species',
#    'weight': 7.9966279999999985}),
#  ('A/mallard/Interior Alaska/10BM07066R0/2010',
#   'A/mallard/Interior Alaska/10BM10787R0/2010',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Intra-Species',
#    'weight': 7.9940479999999985}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM10861R0/2010',
#   {'time_delta': datetime.timedelta(16),
#    'trtype': 'Intra-Species',
#    'weight': 7.9966279999999985}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM10861R0/2010',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Inter-Species',
#    'weight': 7.9966279999999985}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM10829R0/2010',
#   {'time_delta': datetime.timedelta(16),
#    'trtype': 'Intra-Species',
#    'weight': 7.9966279999999985}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM10829R0/2010',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Inter-Species',
#    'weight': 7.9966279999999985}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM10876R0/2010',
#   {'time_delta': datetime.timedelta(16),
#    'trtype': 'Intra-Species',
#    'weight': 7.9966279999999985}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM10876R0/2010',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Inter-Species',
#    'weight': 7.9966279999999985}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM10859R0/2010',
#   {'time_delta': datetime.timedelta(16),
#    'trtype': 'Intra-Species',
#    'weight': 7.9966279999999985}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM10859R0/2010',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Inter-Species',
#    'weight': 7.9966279999999985}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10790R0/2010',
#   {'time_delta': datetime.timedelta(16),
#    'trtype': 'Inter-Species',
#    'weight': 7.995471999999999}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10790R0/2010',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Inter-Species',
#    'weight': 7.995471999999999}),
#  ('A/mallard/Interior Alaska/9BM2057/2009',
#   'A/American green-winged teal/Interior Alaska/9BM8129R0/2009',
#   {'time_delta': datetime.timedelta(32),
#    'trtype': 'Inter-Species',
#    'weight': 7.696851}),
#  ('A/mallard/Interior Alaska/9BM2057/2009',
#   'A/northern pintail/Interior Alaska/9BM7972R0/2009',
#   {'time_delta': datetime.timedelta(32),
#    'trtype': 'Inter-Species',
#    'weight': 7.6961280000000025}),
#  ('A/mallard/Interior Alaska/9BM1949/2009',
#   'A/mallard/Interior Alaska/9BM2241R1/2009',
#   {'time_delta': datetime.timedelta(7),
#    'trtype': 'Inter-Species',
#    'weight': 7.997994999999999}),
#  ('A/mallard/Interior Alaska/9BM1949/2009',
#   'A/mallard/Interior Alaska/9BM2250R0/2009',
#   {'time_delta': datetime.timedelta(7),
#    'trtype': 'Inter-Species',
#    'weight': 7.997994999999999}),
#  ('A/mallard/Wisconsin/1538/2009',
#   'A/American black duck/New Brunswick/00991/2010',
#   {'time_delta': datetime.timedelta(394),
#    'trtype': 'Inter-Species',
#    'weight': 7.7777850000000015}),
#  ('A/mallard/Wisconsin/1538/2009',
#   'A/American black duck/New Brunswick/00986/2010',
#   {'time_delta': datetime.timedelta(394),
#    'trtype': 'Inter-Species',
#    'weight': 7.759139999999999}),
#  ('A/American green-winged teal/Interior Alaska/9BM6410R0/2009',
#   'A/blue-winged teal/New Brunswick/00289/2010',
#   {'time_delta': datetime.timedelta(407),
#    'trtype': 'Intra-Species',
#    'weight': 7.647392}),
#  ('A/American green-winged teal/Interior Alaska/9BM6410R0/2009',
#   'A/blue-winged teal/New Brunswick/00283/2010',
#   {'time_delta': datetime.timedelta(407),
#    'trtype': 'Intra-Species',
#    'weight': 7.6484960000000015}),
#  ('A/American green-winged teal/Interior Alaska/9BM6410R0/2009',
#   'A/blue-winged teal/New Brunswick/00291/2010',
#   {'time_delta': datetime.timedelta(407),
#    'trtype': 'Intra-Species',
#    'weight': 7.647392}),
#  ('A/American green-winged teal/Interior Alaska/9BM6410R0/2009',
#   'A/blue-winged teal/New Brunswick/00285/2010',
#   {'time_delta': datetime.timedelta(407),
#    'trtype': 'Intra-Species',
#    'weight': 7.647845999999999}),
#  ('A/northern pintail/Interior Alaska/9BM8907R0/2009',
#   'A/northern pintail/Interior Alaska/10BM10480R0/2010',
#   {'time_delta': datetime.timedelta(363),
#    'trtype': 'Intra-Species',
#    'weight': 7.975144999999999}),
#  ('A/northern pintail/Louisiana/Sg-01033/2008',
#   'A/ring-necked duck/Illinois/4125/2009',
#   {'time_delta': datetime.timedelta(385),
#    'trtype': 'Inter-Species',
#    'weight': 7.8392779999999975}),
#  ('A/northern pintail/Louisiana/Sg-01033/2008',
#   'A/mallard/Illinois/4124/2009',
#   {'time_delta': datetime.timedelta(385),
#    'trtype': 'Inter-Species',
#    'weight': 7.839239}),
#  ('A/mallard/Interior Alaska/9BM3205R0/2009',
#   'A/northern pintail/Interior Alaska/9BM9383R0/2009',
#   {'time_delta': datetime.timedelta(23),
#    'trtype': 'Inter-Species',
#    'weight': 7.986298}),
#  ('A/northern pintail/Interior Alaska/9BM7118R1/2009',
#   'A/mallard/Interior Alaska/9BM10051R0/2009',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Inter-Species',
#    'weight': 7.997242}),
#  ('A/American green-winged teal/Interior Alaska/9BM5041R0/2009',
#   'A/northern pintail/Interior Alaska/9BM7620R0/2009',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.995724000000001}),
#  ('A/northern shoveler/Interior Alaska/9BM4787R0/2009',
#   'A/northern pintail/Interior Alaska/9BM7240R0/2009',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.985313999999999}),
#  ('A/mallard/Minnesota/Sg-00930/2008',
#   'A/northern pintail/Wisconsin/4198/2009',
#   {'time_delta': datetime.timedelta(443),
#    'trtype': 'Inter-Species',
#    'weight': 7.7439909999999985}),
#  ('A/black scoter/New Brunswick/00002/2009',
#   'A/mallard/New Brunswick/03482/2009',
#   {'time_delta': datetime.timedelta(104),
#    'trtype': 'Inter-Species',
#    'weight': 7.995069999999999}),
#  ('A/black scoter/New Brunswick/00002/2009',
#   'A/green-winged teal/New Brunswick/03483/2009',
#   {'time_delta': datetime.timedelta(104),
#    'trtype': 'Inter-Species',
#    'weight': 7.995705}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09347R0/2010',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Inter-Species',
#    'weight': 7.9963820000000005}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09347R0/2010',
#   {'time_delta': datetime.timedelta(11),
#    'trtype': 'Inter-Species',
#    'weight': 7.9963820000000005}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09348R0/2010',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Inter-Species',
#    'weight': 7.9963820000000005}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM09348R0/2010',
#   {'time_delta': datetime.timedelta(11),
#    'trtype': 'Inter-Species',
#    'weight': 7.9963820000000005}),
#  ('A/northern shoveler/Interior Alaska/10BM02593R0/2010',
#   'A/American green-winged teal/Interior Alaska/10BM05165R0/2010',
#   {'time_delta': datetime.timedelta(29),
#    'trtype': 'Inter-Species',
#    'weight': 7.989718999999999}),
#  ('A/ruddy turnstone/New Jersey/Sg-00496/2008',
#   'A/ruddy turnstone/New Jersey/Sg-00531/2008',
#   {'time_delta': datetime.timedelta(12),
#    'trtype': 'Intra-Species',
#    'weight': 7.9568949999999985}),
#  ('A/black scoter/New Brunswick/00002/2009',
#   'A/northern pintail/New Brunswick/03547/2009',
#   {'time_delta': datetime.timedelta(132),
#    'trtype': 'Inter-Species',
#    'weight': 7.999425}),
#  ('A/northern pintail/Interior Alaska/9BM6205R0/2009',
#   'A/mallard/Interior Alaska/9BM10043R0/2009',
#   {'time_delta': datetime.timedelta(13),
#    'trtype': 'Inter-Species',
#    'weight': 7.998096}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2576P/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.743459}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2576V/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.746422000000001}),
#  ('A/mallard/California/1188/2010',
#   'A/blue-winged teal/Illinois/10OS1563/2010',
#   {'time_delta': datetime.timedelta(37),
#    'trtype': 'Inter-Species',
#    'weight': 7.702699999999999}),
#  ('A/mallard/California/1188/2010',
#   'A/blue-winged teal/Illinois/10OS1561/2010',
#   {'time_delta': datetime.timedelta(37),
#    'trtype': 'Inter-Species',
#    'weight': 7.702699999999999}),
#  ('A/mallard/California/6695/2009',
#   'A/American wigeon/California/2423/2010',
#   {'time_delta': datetime.timedelta(363),
#    'trtype': 'Inter-Species',
#    'weight': 7.959399999999999}),
#  ('A/mallard/California/6695/2009',
#   'A/mallard/California/2529/2010',
#   {'time_delta': datetime.timedelta(363),
#    'trtype': 'Inter-Species',
#    'weight': 7.958345}),
#  ('A/ruddy turnstone/New Jersey/Sg-00496/2008',
#   'A/shorebird/Delaware Bay/589/2008',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.992953}),
#  ('A/ruddy turnstone/New Jersey/Sg-00496/2008',
#   'A/shorebird/Delaware Bay/588/2008',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.992953}),
#  ('A/American green-winged teal/Interior Alaska/9BM8129R0/2009',
#   'A/blue-winged Teal/North Dakota/AI09-3131/2009',
#   {'time_delta': datetime.timedelta(25),
#    'trtype': 'Inter-Species',
#    'weight': 7.711958}),
#  ('A/blue-winged teal/Guatemala/CIP049-05/2010',
#   'A/green-winged teal/Nova Scotia/00354/2010',
#   {'time_delta': datetime.timedelta(189),
#    'trtype': 'Intra-Species',
#    'weight': 7.615873}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM10811R0/2010',
#   {'time_delta': datetime.timedelta(16),
#    'trtype': 'Intra-Species',
#    'weight': 7.9969160000000015}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM10811R0/2010',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Inter-Species',
#    'weight': 7.9969160000000015}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10805R0/2010',
#   {'time_delta': datetime.timedelta(16),
#    'trtype': 'Inter-Species',
#    'weight': 7.996483}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10805R0/2010',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Inter-Species',
#    'weight': 7.996483}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10807R0/2010',
#   {'time_delta': datetime.timedelta(16),
#    'trtype': 'Inter-Species',
#    'weight': 7.9969160000000015}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10807R0/2010',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Inter-Species',
#    'weight': 7.9969160000000015}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10809R0/2010',
#   {'time_delta': datetime.timedelta(16),
#    'trtype': 'Inter-Species',
#    'weight': 7.9969160000000015}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10809R0/2010',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Inter-Species',
#    'weight': 7.9969160000000015}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10801R0/2010',
#   {'time_delta': datetime.timedelta(16),
#    'trtype': 'Inter-Species',
#    'weight': 7.996483}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/northern pintail/Interior Alaska/10BM10801R0/2010',
#   {'time_delta': datetime.timedelta(15),
#    'trtype': 'Inter-Species',
#    'weight': 7.996483}),
#  ('A/northern pintail/Interior Alaska/9BM8907R0/2009',
#   'A/mallard/Interior Alaska/9BM11965R0/2009',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Inter-Species',
#    'weight': 7.974964999999999}),
#  ('A/northern pintail/Interior Alaska/9BM8907R0/2009',
#   'A/northern pintail/Interior Alaska/9BM12176R0/2009',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Inter-Species',
#    'weight': 7.975417999999999}),
#  ('A/northern pintail/Interior Alaska/9BM8907R0/2009',
#   'A/northern pintail/Interior Alaska/9BM12180R0/2009',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Inter-Species',
#    'weight': 7.975417999999999}),
#  ('A/northern pintail/Interior Alaska/9BM6095R0/2009',
#   'A/mallard/Interior Alaska/9BM8829R0/2009',
#   {'time_delta': datetime.timedelta(9),
#    'trtype': 'Inter-Species',
#    'weight': 7.9940760000000015}),
#  ('A/mallard/California/10126/2008',
#   'A/mallard/Illinois/10OS3786/2010',
#   {'time_delta': datetime.timedelta(714),
#    'trtype': 'Inter-Species',
#    'weight': 7.724187}),
#  ('A/American green-winged teal/Texas/AI09-6046/2009',
#   'A/American black duck/Prince Edward Island/00672/2010',
#   {'time_delta': datetime.timedelta(234),
#    'trtype': 'Intra-Species',
#    'weight': 7.686628}),
#  ('A/American green-winged teal/Texas/AI09-6046/2009',
#   'A/American black duck/Prince Edward Island/00673/2010',
#   {'time_delta': datetime.timedelta(234),
#    'trtype': 'Intra-Species',
#    'weight': 7.6872539999999985}),
#  ('A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   'A/mallard/Interior Alaska/10BM11416R0/2010',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.995331}),
#  ('A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   'A/mallard/Interior Alaska/10BM11416R0/2010',
#   {'time_delta': datetime.timedelta(8),
#    'trtype': 'Inter-Species',
#    'weight': 7.995331}),
#  ('A/mallard/Interior Alaska/10BM04564R1/2010',
#   'A/northern pintail/Interior Alaska/10BM11038R0/2010',
#   {'time_delta': datetime.timedelta(24),
#    'trtype': 'Inter-Species',
#    'weight': 7.795902000000001}),
#  ('A/mallard/Ohio/11OS2085/2011',
#   'A/blue-winged teal/Missouri/11OS2620/2011',
#   {'time_delta': datetime.timedelta(23),
#    'trtype': 'Inter-Species',
#    'weight': 7.740749}),
#  ('A/mallard/Ohio/11OS2085/2011',
#   'A/blue-winged teal/Missouri/11OS2583/2011',
#   {'time_delta': datetime.timedelta(23),
#    'trtype': 'Inter-Species',
#    'weight': 7.740749}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM08884R0/2010',
#   {'time_delta': datetime.timedelta(11),
#    'trtype': 'Intra-Species',
#    'weight': 7.995813}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM08884R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.995813}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM08883R0/2010',
#   {'time_delta': datetime.timedelta(11),
#    'trtype': 'Intra-Species',
#    'weight': 7.996247}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM08883R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.996247}),
#  ('A/mallard/Interior Alaska/10BM05347R0/2010',
#   'A/mallard/Interior Alaska/10BM08874R0/2010',
#   {'time_delta': datetime.timedelta(11),
#    'trtype': 'Intra-Species',
#    'weight': 7.996247}),
#  ('A/mallard/Interior Alaska/10BM05860R0/2010',
#   'A/mallard/Interior Alaska/10BM08874R0/2010',
#   {'time_delta': datetime.timedelta(10),
#    'trtype': 'Inter-Species',
#    'weight': 7.996247}),
#  ('A/ruddy turnstone/New Jersey/Sg-00556/2008',
#   'A/mallard/Alberta/121/2008',
#   {'time_delta': datetime.timedelta(63),
#    'trtype': 'Inter-Species',
#    'weight': 7.6732380000000004}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2550P/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.742072999999999}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2547V/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.742072999999999}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2550V/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.742072999999999}),
#  ('A/American green-winged teal/Interior Alaska/10BM04207R0/2010',
#   'A/mallard/Interior Alaska/10BM09893R0/2010',
#   {'time_delta': datetime.timedelta(26),
#    'trtype': 'Inter-Species',
#    'weight': 7.992238}),
#  ('A/American green-winged teal/Interior Alaska/10BM04207R0/2010',
#   'A/mallard/Interior Alaska/10BM09896R0/2010',
#   {'time_delta': datetime.timedelta(26),
#    'trtype': 'Inter-Species',
#    'weight': 7.9913669999999986}),
#  ('A/black scoter/New Brunswick/00002/2009',
#   'A/mallard/New Brunswick/03396/2009',
#   {'time_delta': datetime.timedelta(99),
#    'trtype': 'Inter-Species',
#    'weight': 7.997867999999999}),
#  ('A/black scoter/New Brunswick/00002/2009',
#   'A/mallard/New Brunswick/03397/2009',
#   {'time_delta': datetime.timedelta(99),
#    'trtype': 'Inter-Species',
#    'weight': 7.997649000000001}),
#  ('A/green winged teal/California/AKS1370/2008',
#   'A/mallard/Alberta/192/2010',
#   {'time_delta': datetime.timedelta(928),
#    'trtype': 'Inter-Species',
#    'weight': 7.710038000000001}),
#  ('A/mallard/Interior Alaska/10BM04626R0/2010',
#   'A/northern pintail/Interior Alaska/10BM07993R0/2010',
#   {'time_delta': datetime.timedelta(16),
#    'trtype': 'Inter-Species',
#    'weight': 7.9917659999999975}),
#  ('A/mallard/Minnesota/Sg-00697/2008',
#   'A/northern pintail/Interior Alaska/9BM7302R0/2009',
#   {'time_delta': datetime.timedelta(371),
#    'trtype': 'Inter-Species',
#    'weight': 7.703372}),
#  ('A/American green-winged teal/Illinois/08OS2713/2008',
#   'A/mallard/Mississippi/407/2010',
#   {'time_delta': datetime.timedelta(447),
#    'trtype': 'Inter-Species',
#    'weight': 7.758407000000001}),
#  ('A/mallard/Illinois/08OS2710/2008',
#   'A/mallard/Mississippi/407/2010',
#   {'time_delta': datetime.timedelta(447),
#    'trtype': 'Intra-Species',
#    'weight': 7.758407000000001}),
#  ('A/American wigeon/Interior Alaska/9BM2501R1/2009',
#   'A/northern pintail/Interior Alaska/9BM6146R0/2009',
#   {'time_delta': datetime.timedelta(22),
#    'trtype': 'Intra-Species',
#    'weight': 7.710667000000001}),
#  ('A/American wigeon/Interior Alaska/9BM2501R1/2009',
#   'A/northern pintail/Interior Alaska/9BM6145R0/2009',
#   {'time_delta': datetime.timedelta(22),
#    'trtype': 'Intra-Species',
#    'weight': 7.710460000000001}),
#  ('A/American wigeon/Interior Alaska/9BM2501R1/2009',
#   'A/northern pintail/Interior Alaska/9BM6144R0/2009',
#   {'time_delta': datetime.timedelta(22),
#    'trtype': 'Intra-Species',
#    'weight': 7.710667000000001}),
#  ('A/northern pintail/Interior Alaska/9BM7620R0/2009',
#   'A/northern pintail/Interior Alaska/9BM9989R0/2009',
#   {'time_delta': datetime.timedelta(7),
#    'trtype': 'Intra-Species',
#    'weight': 7.990027000000001}),
#  ('A/northern pintail/Interior Alaska/9BM6205R0/2009',
#   'A/mallard/Interior Alaska/9BM8287R0/2009',
#   {'time_delta': datetime.timedelta(7),
#    'trtype': 'Inter-Species',
#    'weight': 7.998032000000001}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2568P/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.742997}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2568V/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.743431}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2556V/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.750052}),
#  ('A/northern pintail/Minnesota/AI09-4322/2009',
#   'A/mallard/California/2556P/2011',
#   {'time_delta': datetime.timedelta(699),
#    'trtype': 'Inter-Species',
#    'weight': 7.75092}),
#  ('A/laughing gull/New Jersey/Sg-00485/2008',
#   'A/laughing gull/New Jersey/Sg-00568/2008',
#   {'time_delta': datetime.timedelta(13),
#    'trtype': 'Intra-Species',
#    'weight': 7.989456}),
#  ('A/laughing gull/New Jersey/Sg-00485/2008',
#   'A/laughing gull/New Jersey/Sg-00559/2008',
#   {'time_delta': datetime.timedelta(13),
#    'trtype': 'Intra-Species',
#    'weight': 7.99067}),
#  ('A/American green-winged teal/Interior Alaska/9BM4407R0/2009',
#   'A/northern pintail/Interior Alaska/9BM11358R1/2009',
#   {'time_delta': datetime.timedelta(22),
#    'trtype': 'Inter-Species',
#    'weight': 7.997737000000001}),
#  ('A/mallard/Alberta/496/2008',
#   'A/mallard/Minnesota/AI09-1684/2009',
#   {'time_delta': datetime.timedelta(353),
#    'trtype': 'Inter-Species',
#    'weight': 7.885369}),
#  ('A/mallard/Alberta/496/2008',
#   'A/mallard/Minnesota/AI09-1678/2009',
#   {'time_delta': datetime.timedelta(353),
#    'trtype': 'Inter-Species',
#    'weight': 7.886471000000001}),
#  ('A/American black duck/New Brunswick/03552/2009',
#   'A/blue-winged teal/Missouri/10MO003/2010',
#   {'time_delta': datetime.timedelta(369),
#    'trtype': 'Inter-Species',
#    'weight': 7.675462}),
#  ('A/northern pintail/Interior Alaska/10BM04704R0/2010',
#   'A/mallard/Interior Alaska/10BM09570R0/2010',
#   {'time_delta': datetime.timedelta(20),
#    'trtype': 'Inter-Species',
#    'weight': 7.996863999999999}),
#  ('A/northern pintail/Interior Alaska/10BM04704R0/2010',
#   'A/mallard/Interior Alaska/10BM09562R0/2010',
#   {'time_delta': datetime.timedelta(20),
#    'trtype': 'Inter-Species',
#    'weight': 7.997329}),
#  ('A/mallard/Nova Scotia/00346/2010',
#   'A/blue-winged teal/Nova Scotia/00126/2010',
#   {'time_delta': datetime.timedelta(33),
#    'trtype': 'Intra-Species',
#    'weight': 7.999567999999999}),
#  ('A/mallard/New Brunswick/00349/2010',
#   'A/blue-winged teal/Nova Scotia/00126/2010',
#   {'time_delta': datetime.timedelta(33),
#    'trtype': 'Intra-Species',
#    'weight': 7.999567999999999}),
#  ('A/mallard/Nova Scotia/00346/2010',
#   'A/American black duck/Nova Scotia/00089/2010',
#   {'time_delta': datetime.timedelta(33),
#    'trtype': 'Intra-Species',
#    'weight': 7.999567999999999}),
#  ('A/mallard/New Brunswick/00349/2010',
#   'A/American black duck/Nova Scotia/00089/2010',
#   {'time_delta': datetime.timedelta(33),
#    'trtype': 'Intra-Species',
#    'weight': 7.999567999999999}),
#  ('A/blue-winged Teal/North Dakota/AI09-3881/2009',
#   'A/northern pintail/Wisconsin/11OS3416/2011',
#   {'time_delta': datetime.timedelta(762),
#    'trtype': 'Inter-Species',
#    'weight': 7.7905609999999985}),
#  ('A/blue-winged Teal/North Dakota/AI09-3881/2009',
#   'A/gadwall/Wisconsin/11OS3415/2011',
#   {'time_delta': datetime.timedelta(762),
#    'trtype': 'Inter-Species',
#    'weight': 7.7905609999999985}),
#  ('A/northern shoveler/Interior Alaska/10BM02593R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08899R0/2010',
#   {'time_delta': datetime.timedelta(43),
#    'trtype': 'Intra-Species',
#    'weight': 7.976656}),
#  ('A/northern shoveler/Interior Alaska/10BM02593R0/2010',
#   'A/northern pintail/Interior Alaska/10BM08903R0/2010',
#   {'time_delta': datetime.timedelta(43),
#    'trtype': 'Intra-Species',
#    'weight': 7.976656})]

# %%
edges_to_add_list = []
for edge in edges_to_add:
    edge_dict = dict()
    edge_dict['source'] = edge[0]
    edge_dict['sink'] = edge[1]
    edge_dict['weight'] = edge[2]['weight']
    edge_dict['time_delta'] = edge[2]['time_delta']
    edges_to_add_list.append(edge_dict)
    
pd.DataFrame(edges_to_add_list).to_csv('3.10 - Edges to Add.csv')

# %%
# With the new edges added in, it is now 1571 edges.
# 22 September 2014: Update - with 2011 isolates removed, it is 1568
# 23 September 2014: With 2008-2011 included, it is 2223
len(G.edges(data=True))
# Out:
# 2214

# %%
# After adding in more edges, the number of subgraphs becomes 474
# 22 September 2014: Update - with 2011 isolates removed, it is 460.
# 23 September 2014: Update - with 2008-2011 included, it is 686.
subgraphs = list(nx.connected_component_subgraphs(G.to_undirected()))
print(len(subgraphs))
# Out:
# 652

# %%
# Classify the edges.
from datetime import timedelta
for edge in G.edges(data=True):
    if edge[2]['time_delta'] > timedelta(15):
        edge[2]['tr_timeclass'] = "Environmental Persistence"
    if edge[2]['time_delta'] <= timedelta(15):
        edge[2]['tr_timeclass'] = "Direct Transmission"

# %%
# Check to ensure that the time classes are added in correctly.
G.edges(data=True)[9]
# Out:
# ('A/blue-winged teal/Wisconsin/2713/2009',
#  'A/blue-winged teal/Wisconsin/2665/2009',
#  {'time_delta': datetime.timedelta(0),
#   'tr_timeclass': 'Direct Transmission',
#   'trtype': 'Intra-Species',
#   'weight': 7.9932539999999985})

# %%
[edge for edge in G.edges() if 'A/mallard/California/2535P/2011' in edge]
# Out:
# [('A/mallard/California/2536P/2011', 'A/mallard/California/2535P/2011'),
#  ('A/mallard/California/2535P/2011', 'A/mallard/California/2535V/2011')]

# %%
# This is a custom function for serializing dates such that it is JSON compatible. 
# It gets used right at the last step prior to the JSON dump.
from dateutil.tz import tzutc

UTC = tzutc()

def serialize_date(dt):
    """
    Serialize a date/time value into an ISO8601 text representation
    adjusted (if needed) to UTC timezone.

    For instance:
    >>> serialize_date(datetime(2012, 4, 10, 22, 38, 20, 604391))
    '2012-04-10T22:38:20.604391Z'
    """
    #if dt.tzinfo:
    #    dt = dt.astimezone(UTC)
    return dt.isoformat()

# %%
# We do not want to consider any edges in which none of the isolates are connected to an isolate in 2009 or 2010.
# Therefore, grab out every subgraph, and if none of the isolates in the subgraph are connected to a 2009 or 2010
# isolate, then remove all nodes in that subgraph from the large graph G.

subgraphs = list(nx.connected_component_subgraphs(G.to_undirected()))

G_twoyears = G.copy()

for graph in subgraphs:
    # grab all the nodes from each subgraph
    nodes = graph.nodes(data=True)
    node_names = [node[0] for node in nodes]
    
    # grab all years from the subgraph
    dates = [node[1]['isolation_date'] for node in nodes]
    years = [date.year for date in dates]
    
    if 2009 not in years and 2010 not in years:
#         undirected_G.remove_nodes_from(node_names)
        G_twoyears.remove_nodes_from(node_names)
        print(years)
# Out:
# [2008]
# [2011, 2011, 2011, 2011, 2011, 2011, 2011]
# [2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008]
# [2008, 2008]
# [2008, 2011, 2008]
# [2011, 2011]
# [2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008]
# [2008, 2008]
# [2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008]
# [2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008]
# [2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008]
# [2008]
# [2008]
# [2008, 2008]
# [2011, 2011, 2011, 2011, 2011]
# [2011]
# [2008, 2008, 2008, 2008]
# [2008, 2008]
# [2011]
# [2011, 2011]
# [2008]
# [2008]
# [2008]
# [2008, 2008]
# [2008]
# [2008, 2008, 2008]
# [2008]
# [2011]
# [2011, 2011]
# [2011, 2008, 2008, 2008, 2008, 2008, 2008, 2011, 2011, 2011, 2008, 2011, 2008]
# [2011, 2011, 2011]
# [2011, 2011, 2011, 2011]
# [2008]
# [2008, 2008, 2008, 2008]
# [2011]
# [2008]
# [2008, 2008, 2008, 2008]
# [2008]
# [2011, 2011, 2011]
# [2008]
# [2008, 2008, 2008, 2008, 2008]
# [2008, 2008]
# [2011]
# [2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2
# ['A/mallard/Illinois/08OS2315/2008', 'A/northern pintail/Interior Alaska/10BM02585R0/2010', 'A/blue-winged teal/Missouri/10MO030/2010', 'A/mallard/Interior Alaska/10CH00021R0/2010', 'A/American black duck/New Brunswick/00949/2010', 'A/mallard/California/6772/2008', 'A/mallard/Ohio/1695/2009', 'A/blue-winged teal/North Dakota/Sg-00706/2008', 'A/mallard/Wisconsin/2653/2009', 'A/mallard/New Brunswick/00854/2010', 'A/blue-winged teal/Wisconsin/11OS2657/2011']
# ['A/American green-winged teal/Illinois/10OS1551/2010', 'A/ruddy turnstone/New Jersey/Sg-00552/2008', 'A/northern shoveler/Illinois/11OS4707/2011', 'A/blue-winged Teal/Minnesota/AI09-2389/2009', 'A/mallard/California/1523/2010']

# %%
len(list(nx.connected_component_subgraphs(G.to_undirected())))
# Out:
# 652

# %%
# Dump the graph as a JSON node-link file.
# Prior to doing this, serialize all of the node dates to be JSON serializable.
G_serialized = G.copy()

for node in G_serialized.nodes(data=True):
    node[1]['isolation_date'] = serialize_date(node[1]['isolation_date'])

for edge in G_serialized.edges(data=True):
    edge[2]['time_delta'] = edge[2]['time_delta'].days
d = json_graph.node_link_data(G_serialized) # node-link format to serialize
json.dump(d, open('viz/force2.json','w'))

# %%
[edge for edge in G.edges() if 'A/mallard/California/2535P/2011' in edge]
# Out:
# [('A/mallard/California/2536P/2011', 'A/mallard/California/2535P/2011'),
#  ('A/mallard/California/2535P/2011', 'A/mallard/California/2535V/2011')]

# %%
# Write CSV file of the Directed Graph

df_edges = pd.DataFrame()

for edge in G.edges(data=True):
    df_edge = pd.Series()
    df_edge['Source'] = edge[0]
    df_edge['Sink'] = edge[1]
    df_edge['Transmission Type'] = edge[2]['trtype']        
    df_edge['Time Delta'] = edge[2]['time_delta']
    df_edge['Weight'] = edge[2]['weight']
    df_edge['Time Class'] = edge[2]['tr_timeclass']
   
    df_edges = df_edges.append(df_edge, ignore_index=True)
    
df_edges.to_csv('3.10 - Full Transmission as CSV/Full Transmission Edges.csv')

# %%
df_nodes = pd.DataFrame()

for node in G.nodes(data=True):
    node_series = pd.Series()
#     print node
    node_series['Isolate Name'] = node[0]
#     node_series['Country'] = node[1]['country']
    node_series['State'] = node[1]['state']
    node_series['Subtype'] = node[1]['subtype']
    node_series['Host'] = node[1]['host']
    node_series['Isolation Date'] = node[1]['isolation_date']
    
    df_nodes = df_nodes.append(node_series, ignore_index=True)
    
df_nodes['Isolation Date'] = df_nodes['Isolation Date'].astype('datetime64[ns]')
df_nodes

# %%
# Check to see how many nodes belong to Minto Flats (i.e. state = Interior Alaska)
# 22 September 2014: Update - with 2011 isolates removed, this should not change 
len(df_nodes[df_nodes['State'] == 'Interior Alaska'])

# %%
# Write the Nodes to a CSV file.
df_nodes.to_csv('3.10 - Full Transmission as CSV/Full Transmissions Nodes.csv')

# %%
# Modify the Nodes column names to fit with the source-sink paradigm.
df_nodes.columns = map(lambda x: x + '1', df_nodes.columns)
print(df_nodes.columns)

df_full = df_edges.set_index('Source').join(df_nodes.set_index('Isolate Name1'))
df_nodes.columns = map(lambda x: x.replace('1', '2'), df_nodes.columns)
print(df_nodes.columns)

df_full = df_full.reset_index()
print(df_full.columns)

df_full.columns = ['Source' if item == 'index' else item for item in list(df_full.columns)]
print(df_full.columns)

df_full = df_full.set_index('Sink').join(df_nodes.set_index('Isolate Name2'))
df_full = df_full.reset_index()
df_full.columns = ['Sink' if item == 'index' else item for item in list(df_full.columns)]
df_full.columns

df_full.to_csv('3.10 - Full Transmission as CSV/Full Transmissions.csv')

# %%
# Inspect the data.
df_full

# %%
df_full['Isolation Date1'] = df_full['Isolation Date1'].astype('datetime64[ns]')
df_full['Isolation Date2'] = df_full['Isolation Date2'].astype('datetime64[ns]')
df_full

# %%
source_2009 = df_full[(df_full['State1'] != df_full['State2']) & \
                      (df_full['Isolation Date1'] < datetime(2010, 1, 1))]
source_2009.to_csv('3.10 - Full Transmission as CSV/20140820 Source 2009.csv')

source_2010 = df_full[(df_full['State1'] != df_full['State2']) & \
                      (df_full['Isolation Date1'] >= datetime(2010, 1, 1))]
source_2010.to_csv('3.10 - Full Transmission as CSV/20140820 Source 2010.csv')

# %%
# Query the network
# df_full[(df_full['State1'] == 'Interior Alaska') & (df_full['State1'] != df_full['State2'])]
# df_full[(df_full['State1'] == 'Alberta') | (df_full['State2'] == 'Alberta')]
# df_full[(df_full['State1'] != df_full['State2']) & (df_full['Time Delta'] > 15)]['Time Delta'].hist()
df_full[(df_full['State1'] == df_full['State2']) & (df_full['Time Delta'] <= 15)]['Weight'].hist()
# df_full[df_full['State1'] != df_full['State2']].sort("Weight", ascending=False)['Weight'].hist()
# df_full[df_full['Weight'] >= 7.99]['Time Delta'].hist() # These are frozen passengers
# df_full[df_full['Time Delta'] > 300]['Weight'].hist()
# df_full[df_full['Subtype1'] != df_full['Subtype2']]
# df_full[df_full['Source'].str.contains("A/American black duck/New Brunswick/00476/2010")]

# %%
df_nodes[df_nodes['State2'] == 'Indiana']

# %%
# Create an undirected version of the transmission graph.
undirected_G = G.to_undirected()

# Make sure that the time deltas are all positive values.
for edge in undirected_G.edges(data=True):
    if edge[2]['time_delta'] < timedelta(0):
        edge[2]['time_delta'] = abs(edge[2]['time_delta'])

# %%
# Check the undiredcted_G edges:
undirected_G.nodes(data=True)

# %%
undir_nodes = pd.DataFrame()

for node in undirected_G.nodes(data=True):
    node_series = pd.Series()
    node_series['Isolate Name'] = node[0]
    node_series['State'] = node[1]['state']
    node_series['Subtype'] = node[1]['subtype']
    node_series['Host'] = node[1]['host']
    node_series['Isolation Date'] = node[1]['isolation_date']
    
    undir_nodes = undir_nodes.append(node_series, ignore_index=True)
    
undir_nodes['Isolation Date'] = undir_nodes['Isolation Date'].astype('datetime64[ns]')
undir_nodes.to_csv('3.10 - Full Transmission as CSV/Undirected Transmission Nodes.csv')

# %%
# Write CSV file of the undirected graph

undir_edges = pd.DataFrame()

for edge in undirected_G.edges(data=True):
    df_edge = pd.Series()
    df_edge['Isolate1'] = edge[0]
    df_edge['Isolate2'] = edge[1]
    df_edge['Transmission Type'] = edge[2]['trtype']        
    df_edge['Time Delta'] = edge[2]['time_delta']
    df_edge['Weight'] = edge[2]['weight']
    df_edge['Time Class'] = edge[2]['tr_timeclass']
   
    undir_edges = undir_edges.append(df_edge, ignore_index=True)
    
undir_edges.to_csv('3.10 - Full Transmission as CSV/Undirected Full Transmission Edges.csv')

# %%
# Modify the Nodes column names to fit with the undirected isolate1-isolate2 paradigm.
undir_nodes.columns = map(lambda x: x + '1', undir_nodes.columns)
print(undir_nodes.columns)

undir_graph = undir_edges.set_index('Isolate1').join(undir_nodes.set_index('Isolate Name1'))
undir_nodes.columns = map(lambda x: x.replace('1', '2'), undir_nodes.columns)
print(undir_nodes.columns)

undir_graph = undir_graph.reset_index()
print(undir_graph.columns)

undir_graph.columns = ['Isolate1' if item == 'index' else item for item in list(undir_graph.columns)]
print(undir_graph.columns)

undir_graph = undir_graph.set_index('Isolate2').join(undir_nodes.set_index('Isolate Name2'))
undir_graph = undir_graph.reset_index()
undir_graph.columns = ['Isolate2' if item == 'index' else item for item in list(undir_graph.columns)]
undir_graph.columns

undir_graph.to_csv('3.10 - Full Transmission as CSV/Undirected Full Transmissions.csv')

# %%
undir_graph[undir_graph['Time Delta'] < 2]

# %%
# Undirected version should have only 1213 edges.
# 22 September 2014: Update - with 2011 isolates removed, there are only 1210. This is consistent with Nichola removing 
# 3 edges as a result of 2011 isolates being present.
# 23 September 2014: Expanded 2008-2011 dataset has 1704 edges.
len(undirected_G.edges())

# %%
# Open up the lat/long values
lat_long_vals = pd.read_csv('lat_long.csv')
lat_long_vals

# %%
# Do a bunch of checks on the graph:

# 1. There should be no isolation dates < 1 Jan 2008
# df_full[df_full['Isolation Date1'] < datetime(2008, 1, 1)]
# df_full[df_full['Isolation Date2'] < datetime(2008, 1, 1)]

# 2. There should be no isolation dates > 31 Dec 2011
# df_full[df_full['Isolation Date1'] > datetime(2012, 12, 31)]
# df_full[df_full['Isolation Date2'] > datetime(2012, 12, 31)]

# 3. Time deltas should be no smaller than -6.
# df_full[df_full['Time Delta'] < -6]

# 4. Number of rows present in df_full should equal the number of edges in the directed graph.
# len(G.edges()) == len(df_full)

# 5. Number of rows present in undir_graph should equal the number of edges in G.to_undirected()
# len(G.to_undirected().edges()) == len(undir_graph)

# 6. Number of Interior Alaska isolates present should be equal.
# len(undir_nodes[undir_nodes['State2'] == 'Interior Alaska']) == len([node for node in G.nodes(data=True) if node[1]['state'] == 'Interior Alaska'])

# 7. Identify the number of Brandt's 2009 and 2010 isolates that finally made it into the network.
brandt_data = pd.read_csv('Raw Data/20140206 Minto Flats 520 with Accessions.csv', index_col='Sample ID', parse_dates=['Date'])
brandt_isolates = set(brandt_data['Common Name'].str.split('(').str[0].values) #set of isolate names
brandt_lowquality = set(brandt_data[brandt_data['Sequence Accession'].str.contains("\*")]['Common Name'].str.split("(").str[0].values)
graph_isolates = set([node[0] for node in G.nodes(data=True) if node[0].split('/')[2] == 'Interior Alaska'])

# The number of 2009 and 2010 isoaltes that made it into the network is 504:
len(graph_isolates.intersection(brandt_isolates))

# This is out of a total of 516 isolates.

### The following isolates have been removed due to low quality in segment 1, and number 12 isolates.
print((brandt_isolates - graph_isolates).intersection(brandt_lowquality) == brandt_lowquality)
print(len((brandt_isolates - graph_isolates).intersection(brandt_lowquality)))

# %%
# Create a graph based on geography

geonet = nx.DiGraph()

year = df_full

# Add in the nodes 

geographic_locations = np.unique(year[['State1', 'State2']].values)
print(geographic_locations)

for place in geographic_locations:
    geonet.add_node(place)

# Add in the edges with initial weights 0

for row in year.iterrows():
    geonet.add_edge(row[1]['State1'], row[1]['State2'], weight=0, num_connections=0)

# Add in the weights

for row in year.iterrows():
    if geonet.has_edge(row[1]['State1'], row[1]['State2']):
        geonet[row[1]['State1']][row[1]['State2']]['weight'] += row[1]['Weight']
        geonet[row[1]['State1']][row[1]['State2']]['num_connections'] += 1
        
# Add in lat-long data for each state
for row in lat_long_vals.iterrows():
    if row[1]['State'] in geonet.nodes():
        geonet.node[row[1]['State']]['N'] = row[1]['N']
        geonet.node[row[1]['State']]['W'] = row[1]['W']
        
# Check to make sure that every geonet node has an 'n' and 'w' value:
for node, data in geonet.nodes(data=True):
    print node, data

fig = plt.figure(figsize=(12,12))
nx.draw_networkx(geonet)

d = json_graph.node_link_data(geonet) # node-link format to serialize
json.dump(d, open('viz/geonet.json','w'))

# %%
# We want to know if sampling effort, as measured by no. of molecular sequences obtained, is related to the 
# strength of connectivity to AK.

# Let's query the graph by asking if the number of sequences present in AK-connected sites is related
# to the weight between AK and that site.

ak_connected_edges = []
for edge in geonet.edges(data=True):
    if 'Interior Alaska' in edge[0] or 'Interior Alaska' in edge[1]:
        ak_connected_edges.append(edge)
        
# Now, let's grab out the non-IAK site names and pair them with the weights, then cast it as a dataframe.

# site_weight = dict()
# for edge in ak_connected_edges:
#     if edge[0] != 'Interior Alaska':
#         site_weight[edge[0]] = edge[2]['weight']
#     if edge[1] != 'Interior Alaska':
#         site_weight[edge[1]] = edge[2]['weight']

# Just as a backup, do it with all possible edges.
site_weight = dict()
for edge in geonet.edges(data=True):
    site_weight[edge[0]] = 0
    site_weight[edge[1]] = 0
    
for edge in geonet.edges(data=True):
    if edge[0] != edge[1]:
        site_weight[edge[0]] += edge[2]['weight']
        site_weight[edge[1]] += edge[2]['weight']
    
# Create a dataframe with the state name and weight
site_weight_df = pd.DataFrame(zip(site_weight.keys(), site_weight.values()))
site_weight_df.columns = ['site', 'weight']
site_weight_df.set_index('site', inplace=True)
site_weight_df['weight'] = site_weight_df['weight'].apply(lambda x: math.ceil(x/8))

# Let's open up the old datafile that contains all the info and grab out # of sequences from those sites.
raw_data = pd.read_csv('3.10 - Full Transmission as CSV/Undirected Transmission Nodes.csv', index_col=0)
raw_data.replace("SK", "Saskatchewan", inplace=True)
raw_counted = raw_data.groupby('State').count()
raw_counted

# Do a join to bring in the counts into site_weight_df

joined = site_weight_df.join(raw_counted, how='outer')
# joined
joined['counts'] = joined['Isolation Date']
del joined['Isolation Date']

plt.scatter(joined['counts'], joined['weight'])
plt.ylabel('Number of Connections \n Into or Out of Location')
plt.xlabel('Number of Sequences at Location')
plt.title("Sampling Effort vs. Intergeographic Connectivity")
# plt.xlim([0, 250])
plt.savefig('Sampling Effort vs. Intergeographic Connectivity.pdf')

joined.to_csv('Sampling Effort vs. Intergeographic Connectivity.csv')

# %%
# Calculate probability of getting n cross-population edges by random, where n <= num_cross_pop_edges
# This effectively constitutes our statistical test of significance. 
def prob_cross_pop(a_pop, b_pop, n):
    """
    a_pop = size of population A
    b_pop = size of population B
    n = number of cross population edges
    """
    if n == 0 or n > a_pop * b_pop:
        return 0
    else:
        total_edges = np.sum([i for i in range(sum([a_pop, b_pop]))])
        total_cross_pop = a_pop * b_pop

        total_probability = 1
        for i in range(n):
            total_probability = total_probability * ((total_cross_pop - i) / (total_edges - i))

        return total_probability

# %%
# Let's calculate the probability of connectivity by chance.

# Firstly, update geonet's nodes with the number of isolates:
for node in geonet.nodes(data=True):
    node[1]['sample_size'] = int(joined.ix[node[0]]['counts'])
    
# Next, we calculate the probability of having that number of cross-population edges for every edge in geonet.
for edge in geonet.edges(data=True):
    if edge[0] == edge[1]:
        edge[2]['cross_population_likelihood'] = 0
    if edge[0] != edge[1]:
        a_pop = geonet.node[edge[0]]['sample_size']
        b_pop = geonet.node[edge[1]]['sample_size']
        n = edge[2]['num_connections']
        
        edge[2]['cross_population_likelihood'] = prob_cross_pop(a_pop, b_pop, n)
        
geonet.edges(data=True)

# %%
# Create a pandas DataFrame with the geographic sites, number of connections, total weight, and likelihood.
geonet_likelihood_df = pd.DataFrame()
for edge in geonet.edges(data=True):
    row = pd.Series()
    
    row['Site 1'] = edge[0]
    row['Site 2'] = edge[1]
    
    row['Sum of Weights'] = edge[2]['weight']
    row['Number of Connections'] = edge[2]['num_connections']
    row['Probability Value'] = edge[2]['cross_population_likelihood']
    
    geonet_likelihood_df = geonet_likelihood_df.append(row, ignore_index=True)
    
geonet_likelihood_df.to_csv('3.10 - Full Transmission as CSV/Geonet Likelihood.csv')

# %%
# Let's create a filtered version of geonet, in which the likelihood of cross-population edges by random chance is 
# less than 0.05
alpha_value = 0.05

geonet_filtered = geonet.copy()
for edge in geonet_filtered.edges(data=True):
    if edge[2]['cross_population_likelihood'] > alpha_value:
#         print(edge)
        geonet_filtered.remove_edge(edge[0], edge[1])
        
# geonet_filtered.edges(data=True)
nx.draw_networkx(geonet_filtered)
d = json_graph.node_link_data(geonet_filtered) # node-link format to serialize
json.dump(d, open('viz/geonet_filtered.json','w'))

# %%
#HELLO
print("Hello")
