# %%
import networkx as nx
import numpy as np
import pandas as pd
from networkx.readwrite import json_graph
import json
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

from datetime import timedelta, datetime
from copy import deepcopy

# %%
# Load the data
data = pd.read_csv('3.0 - Transmissions/Minto Plus North America All Transmissions.csv', index_col=0, parse_dates=['Collection Date1', 'Collection Date2'])
data['Collection Date1'] = pd.to_datetime(data['Collection Date1'])
data['Collection Date2'] = pd.to_datetime(data['Collection Date2'])
data['Time Delta'] = data['Collection Date2'] - data['Collection Date1']
data['Time Delta'] = data['Time Delta'].astype('timedelta64[D]')
# 22 September 2014: Nichola found edges for which nodes were isolates from the year 2011. I attribute this to an error
# in the IRD when downloading the data; based on the search criteria of 2009-2010 isolates, it's impossible for us to have
# downloaded these isolates unless the IRD parsed their dates incorrectly. Lesson learned, will not make this assumption
# in the future, and will check for this.
data = data[(data['Collection Date1'] < datetime(2011, 1, 1)) & (data['Collection Date2'] < datetime(2011, 1, 1))]
len(data)
# Out:
# 1365392

# %%
# There should be 1186 isolates.
# 22 September 2014: After filtering out isolates from 2011, there are only 1169 isolates, consistent with what I had
# counted when doing data removal earlier on.
len(data.groupby('Isolate1'))
# Out:
# 1169

# %%
# Initialize the graph that will be used to store the transmission network
G = nx.DiGraph()

# Initialize a graph that will hold all of the discarded edges from G. This is used to
# add back edges that are sources for isolates that may have been implicated in bi-directional
# reconstructions as a result of the "-6 to +15" rule.
G_discarded = nx.DiGraph()

# %%
# Add nodes into the graph, along with metadata.
for group in data.groupby(['Isolate1', 'Collection Date1', 'Subtype1', 'Host Species1','State/Province1']):
#     dsplit = str(group[0][1]).split(' ')[0].split('-')
#     isolate_date = serialize_date(datetime(int(dsplit[0]), int(dsplit[1]), int(dsplit[2])))
    G.add_node(group[0][0],
               isolation_date=group[0][1],
               subtype=group[0][2],
               host=group[0][3],
               state=group[0][4])

# %%
# Inspect the first node to make sure the data were entered correctly.
G.nodes(data=True)[0]
# Out:
# ('A/mallard/Interior Alaska/10BM09164R0/2010',
#  {'isolation_date': Timestamp('2010-08-06 00:00:00'),
#   'subtype': 'H3N8',
#   'host': 'IRD:Mallard/Avian',
#   'state': 'Interior Alaska'})

# %%
# There should be the same number of nodes as in the cell with len(data.groupby("Isolate1")).
len(G.nodes())
# Out:
# 1169

# %%
# There should be no edges right now.
G.edges(data=True)
# Out:
# []

# %%
# Add in edges to the graph, and classify them as intra-species or inter-species.
for row in data[data['PWI'] > 7.0].iterrows():
    # 12 September 2014: I just noticed here that 
    #     if Time Delta >= -7 
    # should have been:
    #     if Time Delta >= -6.
    # Made the change here.
    if row[1]['Time Delta'] >= -6:
        if row[1]['Host Species1'] == row[1]['Host Species2']:
            G.add_edge(row[1]['Isolate1'], 
                       row[1]['Isolate2'], 
                       time_delta=row[1]['Time Delta'], 
                       weight=row[1]['PWI'], 
                       trtype='Intra-Species')
        if row[1]['Host Species1'] != row[1]['Host Species2']:
            G.add_edge(row[1]['Isolate1'], 
                       row[1]['Isolate2'], 
                       time_delta=row[1]['Time Delta'], 
                       weight=row[1]['PWI'], 
                       trtype='Inter-Species')

# %%
# Inspect the first edge in the graph, to make sure the data are added in correctly.
G.edges(data=True)[2]
# Out:
# ('A/mallard/Interior Alaska/10BM09164R0/2010',
#  'A/northern pintail/Interior Alaska/10BM09101R0/2010',
#  {'weight': 7.999425, 'trtype': 'Inter-Species', 'time_delta': -1.0})

# %%
# With Time Delta >= -7, there should be 13414 edges.
# With Time Delta >= -6, there should be 13092 edges. 
# 12 September 2014: The latter should be correct.
# 22 September 2014: With 2011 isolates filtered out, now there are only 13083 edges.
print(len(G.edges()))
# Out:
# 13083

# %%
# Prune away any edges not equal to max_weight.
# Add those discarded edges to a separate graph that has 

for node in G.nodes(data=True):
    G_discarded.add_node(node[0], attr_dict=node[1])
    edges = G.in_edges(node[0], data=True)
    if len(edges) > 0:
        max_weight = max([edge[2]['weight'] for edge in edges])
        for edge in edges:
            if edge[2]['weight'] < max_weight:
                G.remove_edge(edge[0], edge[1])
                G_discarded.add_edge(edge[0], edge[1], attr_dict=edge[2])

# %%
# Inspect one of the discarded edges
G_discarded.edges(data=True)[0]
# Out:
# ('A/mallard/Interior Alaska/10BM09164R0/2010',
#  'A/northern pintail/Interior Alaska/10BM09105R0/2010',
#  {'weight': 7.9968059999999985, 'trtype': 'Inter-Species', 'time_delta': -1.0})

# %%
# Check to see how many discarded edges are present
len(G_discarded.edges())
# Out:
# 11706

# %%
# Check to see that the number of discarded edges and the number of retained edges = original # of edges (i.e. 13083)
len(G_discarded.edges()) + len(G.edges())
# Out:
# 13083

# %%
# This cell is used for querying the data, to make sure that the edges are correct.
G.in_edges('A/ruddy turnstone/New Jersey/AI09-775/2009', data=True)
# G.edges(['A/American green-winged teal/Interior Alaska/10BM04207R0/2010'], data=True)
# Out:
# [('A/ruddy turnstone/New Jersey/AI09-841/2009',
#   'A/ruddy turnstone/New Jersey/AI09-775/2009',
#   {'weight': 7.995798, 'trtype': 'Intra-Species', 'time_delta': 7.0})]

# %%
# Identify the potential reassortants in the graph. 
# These guys are the ones without any in_edges going into them.
reassortants = []
for node in G.nodes():
    if len(G.in_edges(node)) == 0:
        reassortants.append(node)
pd.Series(reassortants).to_csv('Reassortants by Network Analysis.csv')

# %%
# There should be 1377 edges.
print(len(G.edges()))
# Out:
# 1377

# %%
# Check to ensure that the metadata for each node are added in correctly.
G.nodes(data=True)[15]
# Out:
# ('A/northern shoveler/California/6535/2009',
#  {'isolation_date': Timestamp('2009-10-24 00:00:00'),
#   'subtype': 'H9N2',
#   'host': 'IRD:Northern Shoveler/Avian',
#   'state': 'California'})

# %%
# Custom function to convert serialized datetime back into date object for comparison

def to_datetime(datestring):
    from datetime import date
    """
    e.g. '2010-08-12T00:00:00' --> date(2010, 08, 12)
    """
    
    y = int(datestring.split('-')[0])
    m = int(datestring.split('-')[1])
    d = int(datestring.split('-')[2].split('T')[0])
    
    return date(y,m,d)

to_datetime('2010-08-12T00:00:00')
# Out:
# datetime.date(2010, 8, 12)

# %%
# Sandbox cell: Check to see if we can do a "min" operation on date objects.

from datetime import date

datelist = [date(2010, 8, 12), 
            date(2010, 8, 7),
            date(2010, 7, 3)]

min(datelist)
# Out:
# datetime.date(2010, 7, 3)

# %%
# 12 September 2014:
# A modification that we would like to do is as follows:
# - Find the earliest isolate in each subgraph.
# - Find the source for each of these earliest isolates in each subgraph.

# Here, I write custom functions to get that done.


# Function for finding earliest isolate in each subgraph:
def find_earliest_nodes(subgraph):
    """
    Returns one isolate that has a date equal to the earliest date amongst all of the 
    isolates in the subgraph.
    
    NOTE: If there are multiple isolates that fulfill the criteria, all of them are considered.
    """
    
    nodes = subgraph.nodes(data=True)
    
    dates = [node[1]['isolation_date'] for node in nodes]
    
    min_date = min(dates)
    
    earliest_nodes = []
   
    for node in nodes:
        if node[1]['isolation_date'] == min_date:
            earliest_nodes.append(node)
            
    return earliest_nodes
            
# Function for adding back the edge for a given earliest_node.
def find_source_node(node, discarded_edges_graph):
    """
    Basic idea of logic:
    1. In discarded_edges_graph, identify in_edges if source node's isolation_date < sink node's isolation_date 
       by more than 6 days.
    2. Identify edge(s) of max weight.
    3. Add it to a list of edges to be added back into the graph.
    
    NOTES:
    - node has to have have metadata provided as well. Otherwise, the code doesn't work. 
    """
    in_edges = [edge for edge in discarded_edges_graph.in_edges(node[0], data=True) if edge[2]['time_delta'] > 6]
    edges_to_add = []
    if len(in_edges) > 0:
        for edge in in_edges:
            source = edge[0]
            sink = edge[1]
            data = edge[2]
            maxweight = max([edge[2]['weight'] for edge in in_edges]) 
            if edge[2]['weight'] == maxweight:
                edges_to_add.append((source, sink, data))
                
    return edges_to_add

# %%
# Find all subgraphs of G, and then add in edges that explain the earliest isolate of each subgraph.
# Prior to adding them back in, there should be 539 subgraphs.
# 22 September 2014: Update - after removal of 2011 isolates, there should only be 525.

subgraphs = list(nx.connected_component_subgraphs(G.to_undirected()))
print(len(subgraphs))

# for subgraph in subgraphs:
#     if len(subgraph.nodes()) == 1:
#         print(subgraph.nodes())

edges_to_add = []

for i in range(len(subgraphs)):
    earliest_nodes = find_earliest_nodes(subgraphs[i])
    
    for earliest_node in earliest_nodes:
    
        new_edges = find_source_node(earliest_node, G_discarded)    
        if len(new_edges) > 0:
            edges_to_add.extend(new_edges)
print(edges_to_add)
G.add_edges_from(edges_to_add)
# Out:
# 525
# [('A/mallard/Interior Alaska/10BM05347R0/2010', 'A/northern pintail/Interior Alaska/10BM10853R0/2010', {'weight': 7.9966279999999985, 'trtype': 'Inter-Species', 'time_delta': 16.0}), ('A/mallard/Interior Alaska/10BM05860R0/2010', 'A/northern pintail/Interior Alaska/10BM10853R0/2010', {'weight': 7.9966279999999985, 'trtype': 'Inter-Species', 'time_delta': 15.0}), ('A/mallard/Interior Alaska/10BM05347R0/2010', 'A/mallard/Interior Alaska/10BM10829R0/2010', {'weight': 7.9966279999999985, 'trtype': 'Intra-Species', 'time_delta': 16.0}), ('A/mallard/Interior Alaska/10BM05860R0/2010', 'A/mallard/Interior Alaska/10BM10829R0/2010', {'weight': 7.9966279999999985, 'trtype': 'Intra-Species', 'time_delta': 15.0}), ('A/mallard/Interior Alaska/10BM05347R0/2010', 'A/northern pintail/Interior Alaska/10BM10790R0/2010', {'weight': 7.995471999999999, 'trtype': 'Inter-Species', 'time_delta': 16.0}), ('A/mallard/Interior Alaska/10BM05860R0/2010', 'A/northern pintail/Interior Alaska/10BM10790R0/2010', {'weight': 7.995471999999999, 'trtype': 'Inter-Species', 'time_delta': 15.0}), ('A/mallard/Interior Alaska/10BM05347R0/2010', 'A/mallard/Interior Alaska/10BM10859R0/2010', {'weight': 7.9966279999999985, 'trtype': 'Intra-Species', 'time_delta': 16.0}), ('A/mallard/Interior Alaska/10BM05860R0/2010', 'A/mallard/Interior Alaska/10BM10859R0/2010', {'weight': 7.9966279999999985, 'trtype': 'Intra-Species', 'time_delta': 15.0}), ('A/mallard/Interior Alaska/10BM05347R0/2010', 'A/mallard/Interior Alaska/10BM10876R0/2010', {'weight': 7.9966279999999985, 'trtype': 'Intra-Species', 'time_delta': 16.0}), ('A/mallard/Interior Alaska/10BM05860R0/2010', 'A/mallard/Interior Alaska/10BM10876R0/2010', {'weight': 7.9966279999999985, 'trtype': 'Intra-Species', 'time_delta': 15.0}), ('A/northern pintail/Interior Alaska/10BM08488R0/2010', 'A/mallard/Interior Alaska/10BM12363R0/2010', {'weight': 7.9975429999999985, 'trtype': 'Inter-Species', 'time_delta': 10.0}), ('A/northern pintail/Interior Alaska/10BM08489R0/2010', 'A/mallard/Interior Alaska/10BM12363R0/2010', {'weight': 7.9975429999999985, 'trtype': 'Inter-Species', 'time_delta': 10.0}), ('A/northern pintail/Interior Alaska/10BM08488R0/2010', 'A/mallard/Interior Alaska/10BM12370R0/2010', {'weight': 7.997547999999999, 'trtype': 'Inter-Species', 'time_delta': 10.0}), ('A/northern pintail/Interior Alaska/10BM08489R0/2010', 'A/mallard/Interior Alaska/10BM12370R0/2010', {'weight': 7.997547999999999, 'trtype': 'Inter-Species', 'time_delta': 10.0}), ('A/northern pintail/Interior Alaska/10BM08488R0/2010', 'A/mallard/Interior Alaska/10BM12374R0/2010', {'weight': 7.997547999999999, 'trtype': 'Inter-Species', 'time_delta': 10.0}), ('A/northern pintail/Interior Alaska/10BM08489R0/2010', 'A/mallard/Interior Alaska/10BM12374R0/2010', {'weight': 7.997547999999999, 'trtype': 'Inter-Species', 'time_delta': 10.0}), ('A/northern pintail/Interior Alaska/10BM08488R0/2010', 'A/mallard/Interior Alaska/10BM12352R0/2010', {'weight': 7.996899000000001, 'trtype': 'Inter-Species', 'time_delta': 10.0}), ('A/northern pintail/Interior Alaska/10BM08489R0/2010', 'A/mallard/Interior Alaska/10BM12352R0/2010', {'weight': 7.996899000000001, 'trtype': 'Inter-Species', 'time_delta': 10.0}), ('A/northern pintail/Interior Alaska/10BM08488R0/2010', 'A/mallard/Interior Alaska/10BM12350R0/2010', {'weight': 7.997547999999999, 'trtype': 'Inter-Species', 'time_delta': 10.0}), ('A/northern pintail/Interior Alaska/10BM08489R0/2010', 'A/mallard/Interior Alaska/10BM12350R0/2010', {'weight': 7.997547999999999, 'trtype': 'Inter-Species', 'time_delta': 10.0}), ('A/northern pintail/Interior Alaska/10BM08488R0/2010', 'A/mallard/Interior Alaska/10BM12351R0/2010', {'weight': 7.996974000000002, 'trtype': 'Inter-Species', 'time_delta': 10.0}), ('A/northern pintail/Interior Alaska/10BM08489R0/2010', 'A/mallard/Interior Alaska/10BM12351R0/2010', {'weight': 7.996974000000002, 'trtype': 'Inter-Species', 'time_delta': 10.0}), ('A/northern pintail/Interior Alaska/10BM08488R0/2010', 'A/ma ...

# %%
# With the new edges added in, it is now 1571 edges.
# 22 September 2014: Update - with 2011 isolates removed, it is 1568
len(G.edges(data=True))
# Out:
# 1568

# %%
# After adding in more edges, the number of subgraphs becomes 474
# 22 September 2014: Update - with 2011 isolates removed, it is 460.
subgraphs = list(nx.connected_component_subgraphs(G.to_undirected()))
print(len(subgraphs))
# Out:
# 460

# %%
# Classify the edges.
from datetime import timedelta
for edge in G.edges(data=True):
    if edge[2]['time_delta'] > 15:
        edge[2]['tr_timeclass'] = "Environmental Persistence"
    if edge[2]['time_delta'] <= 15:
        edge[2]['tr_timeclass'] = "Direct Transmission"

# %%
# Check to ensure that the time classes are added in correctly.
G.edges(data=True)[9]
# Out:
# ('A/American green-winged teal/Interior Alaska/9BM4407R0/2009',
#  'A/northern pintail/Interior Alaska/9BM11151R0/2009',
#  {'weight': 7.9986039999999985,
#   'trtype': 'Inter-Species',
#   'tr_timeclass': 'Environmental Persistence',
#   'time_delta': 22.0})

# %%
# This is a custom function for serializing dates such that it is JSON compatible. 
# It gets used right at the last step prior to the JSON dump.
from dateutil.tz import tzutc

UTC = tzutc()

def serialize_date(dt):
    """
    Serialize a date/time value into an ISO8601 text representation
    adjusted (if needed) to UTC timezone.

    For instance:
    >>> serialize_date(datetime(2012, 4, 10, 22, 38, 20, 604391))
    '2012-04-10T22:38:20.604391Z'
    """
    #if dt.tzinfo:
    #    dt = dt.astimezone(UTC)
    return dt.isoformat()

# %%
# Dump the graph as a JSON node-link file.
# Prior to doing this, serialize all of the node dates to be JSON serializable.
G_serialized = deepcopy(G)

for node in G_serialized.nodes(data=True):
    node[1]['isolation_date'] = serialize_date(node[1]['isolation_date'])

d = json_graph.node_link_data(G_serialized) # node-link format to serialize
json.dump(d, open('viz/force2.json','w'))

# %%
# Write CSV file of the Directed Graph

df_edges = pd.DataFrame()

for edge in G.edges(data=True):
    df_edge = pd.Series()
    df_edge['Source'] = edge[0]
    df_edge['Sink'] = edge[1]
    df_edge['Transmission Type'] = edge[2]['trtype']        
    df_edge['Time Delta'] = edge[2]['time_delta']
    df_edge['Weight'] = edge[2]['weight']
    df_edge['Time Class'] = edge[2]['tr_timeclass']
   
    df_edges = df_edges.append(df_edge, ignore_index=True)
    
df_edges
# Out:
#                                                    Sink  \
# 0            A/mallard/Interior Alaska/10BM10876R0/2010
# 1            A/mallard/Interior Alaska/10BM10859R0/2010
# 2     A/northern pintail/Interior Alaska/10BM10790R0...
# 3            A/mallard/Interior Alaska/10BM10829R0/2010
# 4     A/northern pintail/Interior Alaska/9BM10877R0/...
# 1562         A/mallard/Interior Alaska/10BM11420R0/2010
# 1563         A/mallard/Interior Alaska/10BM11420R0/2010
# 1564  A/glaucous-winged gull/Southeastern Alaska/10J...
# 1565                A/mallard/New Jersey/AI09-5137/2009
# 1566           A/mallard/Interior Alaska/9BM8387R0/2009
# 1567           A/mallard/Interior Alaska/9BM8387R0/2009
#
#                      Time Class  Time Delta Transmission Type    Weight
# 0           Direct Transmission           0     Inter-Species  8.000000
# 1           Direct Transmission           0     Inter-Species  8.000000
# 2           Direct Transmission           0     Intra-Species  7.998844
# 3           Direct Transmission           0     Inter-Species  8.000000
# 4           Direct Transmission          15     Intra-Species  7.995868
# 5           Direct Transmission           0     Intra-Species  7.999568
# 6           Direct Transmission          15     Inter-Species  7.996608
# 7           Direct Transmission          15     Inter-Species  7.998528
# 8     Environmental Persistence          22     Inter-Species  7.995413
# 9     Environmental Persistence          22     Inter-Species  7.998604
# 10    Environmental Persistence          22     Inter-Species  7.998604
# 11    Environmental Persistence          22     Inter-Species  7.997737
# 12    Environmental Persistence          16     Inter-Species  7.998849
# 13          Direct Transmission           0     Inter-Species  8.000000
# 14          Direct Transmission           0     Intra-Species  7.947560
# 15          Direct Transmission          15     Intra-Species  7.988804
# 16          Direct Transmission           1     Intra-Species  7.992587
# 17          Direct Transmission           0     Intra-Species  7.995770
# 18          Direct Transmission          -3     Inter-Species  7.979019
# 19          Direct Transmission          -1     Intra-Species  7.995855
# 20          Direct Transmission          -2     Inter-Species  7.998507
# 21          Direct Transmission          14     Intra-Species  7.996737
# 22          Direct Transmission           0     Intra-Species  7.999568
# 23    Environmental Persistence          70     Inter-Species  7.940741
# 24          Direct Transmission           0     Intra-Species  8.000000
# 25          Direct Transmission           0     Intra-Species  8.000000
# 26          Direct Transmission           0     Intra-Species  8.000000
# 27          Direct Transmission           0     Intra-Species  8.000000
# 28          Direct Transmission           0     Inter-Species  7.999292
# 29          Direct Transmission           0     Inter-Species  8.000000
# ...                         ...         ...               ...       ...
# 1538        Direct Transmission           8     Intra-Species  7.999568
# 1539        Direct Transmission           0     Inter-Species  8.000000
# 1540        Direct Transmission           4     Inter-Species  8.000000
# 1541  Environmental Persistence         286     Intra-Species  7.997936
# 1542        Direct Transmission           0     Intra-Species  8.000000
# 1543        Direct Transmission           0     Intra-Species  8.000000
# 1544        Direct Transmission           0     Intra-Species  8.000000
# 1545        Direct Transmission           0     Intra-Species  7.999568
# 1546        Direct Transmission           0     Intra-Species  8.000000
# 1547        Direct Transmission           0     Intra-Species  8.000000
# 1548        Direct Transmission           0     Intra-Species  8.000000
# 1549        Direct Transmission           0     Intra-Species  8.000000
# 1550        Direct Transmission           0     Intra-Species  8.000000
# 1551        Direct Transmission          -1     Inter-Species  7.995685
# 1552        Direct Transmission           0     Intra-Species  7.996841
# 1553        Direct Transmission           0     Intra-Species  7.997728
# 1554        Direct Transmission           0     Intra-Species  7.996580
# 1555        Direct Transmission          -1     Intra-Species  7.998485
# 1556        Direct Transmission           0     Intra-Species  8.000000
# 1557        Direct Transmission           0     Intra-Species  8.000000
# 1558        Direct Transmission           1     Inter-Species  7.997286
# 1559        Direct Transmission           0     Intra-Species  8.000000
# 1560        Direct Transmission           0     Intra-Species  7.998683
# 1561        Direct Transmission           1     Intra-Species  7.998993
# 1562        Direct Transmission           0     Intra-Species  7.998540
# 1563        Direct Transmission           0     Intra-Species  7.999136
# 1564        Direct Transmission          -1     Intra-Species  7.994860
# 1565        Direct Transmission           0     Intra-Species  7.995770
# 1566  Environmental Persistence          21     Intra-Species  7.924622
# 1567        Direct Transmission           6     Inter-Species  7.907130
#
# [1568 rows x 6 columns]

# %%
df_nodes = pd.DataFrame()

for node in G.nodes(data=True):
    node_series = pd.Series()
#     print node
    node_series['Isolate Name'] = node[0]
#     node_series['Country'] = node[1]['country']
    node_series['State'] = node[1]['state']
    node_series['Subtype'] = node[1]['subtype']
    node_series['Host'] = node[1]['host']
    node_series['Isolation Date'] = node[1]['isolation_date']
    
    df_nodes = df_nodes.append(node_series, ignore_index=True)
    
df_nodes['Isolation Date'] = df_nodes['Isolation Date'].astype('datetime64[ns]')
df_nodes
# Out:
#                                Host  \
# 0                 IRD:Mallard/Avian
# 1        IRD:Northern Pintail/Avian
# 2       IRD:Green-winged Teal/Avian
# 3                 IRD:Mallard/Avian
# 4       IRD:Green-winged Teal/Avian
# 5        IRD:Northern Pintail/Avian
# 6     IRD:American Black Duck/Avian
# 7        IRD:Northern Pintail/Avian
# 8                 IRD:Mallard/Avian
# 9       IRD:Green-Winged Teal/Avian
# 10      IRD:Green-winged Teal/Avian
# 11                IRD:Mallard/Avian
# 12       IRD:Northern Pintail/Avian
# 13       IRD:Blue-Winged Teal/Avian
# 14                IRD:Mallard/Avian
# 15      IRD:Northern Shoveler/Avian
# 16                IRD:Mallard/Avian
# 17              IRD:Shorebird/Avian
# 18                IRD:Mallard/Avian
# 19        IRD:Ruddy Turnstone/Avian
# 20        IRD:American Wigeon/Avian
# 21       IRD:Ring-necked Duck/Avian
# 22    IRD:American Black Duck/Avian
# 23       IRD:Northern Pintail/Avian
# 24                IRD:Mallard/Avian
# 25       IRD:Blue-Winged Teal/Avian
# 26                IRD:Mallard/Avian
# 27                IRD:Mallard/Avian
# 28                IRD:Mallard/Avian
# 29    IRD:American Black Duck/Avian
# ...                             ...
# 1139            IRD:Shorebird/Avian
# 1140              IRD:Mallard/Avian
# 1141              IRD:Mallard/Avian
# 1142                IRD:Environment
# 1143    IRD:Northern Shoveler/Avian
# 1144              IRD:Mallard/Avian
# 1145              IRD:Mallard/Avian
# 1146              IRD:Mallard/Avian
# 1147              IRD:Mallard/Avian
# 1148            IRD:Shorebird/Avian
# 1149              IRD:Mallard/Avian
# 1150    IRD:Northern Shoveler/Avian
# 1151              IRD:Mallard/Avian
# 1152              IRD:Mallard/Avian
# 1153              IRD:Mallard/Avian
# 1154     IRD:Northern Pintail/Avian
# 1155     IRD:Northern Pintail/Avian
# 1156         IRD:Canada Goose/Avian
# 1157  IRD:American Black Duck/Avian
# 1158              IRD:Mallard/Avian
# 1159  Southeastern Alaska   H16N3
# 1160      Interior Alaska    H3N7
# 1161      Interior Alaska    H4N6
# 1162           California    H5N2
# 1163           New Jersey    H4N9
# 1164                  196   H10N3
# 1165            Wisconsin    H4N2
# 1166        New Brunswick    H4N8
# 1167        New Brunswick    H4N6
# 1168      Interior Alaska    H3N8
#
# [1169 rows x 5 columns]

# %%
# Check to see how many nodes belong to Minto Flats (i.e. state = Interior Alaska)
# 22 September 2014: Update - with 2011 isolates removed, this should not change 
len(df_nodes[df_nodes['State'] == 'Interior Alaska'])
# Out:
# 494

# %%
# Write the Nodes to a CSV file.
df_nodes.to_csv('3.10 - Full Transmission as CSV/Full Transmissions Nodes.csv')

# %%
# Modify the Nodes column names to fit with the source-sink paradigm.
df_nodes.columns = map(lambda x: x + '1', df_nodes.columns)
print(df_nodes.columns)

df_full = df_edges.set_index('Source').join(df_nodes.set_index('Isolate Name1'))
df_nodes.columns = map(lambda x: x.replace('1', '2'), df_nodes.columns)
print(df_nodes.columns)

df_full = df_full.reset_index()
print(df_full.columns)

df_full.columns = ['Source' if item == 'index' else item for item in list(df_full.columns)]
print(df_full.columns)

df_full = df_full.set_index('Sink').join(df_nodes.set_index('Isolate Name2'))
df_full = df_full.reset_index()
df_full.columns = ['Sink' if item == 'index' else item for item in list(df_full.columns)]
df_full.columns

df_full.to_csv('3.10 - Full Transmission as CSV/Full Transmissions.csv')
# Out:
# Index(['Host1', 'Isolate Name1', 'Isolation Date1', 'State1', 'Subtype1'], dtype='object')
# Index(['Host2', 'Isolate Name2', 'Isolation Date2', 'State2', 'Subtype2'], dtype='object')
# Index(['index', 'Sink', 'Time Class', 'Time Delta', 'Transmission Type', 'Weight', 'Host1', 'Isolation Date1', 'State1', 'Subtype1'], dtype='object')
# Index(['Source', 'Sink', 'Time Class', 'Time Delta', 'Transmission Type', 'Weight', 'Host1', 'Isolation Date1', 'State1', 'Subtype1'], dtype='object')

# %%
# Inspect the data.
df_full
# Out:
#                                                 Sink  \
# 0     A/American black duck/New Brunswick/00321/2010
# 1     A/American black duck/New Brunswick/00322/2010
# 2     A/American black duck/New Brunswick/00326/2010
# 3     A/American black duck/New Brunswick/00328/2010
# 4     A/American black duck/New Brunswick/00344/2010
# 5     A/American black duck/New Brunswick/00385/2010
# 6     A/American black duck/New Brunswick/00410/2010
# 7     A/American black duck/New Brunswick/00424/2010
# 8     A/American black duck/New Brunswick/00425/2010
# 9     A/American black duck/New Brunswick/00454/2010
# 10    A/American black duck/New Brunswick/00464/2010
# 11    A/American black duck/New Brunswick/00464/2010
# 12    A/American black duck/New Brunswick/00467/2010
# 13    A/American black duck/New Brunswick/00468/2010
# 14    A/American black duck/New Brunswick/00468/2010
# 15    A/American black duck/New Brunswick/00469/2010
# 16    A/American black duck/New Brunswick/00469/2010
# 17    A/American black duck/New Brunswick/00470/2010
# 18    A/American black duck/New Brunswick/00470/2010
# 19    A/American black duck/New Brunswick/00472/2010
# 20    A/American black duck/New Brunswick/00472/2010
# 21    A/American black duck/New Brunswick/00473/2010
# 20    Environmental Persistence         335     Intra-Species  7.723661
# 21          Direct Transmission           0     Intra-Species  7.921325
# 22    Environmental Persistence         380     Inter-Species  7.654294
# 23          Direct Transmission           0     Inter-Species  7.995223
# 24          Direct Transmission           0     Intra-Species  7.996190
# 25    Environmental Persistence         335     Intra-Species  7.726631
# 26          Direct Transmission           0     Intra-Species  7.997571
# 27    Environmental Persistence         335     Intra-Species  7.725577
# 28          Direct Transmission           0     Intra-Species  7.961111
# 29    Environmental Persistence         380     Inter-Species  7.637092
# ...                         ...         ...               ...       ...
# 1538        Direct Transmission           0     Intra-Species  7.998717
# 1539        Direct Transmission           0     Intra-Species  7.998389
# 1540        Direct Transmission           9     Inter-Species  7.993592
# 1541        Direct Transmission           0     Intra-Species  7.993873
# 1542        Direct Transmission           0     Intra-Species  7.998389
# 1543        Direct Transmission           0     Intra-Species  7.999301
# 1544        Direct Transmission           0     Intra-Species  7.999301
# 1545        Direct Transmission           0     Intra-Species  8.000000
# 1546        Direct Transmission           0     Intra-Species  8.000000
# 1547        Direct Transmission           9     Inter-Species  7.996529
# 1548        Direct Transmission           0     Intra-Species  7.998545
# 1549        Direct Transmission          -6     Inter-Species  7.996494
# 1550        Direct Transmission           1     Inter-Species  7.997286
# 1551        Direct Transmission           1     Intra-Species  7.992587
# 1552        Direct Transmission          10     Inter-Species  7.998135
# 1553        Direct Transmission          -5     Inter-Species  7.996465
# 1554        Direct Transmission          10     Inter-Species  7.997503
# 1555        Direct Transmission          -5     Intra-Species  8.000000
# 1556  Environmental Persistence          24     Inter-Species  7.996423
# 1557        Direct Transmission           1     Inter-Species  7.995685
# 1558        Direct Transmission          15     Intra-Species  7.988804
# 1559        Direct Transmission           0     Intra-Species  7.966778
# 1560        Direct Transmission           0     Intra-Species  7.997948
# 1561        Direct Transmission           0     Intra-Species  7.979379
# 1562        Direct Transmission           0     Intra-Species  7.997948
# 1563        Direct Transmission           1     Intra-Species  7.995651
# 1564        Direct Transmission          -1     Intra-Species  7.995651
# 1565        Direct Transmission           8     Inter-Species  7.996099
# 1566  Environmental Persistence         316     Inter-Species  7.768421
# 1567        Direct Transmission           0     Inter-Species  7.999002
#
#                               Host1 Isolation Date1                State1  \
# 0                 IRD:Mallard/Avian      2010-08-08         New Brunswick
# 1     IRD:American Black Duck/Avian      2010-08-04  Prince Edward Island
# 2                 IRD:Mallard/Avian      2010-08-08         New Brunswick
# 3       IRD:Green-winged Teal/Avian      2010-08-08         New Brunswick
# 4                 IRD:Mallard/Avian      2010-08-08           Nova Scotia
# 5                 IRD:Mallard/Avian      2010-08-08         New Brunswick
# 6                 IRD:Mallard/Avian      2010-08-08         New Brunswick
# 7     IRD:American Black Duck/Avian      2010-08-10         New Brunswick
# 8     IRD:American Black Duck/Avian      2010-08-10         New Brunswick
# 9     IRD:American Black Duck/Avian      2010-08-12         New Brunswick
# 10    IRD:American Black Duck/Avian      2010-08-12         New Brunswick
# 11    IRD:American Black Duck/Avian      2009-09-11         New Brunswick
# 12    IRD:American Black Duck/Avian      2010-08-16         New Brunswick
# 13    IRD:American Black Duck/Avian      2010-08-15         New Brunswick
# 14    IRD:American Black Duck/Avian      2009-09-11         New Brunswick
# 15    IRD:American Black Duck/Avian      2010-08-12         New Brunswick
# 16    IRD:American Black Duck/Avian      2009-09-11         New Brunswick
# 17    IRD:American Black Duck/Avian      2010-08-12         New Brunswick
# 18    IRD:American Black Duck/Avian      2009-09-11         New Brunswick
# 19    IRD:American Black Duck/Avian      2010-08-12         New Brunswick
# 20    IRD:American Black Duck/Avian      2009-09-11         New Brunswick
# 21    IRD:American Black Duck/Avian      2010-08-12         New Brunswick
#
IRD:Shorebird/Avian      2009-05-20   Delaware Bay
# 1550     H6N1            IRD:Shorebird/Avian      2010-05-20   Delaware Bay
# 1551    H10N7            IRD:Shorebird/Avian      2009-05-21   Delaware Bay
# 1552    H10N7            IRD:Shorebird/Avian      2009-05-21   Delaware Bay
# 1553    H10N7            IRD:Shorebird/Avian      2009-05-21   Delaware Bay
# 1554    H11N1            IRD:Shorebird/Avian      2009-05-21   Delaware Bay
# 1555    H10N7            IRD:Shorebird/Avian      2009-05-15   Delaware Bay
# 1556    H10N7            IRD:Shorebird/Avian      2009-06-04   Delaware Bay
# 1557     H1N7            IRD:Shorebird/Avian      2009-06-04   Delaware Bay
# 1558    H10N7            IRD:Shorebird/Avian      2009-06-04   Delaware Bay
# 1559     H1N1            IRD:Shorebird/Avian      2009-05-20       Delaware
# 1560     H1N1            IRD:Shorebird/Avian      2009-05-20       Delaware
# 1561     H1N1            IRD:Shorebird/Avian      2009-05-20       Delaware
# 1562     H1N1            IRD:Shorebird/Avian      2009-05-20       Delaware
# 1563     H5N2               IRD:Turkey/Avian      2010-11-26             MB
# 1564     H5N2               IRD:Turkey/Avian      2010-11-25             MB
# 1565     H3N8                 IRD:Duck/Avian      2010-08-12    Nova Scotia
# 1566     H3N8                 IRD:Duck/Avian      2010-09-26      Wisconsin
# 1567     H3N8                 IRD:Duck/Avian      2010-09-26      Wisconsin
#
#      Subtype2
# 0        H1N1
# 1        H3N8
# 2        H1N1
# 3        H1N1
# 4        H7N7
# 5        H1N1
# 6        H1N1
# 7        H3N8
# 8        H3N8
# 9        H3N8
# 10       H4N6
# 11       H4N6
# 12       H3N8
# 13       H4N6
# 14       H4N6
# 15       H4N6
# 16       H4N6
# 17       H4N6
# 18       H4N6
# 19       H4N6
# 20       H4N6
# 21       H4N6
# 22       (H3)
# 23       (H3)
# 24       H4N6
# 25       H4N6
# 26       H4N6
# 27       H4N6
# 28       H3N8
# 29       H3N8
# ...       ...
# 1538    H10N7
# 1539     H1N1
# 1540    H10N7
# 1541    H10N7
# 1542     H1N1
# 1543    H10N1
# 1544    H10N1
# 1545    H10N1
# 1546    H10N1
# 1547    H10N7
# 1548    H10N7
# 1549     H1N9
# 1550     H6N1
# 1551    H10N7
# 1552    H10N7
# 1553    H10N7
# 1554    H11N1
# 1555    H10N7
# 1556    H10N7
# 1557     H1N7
# 1558    H10N7
# 1559     H1N1
# 1560     H1N1
# 1561     H1N1
# 1562     H1N1
# 1563     H5N2
# 1564     H5N2
# 1565     H3N8
# 1566     H3N8
# 1567     H3N8
#
# [1568 rows x 14 columns]

# %%
df_full['Isolation Date1'] = df_full['Isolation Date1'].astype('datetime64[ns]')
df_full['Isolation Date2'] = df_full['Isolation Date2'].astype('datetime64[ns]')
df_full
# Out:
#                                                 Sink  \
# 0     A/American black duck/New Brunswick/00321/2010
# 1     A/American black duck/New Brunswick/00322/2010
# 2     A/American black duck/New Brunswick/00326/2010
# 3     A/American black duck/New Brunswick/00328/2010
# 4     A/American black duck/New Brunswick/00344/2010
# 5     A/American black duck/New Brunswick/00385/2010
# 6     A/American black duck/New Brunswick/00410/2010
# 7     A/American black duck/New Brunswick/00424/2010
# 8     A/American black duck/New Brunswick/00425/2010
# 9     A/American black duck/New Brunswick/00454/2010
# 10    A/American black duck/New Brunswick/00464/2010
# 11    A/American black duck/New Brunswick/00464/2010
# 12    A/American black duck/New Brunswick/00467/2010
# 13          Direct Transmission          -3     Intra-Species  7.998610
# 14    Environmental Persistence         335     Intra-Species  7.725058
# 15          Direct Transmission           0     Intra-Species  7.996128
# 16    Environmental Persistence         335     Intra-Species  7.730342
# 17          Direct Transmission           0     Intra-Species  7.995578
# 18    Environmental Persistence         335     Intra-Species  7.726709
# 19          Direct Transmission           0     Intra-Species  7.998529
# 20    Environmental Persistence         335     Intra-Species  7.723661
# 21          Direct Transmission           0     Intra-Species  7.921325
# 22    Environmental Persistence         380     Inter-Species  7.654294
# 23          Direct Transmission           0     Inter-Species  7.995223
# 24          Direct Transmission           0     Intra-Species  7.996190
# 25    Environmental Persistence         335     Intra-Species  7.726631
# 26          Direct Transmission           0     Intra-Species  7.997571
# 27    Environmental Persistence         335     Intra-Species  7.725577
# 28          Direct Transmission           0     Intra-Species  7.961111
# 29    Environmental Persistence         380     Inter-Species  7.637092
# ...                         ...         ...               ...       ...
# 1538        Direct Transmission           0     Intra-Species  7.998717
# 1539        Direct Transmission           0     Intra-Species  7.998389
# 1540        Direct Transmission           9     Inter-Species  7.993592
# 1541        Direct Transmission           0     Intra-Species  7.993873
# 1542        Direct Transmission           0     Intra-Species  7.998389
# 1543        Direct Transmission           0     Intra-Species  7.999301
# 1544        Direct Transmission           0     Intra-Species  7.999301
# 1545        Direct Transmission           0     Intra-Species  8.000000
# 1546        Direct Transmission           0     Intra-Species  8.000000
# 1547        Direct Transmission           9     Inter-Species  7.996529
# 1548        Direct Transmission           0     Intra-Species  7.998545
# 1549        Direct Transmission          -6     Inter-Species  7.996494
# 1550        Direct Transmission           1     Inter-Species  7.997286
# 1551        Direct Transmission           1     Intra-Species  7.992587
# 1552        Direct Transmission          10     Inter-Species  7.998135
# 1553        Direct Transmission          -5     Inter-Species  7.996465
# 1554        Direct Transmission          10     Inter-Species  7.997503
# 1555        Direct Transmission          -5     Intra-Species  8.000000
# 1556  Environmental Persistence          24     Inter-Species  7.996423
# 1557        Direct Transmission           1     Inter-Species  7.995685
# 1558        Direct Transmission          15     Intra-Species  7.988804
# 1559        Direct Transmission           0     Intra-Species  7.966778
# 1560        Direct Transmission           0     Intra-Species  7.997948
# 1561        Direct Transmission           0     Intra-Species  7.979379
# 1562        Direct Transmission           0     Intra-Species  7.997948
# 1563        Direct Transmission           1     Intra-Species  7.995651
# 1564        Direct Transmission          -1     Intra-Species  7.995651
# 1565        Direct Transmission           8     Inter-Species  7.996099
# 1566  Environmental Persistence         316     Inter-Species  7.768421
# 1567        Direct Transmission           0     Inter-Species  7.999002
#
#                               Host1 Isolation Date1                State1  \
# 0                 IRD:Mallard/Avian      2010-08-08         New Brunswick
# 1     IRD:American Black Duck/Avian      2010-08-04  Prince Edward Island
# 2                 IRD:Mallard/Avian      2010-08-08         New Brunswick
# 3       IRD:Green-winged Teal/Avian      2010-08-08         New Brunswick
# 4                 IRD:Mallard/Avian      2010-08-08           Nova Scotia
# 5                 IRD:Mallard/Avian      2010-08-08         New Brunswick
# 6                 IRD:Mallard/Avian      2010-08-08         New Brunswick
# 7     IRD:American Black Duck/Avian      2010-08-10         New Brunswick
# 8     IRD:American Black Duck/Avian      2010-08-10         New Brunswick
# 9     IRD:American Black Duck/Avian      2010-08-12         New Brunswick
#
IRD:American Black Duck/Avian      2010-08-12  New Brunswick
# 28       H3N8  IRD:American Black Duck/Avian      2010-08-12  New Brunswick
# 29       H3N8  IRD:American Black Duck/Avian      2010-08-12  New Brunswick
# ...       ...                            ...             ...            ...
# 1538    H10N7            IRD:Shorebird/Avian      2009-05-20   Delaware Bay
# 1539     H1N1            IRD:Shorebird/Avian      2009-05-20   Delaware Bay
# 1540    H10N7            IRD:Shorebird/Avian      2009-05-20   Delaware Bay
# 1541    H10N7            IRD:Shorebird/Avian      2009-05-20   Delaware Bay
# 1542     H1N1            IRD:Shorebird/Avian      2009-05-20   Delaware Bay
# 1543    H10N1            IRD:Shorebird/Avian      2009-05-20   Delaware Bay
# 1544    H10N1            IRD:Shorebird/Avian      2009-05-20   Delaware Bay
# 1545    H10N1            IRD:Shorebird/Avian      2009-05-20   Delaware Bay
# 1546    H10N1            IRD:Shorebird/Avian      2009-05-20   Delaware Bay
# 1547    H10N7            IRD:Shorebird/Avian      2009-05-20   Delaware Bay
# 1548    H10N7            IRD:Shorebird/Avian      2009-05-20   Delaware Bay
# 1549     H1N9            IRD:Shorebird/Avian      2009-05-20   Delaware Bay
# 1550     H6N1            IRD:Shorebird/Avian      2010-05-20   Delaware Bay
# 1551    H10N7            IRD:Shorebird/Avian      2009-05-21   Delaware Bay
# 1552    H10N7            IRD:Shorebird/Avian      2009-05-21   Delaware Bay
# 1553    H10N7            IRD:Shorebird/Avian      2009-05-21   Delaware Bay
# 1554    H11N1            IRD:Shorebird/Avian      2009-05-21   Delaware Bay
# 1555    H10N7            IRD:Shorebird/Avian      2009-05-15   Delaware Bay
# 1556    H10N7            IRD:Shorebird/Avian      2009-06-04   Delaware Bay
# 1557     H1N7            IRD:Shorebird/Avian      2009-06-04   Delaware Bay
# 1558    H10N7            IRD:Shorebird/Avian      2009-06-04   Delaware Bay
# 1559     H1N1            IRD:Shorebird/Avian      2009-05-20       Delaware
# 1560     H1N1            IRD:Shorebird/Avian      2009-05-20       Delaware
# 1561     H1N1            IRD:Shorebird/Avian      2009-05-20       Delaware
# 1562     H1N1            IRD:Shorebird/Avian      2009-05-20       Delaware
# 1563     H5N2               IRD:Turkey/Avian      2010-11-26             MB
# 1564     H5N2               IRD:Turkey/Avian      2010-11-25             MB
# 1565     H3N8                 IRD:Duck/Avian      2010-08-12    Nova Scotia
# 1566     H3N8                 IRD:Duck/Avian      2010-09-26      Wisconsin
# 1567     H3N8                 IRD:Duck/Avian      2010-09-26      Wisconsin
#
#      Subtype2
# 0        H1N1
# 1        H3N8
# 2        H1N1
# 3        H1N1
# 4        H7N7
# 5        H1N1
# 6        H1N1
# 7        H3N8
# 8        H3N8
# 9        H3N8
# 10       H4N6
# 11       H4N6
# 12       H3N8
# 13       H4N6
# 14       H4N6
# 15       H4N6
# 16       H4N6
# 17       H4N6
# 18       H4N6
# 19       H4N6
# 20       H4N6
# 21       H4N6
# 22       (H3)
# 23       (H3)
# 24       H4N6
# 25       H4N6
# 26       H4N6
# 27       H4N6
# 28       H3N8
# 29       H3N8
# ...       ...
# 1538    H10N7
# 1539     H1N1
# 1540    H10N7
# 1541    H10N7
# 1542     H1N1
# 1543    H10N1
# 1544    H10N1
# 1545    H10N1
# 1546    H10N1
# 1547    H10N7
# 1548    H10N7
# 1549     H1N9
# 1550     H6N1
# 1551    H10N7
# 1552    H10N7
# 1553    H10N7
# 1554    H11N1
# 1555    H10N7
# 1556    H10N7
# 1557     H1N7
# 1558    H10N7
# 1559     H1N1
# 1560     H1N1
# 1561     H1N1
# 1562     H1N1
# 1563     H5N2
# 1564     H5N2
# 1565     H3N8
# 1566     H3N8
# 1567     H3N8
#
# [1568 rows x 14 columns]

# %%
source_2009 = df_full[(df_full['State1'] != df_full['State2']) & \
                      (df_full['Isolation Date1'] < datetime(2010, 1, 1))]
source_2009.to_csv('3.10 - Full Transmission as CSV/20140820 Source 2009.csv')

source_2010 = df_full[(df_full['State1'] != df_full['State2']) & \
                      (df_full['Isolation Date1'] >= datetime(2010, 1, 1))]
source_2010.to_csv('3.10 - Full Transmission as CSV/20140820 Source 2010.csv')

# %%
# Query the network
# df_full[(df_full['State1'] == 'Interior Alaska') & (df_full['State1'] != df_full['State2'])]
# df_full[(df_full['State1'] == 'Alberta') | (df_full['State2'] == 'Alberta')]
# df_full[(df_full['State1'] != df_full['State2']) & (df_full['Time Delta'] > 15)]['Time Delta'].hist()
# df_full[(df_full['State1'] == df_full['State2']) & (df_full['Time Delta'] <= 15)]['Weight'].hist()
# df_full[df_full['State1'] != df_full['State2']].sort("Weight", ascending=False)['Weight'].hist()
# df_full[df_full['Weight'] >= 7.99]['Time Delta'].hist()
# df_full[df_full['Time Delta'] > 300]['Weight'].hist()
df_full[df_full['Subtype1'] != df_full['Subtype2']]
# Out:
#                                                    Sink  \
# 22       A/American black duck/New Brunswick/00476/2010
# 23       A/American black duck/New Brunswick/00476/2010
# 42       A/American black duck/New Brunswick/00610/2010
# 43       A/American black duck/New Brunswick/00615/2010
# 45       A/American black duck/New Brunswick/00617/2010
# 125   A/American green-winged teal/Interior Alaska/1...
# 132   A/American green-winged teal/Interior Alaska/1...
# 225           A/blue-winged teal/Nova Scotia/00067/2010
# 365   A/greater white-fronted goose/California/3778/...
# 392         A/hooded merganser/New Brunswick/03750/2009
# 399   A/mallard-black duck hybrid/New Brunswick/0373...
# 458          A/mallard/Interior Alaska/10BM06447R0/2010
# 945                  A/mallard/New Brunswick/00494/2010
# 957                 A/mallard/New Jersey/AI09-5086/2009
# 959                 A/mallard/New Jersey/AI09-5137/2009
# 984                    A/mallard/Nova Scotia/01017/2010
# 1000                  A/mallard/Wisconsin/10OS3169/2010
# 1469         A/northern shoveler/Missouri/10OS4700/2010
# 1474             A/ring-billed gull/Quebec/02622-1/2009
#
#                                                  Source  \
# 22                   A/mallard/Minnesota/AI09-1829/2009
# 23                   A/mallard/New Brunswick/00495/2010
# 42       A/American black duck/New Brunswick/00469/2010
# 43                   A/mallard/New Brunswick/00494/2010
# 45                        A/mallard/Wisconsin/2712/2009
# 125          A/mallard/Interior Alaska/10BM06447R0/2010
# 132          A/mallard/Interior Alaska/10BM06447R0/2010
# 225   A/northern pintail/Interior Alaska/10BM05034R0...
# 365   A/American green-winged teal/Minnesota/AI09-35...
# 392              A/ring-billed gull/Quebec/02622-1/2009
# 399              A/ring-billed gull/Quebec/02622-1/2009
# 458   A/American green-winged teal/Interior Alaska/1...
# 945      A/American black duck/New Brunswick/00615/2010
# 957                 A/mallard/New Jersey/AI09-5137/2009
# 959                 A/mallard/New Jersey/AI09-5086/2009
# 984                        A/mallard/Ohio/10OS1354/2010
# 1000                  A/mallard/Wisconsin/10OS2945/2010
# 1469                        A/mallard/Missouri/220/2009
# 1474         A/ruddy turnstone/New Jersey/AI09-294/2009
#
#                      Time Class  Time Delta Transmission Type    Weight  \
# 22    Environmental Persistence         380     Inter-Species  7.654294
# 23          Direct Transmission           0     Inter-Species  7.995223
# 42          Direct Transmission           4     Intra-Species  7.918621
# 43          Direct Transmission           4     Inter-Species  7.919835
# 45    Environmental Persistence         309     Inter-Species  7.656613
# 125         Direct Transmission           3     Inter-Species  7.957495
# 132         Direct Transmission           5     Inter-Species  7.595989
# 225   Environmental Persistence          48     Inter-Species  7.653114
# 365   Environmental Persistence         449     Inter-Species  7.699812
# 392   Environmental Persistence          56     Inter-Species  7.981710
# 399   Environmental Persistence          56     Inter-Species  7.976569
# 458         Direct Transmission          -3     Inter-Species  7.957495
# 945         Direct Transmission          -4     Inter-Species  7.919835
# 957         Direct Transmission           0     Intra-Species  7.995770
# 959         Direct Transmission           0     Intra-Species  7.995770
# 984   Environmental Persistence          45     Intra-Species  7.707709
# 1000  Environmental Persistence          26     Intra-Species  7.996008
# 1469  Environmental Persistence         370     Inter-Species  7.765081
# 1474  Environmental Persistence          70     Inter-Species  7.940741
#
#                               Host1 Isolation Date1           State1 Subtype1  \
# 22                IRD:Mallard/Avian      2009-07-28        Minnesota     H3N8
# 23                IRD:Mallard/Avian      2010-08-12    New Brunswick     H3N8
# 42    IRD:American Black Duck/Avian      2010-08-12    New Brunswick     H4N6
# 43                IRD:Mallard/Avian      2010-08-12    New Brunswick     (N8)
# 45                IRD:Mallard/Avian      2009-10-11        Wisconsin     H3N6
# 125               IRD:Mallard/Avian      2010-07-30  Interior Alaska     (H3)
# 132               IRD:Mallard/Avian      2010-07-30  Interior Alaska     (H3)
# 225      IRD:Northern Pintail/Avian      2010-07-21  Interior Alaska     H3N6
# 365     IRD:Green-winged Teal/Avian      2009-09-12        Minnesota     H6N1
# 392                  IRD:Gull/Avian      2009-07-20           Quebec     (N6)
# 399                  IRD:Gull/Avian      2009-07-20           Quebec     (N6)
# 458     IRD:Green-winged Teal/Avian      2010-08-02  Interior Alaska     H3N8
# 945   IRD:American Black Duck/Avian      2010-08-16    New Brunswick     H4N8
# 957               IRD:Mallard/Avian      2009-09-28       New Jersey     H4N9
# 959               IRD:Mallard/Avian      2009-09-28       New Jersey     (H4)
# 984               IRD:Mallard/Avian      2010-08-06             Ohio     H6N1
# 1000              IRD:Mallard/Avian      2010-10-03        Wisconsin     (H4)
# 1469              IRD:Mallard/Avian      2009-12-07         Missouri     H7N3
# 1474      IRD:Ruddy Turnstone/Avian      2009-05-11       New Jersey    H13N6
#
#                                       Host2 Isolation Date2           State2  \
# 22            IRD:American Black Duck/Avian      2010-08-12    New Brunswick
# 23            IRD:American Black Duck/Avian      2010-08-12    New Brunswick
# 42            IRD:American Black Duck/Avian      2010-08-16    New Brunswick
# 43            IRD:American Black Duck/Avian      2010-08-16    New Brunswick
# 45            IRD:American Black Duck/Avian      2010-08-16    New Brunswick
# 125             IRD:Green-winged Teal/Avian      2010-08-02  Interior Alaska
# 132             IRD:Green-winged Teal/Avian      2010-08-04  Interior Alaska
# 225                          IRD:Teal/Avian      2010-09-07      Nova Scotia
# 365   IRD:Greater White-Fronted Goose/Avian      2010-12-05       California
# 392              IRD:Hooded Merganser/Avian      2009-09-14    New Brunswick
# 399     IRD:Mallard-Black Duck Hybrid/Avian      2009-09-14    New Brunswick
# 458                       IRD:Mallard/Avian      2010-07-30  Interior Alaska
# 945                       IRD:Mallard/Avian      2010-08-12    New Brunswick
# 957                       IRD:Mallard/Avian      2009-09-28       New Jersey
# 959                       IRD:Mallard/Avian      2009-09-28       New Jersey
# 984                       IRD:Mallard/Avian      2010-09-20      Nova Scotia
# 1000                      IRD:Mallard/Avian      2010-10-29        Wisconsin
# 1469            IRD:Northern Shoveler/Avian      2010-12-12         Missouri
# 1474                         IRD:Gull/Avian      2009-07-20           Quebec
#
#      Subtype2
# 22       (H3)
# 23       (H3)
# 42       (H4)
# 43       H4N8
# 45       (N6)
# 125      H3N8
# 132      H3N8
# 225      (N6)
# 365      (H6)
# 392     H13N6
# 399     H13N6
# 458      (H3)
# 945      (N8)
# 957      (H4)
# 959      H4N9
# 984      (N1)
# 1000     H4N9
# 1469     (N3)
# 1474     (N6)

# %%
df_nodes[df_nodes['State2'] == 'Alberta']
# Out:
#                            Host2                      Isolate Name2  \
# 191            IRD:Mallard/Avian         A/mallard/Alberta/413/2009
# 284            IRD:Mallard/Avian         A/mallard/Alberta/155/2009
# 301            IRD:Mallard/Avian         A/mallard/Alberta/421/2009
# 315            IRD:Mallard/Avian         A/mallard/Alberta/319/2009
# 327            IRD:Mallard/Avian         A/mallard/Alberta/551/2009
# 473            IRD:Mallard/Avian         A/mallard/Alberta/289/2009
# 676            IRD:Mallard/Avian         A/mallard/Alberta/417/2009
# 867            IRD:Mallard/Avian         A/mallard/Alberta/419/2009
# 1007           IRD:Mallard/Avian          A/mallard/Alberta/35/2009
# 1016  IRD:Northern Pintail/Avian  A/northern pintail/Alberta/8/2009
#
#      Isolation Date2   State2 Subtype2
# 191       2009-08-22  Alberta     (H6)
# 284       2009-08-19  Alberta     H1N9
# 301       2009-08-22  Alberta     H2N3
# 315       2009-08-22  Alberta     H2N3
# 327       2009-08-23  Alberta     H3N8
# 473       2009-08-20  Alberta     H2N9
# 676       2009-08-22  Alberta     H2N3
# 867       2009-08-22  Alberta     H2N3
# 1007      2009-08-19  Alberta     H2N3
# 1016      2009-08-19  Alberta     H3N8

# %%
# Open up the lat/long values
lat_long_vals = pd.read_csv('lat_long.csv')
lat_long_vals
# Out:
#                    State        N         W
# 0                Alberta  55.0000  115.0000
# 1               Arkansas  34.8000   92.2000
# 2             California  37.0000  120.0000
# 3               Delaware  39.0000   75.5000
# 4           Delaware Bay  39.0000   75.5000
# 5              Guatemala  14.6000   90.5000
# 6               Illinois  40.0000   89.0000
# 7                Indiana  40.0000   86.0000
# 8        Interior Alaska  64.8436  147.7231
# 9                   Iowa  42.0000   93.0000
# 10             Louisiana  31.0413   91.8360
# 11                    MB  55.0000   97.0000
# 12              Michigan  43.6867   85.0102
# 13             Minnesota  46.0000   94.0000
# 14           Mississippi  33.0000   90.0000
# 15              Missouri  38.5000   92.5000
# 16         New Brunswick  46.0000   66.0000
# 17            New Jersey  40.0000   74.5000
# 18          North Dakota  47.0000  100.0000
# 19           Nova Scotia  45.0000   63.0000
# 20               Nunavet  73.0000   91.0000
# 21                  Ohio  40.5000   82.5000
# 22  Prince Edward Island  46.2000   63.0000
# 23                Quebec  53.0000   70.0000
# 24   Southeastern Alaska  61.2167  149.9000
# 25                 Texas  31.0000  100.0000
# 26             Wisconsin  44.5000   89.5000

# %%
# Create an undirected version of the transmission graph.
undirected_G = G.to_undirected()

# Make sure that the time deltas are all positive values.
for edge in undirected_G.edges(data=True):
    if edge[2]['time_delta'] < 0:
        edge[2]['time_delta'] = abs(edge[2]['time_delta'])

# %%
# Check the undiredcted_G edges:
undirected_G.nodes(data=True)
# Out:
# [('A/mallard/Interior Alaska/10BM09164R0/2010',
#   {'isolation_date': Timestamp('2010-08-06 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/10BM10853R0/2010',
#   {'isolation_date': Timestamp('2010-08-10 00:00:00'),
#    'subtype': 'H7N3',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American green-winged teal/Wisconsin/10OS3127/2010',
#   {'isolation_date': Timestamp('2010-10-20 00:00:00'),
#    'subtype': 'H5N2',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'Wisconsin'}),
#  ('A/mallard/Interior Alaska/10BM12383R0/2010',
#   {'isolation_date': Timestamp('2010-08-14 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American green-winged teal/Wisconsin/10OS3093/2010',
#   {'isolation_date': Timestamp('2010-10-03 00:00:00'),
#    'subtype': '(N6)',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'Wisconsin'}),
#  ('A/blue-winged Teal/Minnesota/AI09-3786/2009',
#   {'isolation_date': Timestamp('2009-09-06 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Blue-Winged Teal/Avian',
#    'state': 'Minnesota'}),
#  ('A/American black duck/New Brunswick/00322/2010',
#   {'isolation_date': Timestamp('2010-08-08 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/northern pintail/Interior Alaska/9BM6039R0/2009',
#   {'isolation_date': Timestamp('2009-08-02 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/9BM6886R0/2009',
#   {'isolation_date': Timestamp('2009-08-10 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American green-winged teal/Interior Alaska/9BM4407R0/2009',
#   {'isolation_date': Timestamp('2009-07-27 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Green-Winged Teal/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/10BM10480R0/2010',
#   {'isolation_date': Timestamp('2010-08-09 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American black duck/New Brunswick/03553/2009',
#   {'isolation_date': Timestamp('2009-09-11 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/American green-winged teal/Illinois/10OS1598/2010',
#   {'isolation_date': Timestamp('2010-09-05 00:00:00'),
#    'subtype': 'H4N8',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'Illinois'}),
#  ('A/mallard/Illinois/4124/2009',
#   {'isolation_date': Timestamp('2009-11-29 00:00:00'),
#    'subtype': 'H4N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Illinois'}),
#  ('A/northern pintail/Illinois/10OS3959/2010',
#   {'isolation_date': Timestamp('2010-11-21 00:00:00'),
#    'subtype': 'H7N3',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Illinois'}),
#  ('A/mallard/Interior Alaska/9BM2241R1/2009',
#   {'isolation_date': Timestamp('2009-07-11 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/blue-winged teal/Wisconsin/2720/2009',
#   {'isolation_date': Timestamp('2009-10-17 00:00:00'),
#    'subtype': 'H3N2',
#    'host': 'IRD:Blue-Winged Teal/Avian',
#    'state': 'Wisconsin'}),
#  ('A/mallard/New Jersey/AI09-6434/2009',
#   {'isolation_date': Timestamp('2009-09-28 00:00:00'),
#    'subtype': 'H6N2',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'New Jersey'}),
#  ('A/northern shoveler/California/6535/2009',
#   {'isolation_date': Timestamp('2009-10-24 00:00:00'),
#    'subtype': 'H9N2',
#    'host': 'IRD:Northern Shoveler/Avian',
#    'state': 'California'}),
#  ('A/mallard/California/3134/2010',
#   {'isolation_date': Timestamp('2010-11-24 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'California'}),
#  ('A/northern pintail/Interior Alaska/10BM08920R0/2010',
#   {'isolation_date': Timestamp('2010-08-05 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Minnesota/AI09-2519/2009',
#   {'isolation_date': Timestamp('2009-09-06 00:00:00'),
#    'subtype': 'H3N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Minnesota'}),
#  ('A/mallard/California/1210/2010',
#   {'isolation_date': Timestamp('2010-07-29 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'California'}),
#  ('A/American wigeon/California/2997/2010',
#   {'isolation_date': Timestamp('2010-11-17 00:00:00'),
#    'subtype': 'H6N1',
#    'host': 'IRD:American Wigeon/Avian',
#    'state': 'California'}),
#  ('A/mallard/Interior Alaska/9BM12198R0/2009',
#   {'isolation_date': Timestamp('2009-08-21 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/9BM9065R0/2009',
#   {'isolation_date': Timestamp('2009-08-11 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/New Jersey/AI09-5086/2009',
#   {'isolation_date': Timestamp('2009-09-28 00:00:00'),
#    'subtype': '(H4)',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'New Jersey'}),
#  ('A/blue-winged teal/Wisconsin/2649/2009',
#   {'isolation_date': Timestamp('2009-10-17 00:00:00'),
#    'subtype': 'H6N1',
#    'host': 'IRD:Blue-Winged Teal/Avian',
#    'state': 'Wisconsin'}),
#  ('A/mallard/New Brunswick/00492/2010',
#   {'isolation_date': Timestamp('2010-08-12 00:00:00'),
#    'subtype': '(H3)',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'New Brunswick'}),
#  ('A/mallard/Mississippi/390/2010',
#   {'isolation_date': Timestamp('2010-01-17 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Mississippi'}),
#  ('A/northern pintail/Interior Alaska/9BM11556R0/2009',
#   {'isolation_date': Timestamp('2009-08-19 00:00:00'),
#    'subtype': 'H8N4',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American black duck/New Brunswick/00614/2010',
#   {'isolation_date': Timestamp('2010-08-16 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/northern pintail/Interior Alaska/9BM4989R0/2009',
#   {'isolation_date': Timestamp('2009-07-29 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/ruddy turnstone/New Jersey/AI09-294/2009',
#   {'isolation_date': Timestamp('2009-05-11 00:00:00'),
#    'subtype': 'H13N6',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'New Jersey'}),
#  ('A/blue-winged teal/Nova Scotia/00077/2010',
#   {'isolation_date': Timestamp('2010-09-07 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Teal/Avian',
#    'state': 'Nova Scotia'}),
#  ('A/mallard/Interior Alaska/9BM9335R0/2009',
#   {'isolation_date': Timestamp('2009-08-12 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/New Brunswick/00341/2010',
#   {'isolation_date': Timestamp('2010-08-08 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'New Brunswick'}),
#  ('A/long-tailed duck/Wisconsin/10OS3919/2010',
#   {'isolation_date': Timestamp('2010-11-16 00:00:00'),
#    'subtype': 'H10N6',
#    'host': 'IRD:Duck/Avian',
#    'state': 'Wisconsin'}),
#  ('A/northern pintail/Interior Alaska/9BM8273R0/2009',
#   {'isolation_date': Timestamp('2009-08-09 00:00:00'),
#    'subtype': 'H10N4',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/9BM9129R0/2009',
#   {'isolation_date': Timestamp('2009-08-12 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American black duck/Nova Scotia/00099/2010',
#   {'isolation_date': Timestamp('2010-09-10 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'Nova Scotia'}),
#  ('A/American green-winged teal/Interior Alaska/9BM5045R0/2009',
#   {'isolation_date': Timestamp('2009-07-29 00:00:00'),
#    'subtype': 'H8N4',
#    'host': 'IRD:Green-Winged Teal/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/9BM8921R0/2009',
#   {'isolation_date': Timestamp('2009-08-11 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Illinois/10OS3659/2010',
#   {'isolation_date': Timestamp('2010-10-31 00:00:00'),
#    'subtype': 'H11N2',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Illinois'}),
#  ('A/shorebird/Delaware Bay/478/2009',
#   {'isolation_date': Timestamp('2009-05-21 00:00:00'),
#    'subtype': 'H6N1',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware Bay'}),
#  ('A/shorebird/Delaware Bay/132/2009',
#   {'isolation_date': Timestamp('2009-05-20 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware Bay'}),
#  ('A/mallard/Interior Alaska/9BM11542R0/2009',
#   {'isolation_date': Timestamp('2009-08-19 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Wisconsin/10OS2538/2010',
#   {'isolation_date': Timestamp('2010-09-26 00:00:00'),
#    'subtype': 'H3N2',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Wisconsin'}),
#  ('A/shorebird/Delaware Bay/170/2009',
#   {'isolation_date': Timestamp('2009-05-20 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware Bay'}),
#  ('A/mallard/California/5351/2009',
#   {'isolation_date': Timestamp('2009-08-04 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'California'}),
#  ('A/mallard/Minnesota/AI09-4324/2009',
#   {'isolation_date': Timestamp('2009-09-15 00:00:00'),
#    'subtype': '(N8)',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Minnesota'}),
#  ('A/northern pintail/Interior Alaska/9BM7496R0/2009',
#   {'isolation_date': Timestamp('2009-08-08 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American black duck/New Brunswick/00410/2010',
#   {'isolation_date': Timestamp('2010-08-10 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/mallard/Minnesota/AI10-2762/2010',
#   {'isolation_date': Timestamp('2010-09-01 00:00:00'),
#    'subtype': 'H11N9',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Minnesota'}),
#  ('A/northern shoveler/Interior Alaska/10BM05487R0/2010',
#   {'isolation_date': Timestamp('2010-07-26 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Shoveler/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/10BM05337R0/2010',
#   {'isolation_date': Timestamp('2010-07-24 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Ohio/10OS1319/2010',
#   {'isolation_date': Timestamp('2010-08-02 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Ohio'}),
#  ('A/northern pintail/Interior Alaska/9BM12066R1/2009',
#   {'isolation_date': Timestamp('2009-08-20 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American black duck/New Brunswick/03395/2009',
#   {'isolation_date': Timestamp('2009-08-09 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/American green-winged teal/Illinois/10OS3329/2010',
#   {'isolation_date': Timestamp('2010-10-30 00:00:00'),
#    'subtype': 'H7N7',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'Illinois'}),
#  ('A/American green-winged teal/Interior Alaska/9BM6222R0/2009',
#   {'isolation_date': Timestamp('2009-08-03 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:American Green-winged Teal/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/9BM10222R0/2009',
#   {'isolation_date': Timestamp('2009-08-16 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/10BM02111R0/2010',
#   {'isolation_date': Timestamp('2010-06-10 00:00:00'),
#    'subtype': 'H12N5',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/10BM09162R0/2010',
#   {'isolation_date': Timestamp('2010-08-06 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/9BM12190R0/2009',
#   {'isolation_date': Timestamp('2009-08-21 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/9BM11564R0/2009',
#   {'isolation_date': Timestamp('2009-08-19 00:00:00'),
#    'subtype': 'H10N4',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American black duck/Prince Edward Island/00673/2010',
#   {'isolation_date': Timestamp('2010-08-04 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'Prince Edward Island'}),
#  ('A/mallard/Interior Alaska/10BM11419R0/2010',
#   {'isolation_date': Timestamp('2010-08-12 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/green-winged teal/Prince Edward Island/00839/2010',
#   {'isolation_date': Timestamp('2010-09-02 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'Prince Edward Island'}),
#  ('A/American green-winged teal/Interior Alaska/10BM08222R0/2010',
#   {'isolation_date': Timestamp('2010-08-04 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/green-winged teal/New Brunswick/00333/2010',
#   {'isolation_date': Timestamp('2010-08-08 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'New Brunswick'}),
#  ('A/northern pintail/Interior Alaska/9BM7846R0/2009',
#   {'isolation_date': Timestamp('2009-08-08 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/California/1305/2010',
#   {'isolation_date': Timestamp('2010-08-03 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'California'}),
#  ('A/northern pintail/Interior Alaska/10BM10809R0/2010',
#   {'isolation_date': Timestamp('2010-08-10 00:00:00'),
#    'subtype': 'H7N3',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Wisconsin/10OS2667/2010',
#   {'isolation_date': Timestamp('2010-10-01 00:00:00'),
#    'subtype': 'H11N9',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Wisconsin'}),
#  ('A/American black duck/New Brunswick/03451/2009',
#   {'isolation_date': Timestamp('2009-08-12 00:00:00'),
#    'subtype': 'H3N9',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/mallard/Mississippi/354/2010',
#   {'isolation_date': Timestamp('2010-01-16 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Mississippi'}),
#  ('A/blue-winged teal/New Brunswick/00288/2010',
#   {'isolation_date': Timestamp('2010-09-14 00:00:00'),
#    'subtype': 'H5N2',
#    'host': 'IRD:Teal/Avian',
#    'state': 'New Brunswick'}),
#  ('A/American green-winged teal/Interior Alaska/10BM08422R0/2010',
#   {'isolation_date': Timestamp('2010-08-04 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/herring gull/New Jersey/AI09-1262/2009',
#   {'isolation_date': Timestamp('2009-06-10 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Herring Gull/Avian',
#    'state': 'New Jersey'}),
#  ('A/hooded merganser/New Brunswick/03749/2009',
#   {'isolation_date': Timestamp('2009-09-14 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Hooded Merganser/Avian',
#    'state': 'New Brunswick'}),
#  ('A/American black duck/New Brunswick/00525/2010',
#   {'isolation_date': Timestamp('2010-08-13 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/American black duck/Nova Scotia/00090/2010',
#   {'isolation_date': Timestamp('2010-09-10 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'Nova Scotia'}),
#  ('A/American black duck/Illinois/4119/2009',
#   {'isolation_date': Timestamp('2009-11-29 00:00:00'),
#    'subtype': 'H8N4',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'Illinois'}),
#  ('A/mallard/Interior Alaska/9BM12285R0/2009',
#   {'isolation_date': Timestamp('2009-09-01 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/10BM11366R0/2010',
#   {'isolation_date': Timestamp('2010-08-12 00:00:00'),
#    'subtype': 'H7N3',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/blue-winged teal/New Brunswick/00595/2010',
#   {'isolation_date': Timestamp('2010-08-15 00:00:00'),
#    'subtype': 'H3N7',
#    'host': 'IRD:Teal/Avian',
#    'state': 'New Brunswick'}),
#  ('A/mallard/New Brunswick/00494/2010',
#   {'isolation_date': Timestamp('2010-08-12 00:00:00'),
#    'subtype': '(N8)',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'New Brunswick'}),
#  ('A/blue-winged teal/Wisconsin/3060/2009',
#   {'isolation_date': Timestamp('2009-10-17 00:00:00'),
#    'subtype': 'H3N2',
#    'host': 'IRD:Blue-Winged Teal/Avian',
#    'state': 'Wisconsin'}),
#  ('A/common goldeneye/Wisconsin/10OS4202/2010',
#   {'isolation_date': Timestamp('2010-12-02 00:00:00'),
#    'subtype': 'H7N6',
#    'host': 'IRD:Common Goldeneye/Avian',
#    'state': 'Wisconsin'}),
#  ('A/mallard/Interior Alaska/9BM1869/2009',
#   {'isolation_date': Timestamp('2009-07-01 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/9BM12204R0/2009',
#   {'isolation_date': Timestamp('2009-08-21 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Wisconsin/10OS3845/2010',
#   {'isolation_date': Timestamp('2010-11-12 00:00:00'),
#    'subtype': 'H5N2',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Wisconsin'}),
#  ('A/mallard/Interior Alaska/9BM3205R0/2009',
#   {'isolation_date': Timestamp('2009-07-20 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/blue-winged teal/New Brunswick/00768/2010',
#   {'isolation_date': Timestamp('2010-08-25 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Teal/Avian',
#    'state': 'New Brunswick'}),
#  ('A/northern pintail/California/3452/2010',
#   {'isolation_date': Timestamp('2010-12-04 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'California'}),
#  ('A/American green-winged teal/Interior Alaska/10BM05440R0/2010',
#   {'isolation_date': Timestamp('2010-07-26 00:00:00'),
#    'subtype': '(H3)',
#    'host': 'IRD:Green-Winged Teal/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern shoveler/Mississippi/236/2010',
#   {'isolation_date': Timestamp('2010-01-12 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Northern Shoveler/Avian',
#    'state': 'Mississippi'}),
#  ('A/mallard/Ohio/10OS1469/2010',
#   {'isolation_date': Timestamp('2010-08-18 00:00:00'),
#    'subtype': 'H3N2',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Ohio'}),
#  ('A/mallard/Interior Alaska/10BM08883R0/2010',
#   {'isolation_date': Timestamp('2010-08-05 00:00:00'),
#    'subtype': 'H7N3',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American black duck/New Brunswick/00620/2010',
#   {'isolation_date': Timestamp('2010-08-16 00:00:00'),
#    'subtype': 'H3N6',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/northern shoveler/Interior Alaska/9BM2925R0/2009',
#   {'isolation_date': Timestamp('2009-07-16 00:00:00'),
#    'subtype': 'H8N4',
#    'host': 'IRD:Northern Shoveler/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern shoveler/Interior Alaska/9BM4905R0/2009',
#   {'isolation_date': Timestamp('2009-07-29 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Northern Shoveler/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Arkansas/AI09-5761/2009',
#   {'isolation_date': Timestamp('2009-12-11 00:00:00'),
#    'subtype': 'H2N3',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Arkansas'}),
#  ('A/mallard/Missouri/10MO084/2010',
#   {'isolation_date': Timestamp('2010-11-16 00:00:00'),
#    'subtype': 'H5N9',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Missouri'}),
#  ('A/ruddy turnstone/New Jersey/AI09-907/2009',
#   {'isolation_date': Timestamp('2009-05-29 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'New Jersey'}),
#  ('A/American green-winged teal/Illinois/10OS4014/2010',
#   {'isolation_date': Timestamp('2010-11-27 00:00:00'),
#    'subtype': 'H7N3',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'Illinois'}),
#  ('A/northern pintail/Interior Alaska/9BM7118R1/2009',
#   {'isolation_date': Timestamp('2009-08-06 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/California/1523/2010',
#   {'isolation_date': Timestamp('2010-08-11 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'California'}),
#  ('A/mallard/Interior Alaska/9BM2536R0/2009',
#   {'isolation_date': Timestamp('2009-07-13 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/10BM07114R0/2010',
#   {'isolation_date': Timestamp('2010-08-01 00:00:00'),
#    'subtype': 'H7N3',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/10BM02644R0/2010',
#   {'isolation_date': Timestamp('2010-06-25 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American green-winged teal/Illinois/3054/2009',
#   {'isolation_date': Timestamp('2009-10-17 00:00:00'),
#    'subtype': 'H1N2',
#    'host': 'IRD:Green-Winged Teal/Avian',
#    'state': 'Illinois'}),
#  ('A/gadwall/Iowa/10OS2753/2010',
#   {'isolation_date': Timestamp('2010-10-17 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Gadwall/Avian',
#    'state': 'Iowa'}),
#  ('A/gull/Delaware/AI09-438/2009',
#   {'isolation_date': Timestamp('2009-05-28 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Gull/Avian',
#    'state': 'Delaware'}),
#  ('A/shorebird/Delaware Bay/111/2009',
#   {'isolation_date': Timestamp('2009-05-20 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware Bay'}),
#  ('A/blue-winged teal/Guatemala/CIP049-04/2010',
#   {'isolation_date': Timestamp('2010-01-31 00:00:00'),
#    'subtype': 'H8N4',
#    'host': 'IRD:Blue-Winged Teal/Avian',
#    'state': 'Guatemala'}),
#  ('A/mallard/Minnesota/AI09-2509/2009',
#   {'isolation_date': Timestamp('2009-09-06 00:00:00'),
#    'subtype': 'H6N1',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Minnesota'}),
#  ('A/blue-winged teal/Prince Edward Island/03910/2009',
#   {'isolation_date': Timestamp('2009-08-19 00:00:00'),
#    'subtype': 'H4N9',
#    'host': 'IRD:Blue-Winged Teal/Avian',
#    'state': 'Prince Edward Island'}),
#  ('A/gadwall/Missouri/10OS4731/2010',
#   {'isolation_date': Timestamp('2010-12-12 00:00:00'),
#    'subtype': 'H7N3',
#    'host': 'IRD:Gadwall/Avian',
#    'state': 'Missouri'}),
#  ('A/mallard/Arkansas/AI09-5944/2009',
#   {'isolation_date': Timestamp('2009-12-10 00:00:00'),
#    'subtype': 'H4N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Arkansas'}),
#  ('A/blue-winged teal/New Brunswick/00775/2010',
#   {'isolation_date': Timestamp('2010-08-25 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Teal/Avian',
#    'state': 'New Brunswick'}),
#  ('A/mallard/Interior Alaska/10BM06456R0/2010',
#   {'isolation_date': Timestamp('2010-07-30 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American black duck/New Brunswick/00886/2010',
#   {'isolation_date': Timestamp('2010-09-13 00:00:00'),
#    'subtype': 'H4N9',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/gadwall/Illinois/10OS3342/2010',
#   {'isolation_date': Timestamp('2010-10-30 00:00:00'),
#    'subtype': 'H6N1',
#    'host': 'IRD:Gadwall/Avian',
#    'state': 'Illinois'}),
#  ('A/northern pintail/Interior Alaska/10BM06704R0/2010',
#   {'isolation_date': Timestamp('2010-07-30 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/9BM2168/2009',
#   {'isolation_date': Timestamp('2009-07-10 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/10BM08488R0/2010',
#   {'isolation_date': Timestamp('2010-08-04 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/10BM11420R0/2010',
#   {'isolation_date': Timestamp('2010-08-12 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Mississippi/407/2010',
#   {'isolation_date': Timestamp('2010-01-16 00:00:00'),
#    'subtype': '(N2)',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Mississippi'}),
#  ('A/northern pintail/Interior Alaska/10BM07476R0/2010',
#   {'isolation_date': Timestamp('2010-08-02 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/blue-winged teal/Wisconsin/2753/2009',
#   {'isolation_date': Timestamp('2009-10-24 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Blue-Winged Teal/Avian',
#    'state': 'Wisconsin'}),
#  ('A/American black duck/New Brunswick/03552/2009',
#   {'isolation_date': Timestamp('2009-09-11 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/northern pintail/Interior Alaska/10BM08903R0/2010',
#   {'isolation_date': Timestamp('2010-08-05 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/California/5192/2009',
#   {'isolation_date': Timestamp('2009-07-27 00:00:00'),
#    'subtype': 'H4N2',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'California'}),
#  ('A/northern pintail/Interior Alaska/10BM08489R0/2010',
#   {'isolation_date': Timestamp('2010-08-04 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/ruddy turnstone/Delaware/AI09-1268/2009',
#   {'isolation_date': Timestamp('2009-06-02 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'Delaware'}),
#  ('A/mallard/Interior Alaska/9BM10111R0/2009',
#   {'isolation_date': Timestamp('2009-08-15 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/9BM1585R1/2009',
#   {'isolation_date': Timestamp('2009-06-24 00:00:00'),
#    'subtype': 'H12N5',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/New Brunswick/00593/2010',
#   {'isolation_date': Timestamp('2010-08-15 00:00:00'),
#    'subtype': 'H3N7',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'New Brunswick'}),
#  ('A/American green-winged teal/Interior Alaska/10BM08226R0/2010',
#   {'isolation_date': Timestamp('2010-08-04 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/9BM6510R0/2009',
#   {'isolation_date': Timestamp('2009-08-04 00:00:00'),
#    'subtype': 'H8N4',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/ruddy turnstone/New Jersey/AI09-961/2009',
#   {'isolation_date': Timestamp('2009-05-22 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'New Jersey'}),
#  ('A/green-winged teal/Prince Edward Island/00838/2010',
#   {'isolation_date': Timestamp('2010-09-02 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'Prince Edward Island'}),
#  ('A/mallard/Interior Alaska/9BM12390R0/2009',
#   {'isolation_date': Timestamp('2009-09-02 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American green-winged teal/Interior Alaska/10BM05376R0/2010',
#   {'isolation_date': Timestamp('2010-07-25 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Green-Winged Teal/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/blue-winged Teal/North Dakota/AI09-3131/2009',
#   {'isolation_date': Timestamp('2009-09-03 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Blue-Winged Teal/Avian',
#    'state': 'North Dakota'}),
#  ('A/blue-winged teal/Prince Edward Island/00803/2010',
#   {'isolation_date': Timestamp('2010-09-01 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Teal/Avian',
#    'state': 'Prince Edward Island'}),
#  ('A/northern pintail/Interior Alaska/9BM8967R0/2009',
#   {'isolation_date': Timestamp('2009-08-11 00:00:00'),
#    'subtype': 'H8N4',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/9BM10370R0/2009',
#   {'isolation_date': Timestamp('2009-08-17 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American green-winged teal/Wisconsin/10OS2955/2010',
#   {'isolation_date': Timestamp('2010-10-03 00:00:00'),
#    'subtype': 'H5N2',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'Wisconsin'}),
#  ('A/ruddy turnstone/Delaware/AI09-467/2009',
#   {'isolation_date': Timestamp('2009-05-28 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'Delaware'}),
#  ('A/northern pintail/Mississippi/10OS4521/2010',
#   {'isolation_date': Timestamp('2010-12-10 00:00:00'),
#    'subtype': '(H4)',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Mississippi'}),
#  ('A/northern pintail/Interior Alaska/9BM3859R1/2009',
#   {'isolation_date': Timestamp('2009-07-24 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/California/5149/2009',
#   {'isolation_date': Timestamp('2009-07-25 00:00:00'),
#    'subtype': 'H5N2',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'California'}),
#  ('A/northern pintail/Wisconsin/2737/2009',
#   {'isolation_date': Timestamp('2009-10-17 00:00:00'),
#    'subtype': 'H3N2',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Wisconsin'}),
#  ('A/northern shoveler/Missouri/10OS4750/2010',
#   {'isolation_date': Timestamp('2010-12-12 00:00:00'),
#    'subtype': 'H7N3',
#    'host': 'IRD:Northern Shoveler/Avian',
#    'state': 'Missouri'}),
#  ('A/northern pintail/Interior Alaska/10BM12413R0/2010',
#   {'isolation_date': Timestamp('2010-08-14 00:00:00'),
#    'subtype': 'H8N4',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/ruddy turnstone/New Jersey/AI09-620/2009',
#   {'isolation_date': Timestamp('2009-05-22 00:00:00'),
#    'subtype': 'H11N1',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'New Jersey'}),
#  ('A/blue-winged teal/Nova Scotia/00126/2010',
#   {'isolation_date': Timestamp('2010-09-10 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Teal/Avian',
#    'state': 'Nova Scotia'}),
#  ('A/American wigeon/California/3180/2010',
#   {'isolation_date': Timestamp('2010-11-27 00:00:00'),
#    'subtype': 'H5N2',
#    'host': 'IRD:American Wigeon/Avian',
#    'state': 'California'}),
#  ('A/mallard/Nova Scotia/00372/2010',
#   {'isolation_date': Timestamp('2010-08-08 00:00:00'),
#    'subtype': 'H7N7',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Nova Scotia'}),
#  ('A/blue-winged teal/Nova Scotia/00121/2010',
#   {'isolation_date': Timestamp('2010-09-10 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Teal/Avian',
#    'state': 'Nova Scotia'}),
#  ('A/mallard/Wisconsin/4194/2009',
#   {'isolation_date': Timestamp('2009-12-03 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Wisconsin'}),
#  ('A/gull/Southeastern Alaska/10JR01527R0/2010',
#   {'isolation_date': Timestamp('2010-08-12 00:00:00'),
#    'subtype': 'H16N3',
#    'host': 'IRD:Gull/Avian',
#    'state': 'Southeastern Alaska'}),
#  ('A/mallard/Interior Alaska/10BM12350R0/2010',
#   {'isolation_date': Timestamp('2010-08-14 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/9BM2535R0/2009',
#   {'isolation_date': Timestamp('2009-07-12 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/glaucous-winged gull/Southeastern Alaska/9JR0822R0/2009',
#   {'isolation_date': Timestamp('2009-08-19 00:00:00'),
#    'subtype': 'H13N6',
#    'host': 'IRD:Gull/Avian',
#    'state': 'Southeastern Alaska'}),
#  ('A/blue-winged Teal/North Dakota/AI09-3760/2009',
#   {'isolation_date': Timestamp('2009-09-04 00:00:00'),
#    'subtype': 'H7N3',
#    'host': 'IRD:Blue-Winged Teal/Avian',
#    'state': 'North Dakota'}),
#  ('A/laughing gull/New Jersey/AI09-271/2009',
#   {'isolation_date': Timestamp('2009-05-15 00:00:00'),
#    'subtype': 'H11N1',
#    'host': 'IRD:Laughing Gull/Avian',
#    'state': 'New Jersey'}),
#  ('A/northern pintail/Interior Alaska/10BM12146R0/2010',
#   {'isolation_date': Timestamp('2010-08-13 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/9BM10238R0/2009',
#   {'isolation_date': Timestamp('2009-08-16 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/shorebird/Delaware Bay/226/2009',
#   {'isolation_date': Timestamp('2009-05-20 00:00:00'),
#    'subtype': 'H1N7',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware Bay'}),
#  ('A/mallard/Interior Alaska/9BM11382R0/2009',
#   {'isolation_date': Timestamp('2009-08-18 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/9BM7368R0/2009',
#   {'isolation_date': Timestamp('2009-08-07 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/9BM10851R0/2009',
#   {'isolation_date': Timestamp('2009-08-17 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/10BM06447R0/2010',
#   {'isolation_date': Timestamp('2010-07-30 00:00:00'),
#    'subtype': '(H3)',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/shorebird/Delaware Bay/289/2009',
#   {'isolation_date': Timestamp('2009-05-20 00:00:00'),
#    'subtype': '(N1)',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware Bay'}),
#  ('A/mallard/Missouri/10MO0551/2010',
#   {'isolation_date': Timestamp('2010-12-29 00:00:00'),
#    'subtype': 'H7N7',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Missouri'}),
#  ('A/mallard/Michigan/10OS1491/2010',
#   {'isolation_date': Timestamp('2010-08-20 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Michigan'}),
#  ('A/northern shoveler/Mississippi/252/2010',
#   {'isolation_date': Timestamp('2010-01-10 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Northern Shoveler/Avian',
#    'state': 'Mississippi'}),
#  ('A/mallard/Alberta/413/2009',
#   {'isolation_date': Timestamp('2009-08-22 00:00:00'),
#    'subtype': '(H6)',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Alberta'}),
#  ('A/mallard/Interior Alaska/9BM1967/2009',
#   {'isolation_date': Timestamp('2009-07-06 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Ohio/10OS1470/2010',
#   {'isolation_date': Timestamp('2010-08-18 00:00:00'),
#    'subtype': 'H3N2',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Ohio'}),
#  ('A/northern pintail/Interior Alaska/10BM00849R2/2010',
#   {'isolation_date': Timestamp('2010-05-23 00:00:00'),
#    'subtype': 'H3N1',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/9BM11487R0/2009',
#   {'isolation_date': Timestamp('2009-08-18 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/10BM12370R0/2010',
#   {'isolation_date': Timestamp('2010-08-14 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Missouri/10MO0550/2010',
#   {'isolation_date': Timestamp('2010-12-29 00:00:00'),
#    'subtype': 'H11N3',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Missouri'}),
#  ('A/mallard/Wisconsin/10OS2659/2010',
#   {'isolation_date': Timestamp('2010-10-02 00:00:00'),
#    'subtype': 'H4N2',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Wisconsin'}),
#  ('A/shorebird/Delaware Bay/549/2009',
#   {'isolation_date': Timestamp('2009-05-21 00:00:00'),
#    'subtype': 'H11N1',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware Bay'}),
#  ('A/mallard/Iowa/10OS2420/2010',
#   {'isolation_date': Timestamp('2010-09-18 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Iowa'}),
#  ('A/shorebird/Delaware Bay/545/2009',
#   {'isolation_date': Timestamp('2009-05-21 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware Bay'}),
#  ('A/northern pintail/Interior Alaska/9BM7696R0/2009',
#   {'isolation_date': Timestamp('2009-08-08 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/New Brunswick/00324/2010',
#   {'isolation_date': Timestamp('2010-08-08 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'New Brunswick'}),
#  ('A/mallard/California/1297/2010',
#   {'isolation_date': Timestamp('2010-07-30 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'California'}),
#  ('A/northern shoveler/Missouri/10OS4700/2010',
#   {'isolation_date': Timestamp('2010-12-12 00:00:00'),
#    'subtype': '(N3)',
#    'host': 'IRD:Northern Shoveler/Avian',
#    'state': 'Missouri'}),
#  ('A/mallard/Interior Alaska/9BM10047R0/2009',
#   {'isolation_date': Timestamp('2009-08-15 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/ruddy turnstone/New Jersey/AI09-119/2009',
#   {'isolation_date': Timestamp('2009-05-20 00:00:00'),
#    'subtype': 'H1N8',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'New Jersey'}),
#  ('A/northern pintail/Interior Alaska/9BM9447R0/2009',
#   {'isolation_date': Timestamp('2009-08-13 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Iowa/10OS2492/2010',
#   {'isolation_date': Timestamp('2010-09-18 00:00:00'),
#    'subtype': 'H3N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Iowa'}),
#  ('A/mallard/California/5502/2009',
#   {'isolation_date': Timestamp('2009-07-23 00:00:00'),
#    'subtype': 'H5N2',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'California'}),
#  ('A/shorebird/Delaware Bay/55/2009',
#   {'isolation_date': Timestamp('2009-05-15 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware Bay'}),
#  ('A/gull/Delaware/428/2009',
#   {'isolation_date': Timestamp('2009-05-21 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Gull/Avian',
#    'state': 'Delaware'}),
#  ('A/ruddy turnstone/New Jersey/AI09-618/2009',
#   {'isolation_date': Timestamp('2009-05-26 00:00:00'),
#    'subtype': 'H1N9',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'New Jersey'}),
#  ('A/American black duck/New Brunswick/00986/2010',
#   {'isolation_date': Timestamp('2010-09-16 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/northern shoveler/Illinois/3767/2009',
#   {'isolation_date': Timestamp('2009-11-14 00:00:00'),
#    'subtype': '(N5)',
#    'host': 'IRD:Northern Shoveler/Avian',
#    'state': 'Illinois'}),
#  ('A/mallard/Interior Alaska/9BM2783R0/2009',
#   {'isolation_date': Timestamp('2009-07-15 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/environment/California/5807/2009',
#   {'isolation_date': Timestamp('2009-08-31 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Environment',
#    'state': 'California'}),
#  ('A/blue-winged teal/Nova Scotia/00074/2010',
#   {'isolation_date': Timestamp('2010-09-07 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Teal/Avian',
#    'state': 'Nova Scotia'}),
#  ('A/northern shoveler/Wisconsin/10OS3226/2010',
#   {'isolation_date': Timestamp('2010-11-10 00:00:00'),
#    'subtype': 'H7N3',
#    'host': 'IRD:Northern Shoveler/Avian',
#    'state': 'Wisconsin'}),
#  ('A/American green-winged teal/Wisconsin/2743/2009',
#   {'isolation_date': Timestamp('2009-10-17 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Green-Winged Teal/Avian',
#    'state': 'Wisconsin'}),
#  ('A/blue-winged teal/Wisconsin/2741/2009',
#   {'isolation_date': Timestamp('2009-10-17 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Teal/Avian',
#    'state': 'Wisconsin'}),
#  ('A/ruddy turnstone/New Jersey/AI09-071/2009',
#   {'isolation_date': Timestamp('2009-05-11 00:00:00'),
#    'subtype': '(N1)',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'New Jersey'}),
#  ('A/northern pintail/Interior Alaska/9BM6164R0/2009',
#   {'isolation_date': Timestamp('2009-08-02 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Illinois/3747/2009',
#   {'isolation_date': Timestamp('2009-11-14 00:00:00'),
#    'subtype': 'H6N1',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Illinois'}),
#  ('A/mallard/New Brunswick/00337/2010',
#   {'isolation_date': Timestamp('2010-08-08 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'New Brunswick'}),
#  ('A/mallard/Ohio/1686/2009',
#   {'isolation_date': Timestamp('2009-08-10 00:00:00'),
#    'subtype': 'H6N9',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Ohio'}),
#  ('A/mallard/New Brunswick/00495/2010',
#   {'isolation_date': Timestamp('2010-08-12 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'New Brunswick'}),
#  ('A/northern pintail/Interior Alaska/10BM08505R0/2010',
#   {'isolation_date': Timestamp('2010-08-04 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Nova Scotia/00085/2010',
#   {'isolation_date': Timestamp('2010-09-10 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Nova Scotia'}),
#  ('A/northern pintail/Interior Alaska/9BM7620R0/2009',
#   {'isolation_date': Timestamp('2009-08-08 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/10BM08899R0/2010',
#   {'isolation_date': Timestamp('2010-08-05 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/blue-winged teal/Wisconsin/10OS3092/2010',
#   {'isolation_date': Timestamp('2010-10-03 00:00:00'),
#    'subtype': 'H3N6',
#    'host': 'IRD:Teal/Avian',
#    'state': 'Wisconsin'}),
#  ('A/northern pintail/Interior Alaska/9BM11179R0/2009',
#   {'isolation_date': Timestamp('2009-08-18 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American green-winged teal/Mississippi/300/2010',
#   {'isolation_date': Timestamp('2010-01-16 00:00:00'),
#    'subtype': 'H11N9',
#    'host': 'IRD:Green-Winged Teal/Avian',
#    'state': 'Mississippi'}),
#  ('A/mallard/Interior Alaska/10BM08120R0/2010',
#   {'isolation_date': Timestamp('2010-08-04 00:00:00'),
#    'subtype': 'H7N3',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern shoveler/Illinois/10OS3619/2010',
#   {'isolation_date': Timestamp('2010-10-30 00:00:00'),
#    'subtype': 'H11N9',
#    'host': 'IRD:Northern Shoveler/Avian',
#    'state': 'Illinois'}),
#  ('A/mallard/Nova Scotia/00778/2010',
#   {'isolation_date': Timestamp('2010-09-07 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Nova Scotia'}),
#  ('A/northern pintail/Interior Alaska/9BM11911R0/2009',
#   {'isolation_date': Timestamp('2009-08-19 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Minnesota/AI09-3100/2009',
#   {'isolation_date': Timestamp('2009-09-08 00:00:00'),
#    'subtype': 'H6N3',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Minnesota'}),
#  ('A/blue-winged teal/New Brunswick/00765/2010',
#   {'isolation_date': Timestamp('2010-08-25 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Teal/Avian',
#    'state': 'New Brunswick'}),
#  ('A/blue-winged teal/Guatemala/CIP049-08/2010',
#   {'isolation_date': Timestamp('2010-01-31 00:00:00'),
#    'subtype': 'H5N3',
#    'host': 'IRD:Blue-Winged Teal/Avian',
#    'state': 'Guatemala'}),
#  ('A/American green-winged teal/Interior Alaska/9BM6223R0/2009',
#   {'isolation_date': Timestamp('2009-08-03 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:American Green-winged Teal/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/9BM1972/2009',
#   {'isolation_date': Timestamp('2009-07-06 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/9BM7632R0/2009',
#   {'isolation_date': Timestamp('2009-08-08 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/blue-winged teal/Prince Edward Island/00849/2010',
#   {'isolation_date': Timestamp('2010-09-03 00:00:00'),
#    'subtype': 'H6N1',
#    'host': 'IRD:Teal/Avian',
#    'state': 'Prince Edward Island'}),
#  ('A/northern pintail/Interior Alaska/9BM11789R0/2009',
#   {'isolation_date': Timestamp('2009-08-19 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/ruddy turnstone/New Jersey/AI09-027/2009',
#   {'isolation_date': Timestamp('2009-05-13 00:00:00'),
#    'subtype': 'H11N1',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'New Jersey'}),
#  ('A/American green-winged teal/Interior Alaska/10BM07000R0/2010',
#   {'isolation_date': Timestamp('2010-07-31 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Green-Winged Teal/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/10BM04623R0/2010',
#   {'isolation_date': Timestamp('2010-07-18 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/shorebird/Delaware Bay/500/2009',
#   {'isolation_date': Timestamp('2009-05-21 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware Bay'}),
#  ('A/northern pintail/Interior Alaska/10BM09101R0/2010',
#   {'isolation_date': Timestamp('2010-08-05 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/ruddy turnstone/New Jersey/AI09-1211/2009',
#   {'isolation_date': Timestamp('2009-06-03 00:00:00'),
#    'subtype': 'H1N9',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'New Jersey'}),
#  ('A/American green-winged teal/Illinois/2975/2009',
#   {'isolation_date': Timestamp('2009-10-17 00:00:00'),
#    'subtype': '(H10)',
#    'host': 'IRD:Green-Winged Teal/Avian',
#    'state': 'Illinois'}),
#  ('A/mallard/Interior Alaska/10BM12311R0/2010',
#   {'isolation_date': Timestamp('2010-08-14 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/9BM1870/2009',
#   {'isolation_date': Timestamp('2009-07-01 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/blue-winged teal/New Brunswick/00772/2010',
#   {'isolation_date': Timestamp('2010-08-25 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Teal/Avian',
#    'state': 'New Brunswick'}),
#  ('A/American black duck/Prince Edward Island/00788/2010',
#   {'isolation_date': Timestamp('2010-08-25 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'Prince Edward Island'}),
#  ('A/mallard/Interior Alaska/10BM07092R0/2010',
#   {'isolation_date': Timestamp('2010-08-01 00:00:00'),
#    'subtype': 'H7N3',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/ruddy turnstone/New Jersey/AI09-1082/2009',
#   {'isolation_date': Timestamp('2009-05-30 00:00:00'),
#    'subtype': 'H1N9',
# ...
#  ('A/blue-winged teal/Missouri/10MO0407/2010',
#   {'isolation_date': Timestamp('2010-09-17 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Teal/Avian',
#    'state': 'Missouri'}),
#  ('A/American black duck/New Brunswick/00991/2010',
#   {'isolation_date': Timestamp('2010-09-16 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/American black duck/Nova Scotia/00086/2010',
#   {'isolation_date': Timestamp('2010-09-10 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'Nova Scotia'}),
#  ('A/gull/New Jersey/AI09-964/2009',
#   {'isolation_date': Timestamp('2009-05-27 00:00:00'),
#    'subtype': 'H1N8',
#    'host': 'IRD:Gull/Avian',
#    'state': 'New Jersey'}),
#  ('A/ruddy turnstone/New Jersey/AI09-474/2009',
#   {'isolation_date': Timestamp('2009-05-29 00:00:00'),
#    'subtype': 'H10N1',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'New Jersey'}),
#  ('A/shorebird/Delaware Bay/756/2009',
#   {'isolation_date': Timestamp('2009-06-04 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware Bay'}),
#  ('A/ruddy turnstone/New Jersey/AI09-944/2009',
#   {'isolation_date': Timestamp('2009-05-22 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'New Jersey'}),
#  ('A/northern pintail/Interior Alaska/9BM7240R0/2009',
#   {'isolation_date': Timestamp('2009-08-06 00:00:00'),
#    'subtype': 'H8N4',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/9BM2705R0/2009',
#   {'isolation_date': Timestamp('2009-07-15 00:00:00'),
#    'subtype': 'H8N4',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/9BM7799R0/2009',
#   {'isolation_date': Timestamp('2009-08-08 00:00:00'),
#    'subtype': 'H4N7',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/blue-winged Teal/North Dakota/AI09-4039/2009',
#   {'isolation_date': Timestamp('2009-09-14 00:00:00'),
#    'subtype': 'H3N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'North Dakota'}),
#  ('A/mallard/Missouri/10MO0333/2010',
#   {'isolation_date': Timestamp('2010-12-22 00:00:00'),
#    'subtype': 'H11N9',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Missouri'}),
#  ('A/blue-winged teal/New Brunswick/00283/2010',
#   {'isolation_date': Timestamp('2010-09-14 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Teal/Avian',
#    'state': 'New Brunswick'}),
#  ('A/northern pintail/Interior Alaska/9BM4347R0/2009',
#   {'isolation_date': Timestamp('2009-07-27 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/10BM12308R0/2010',
#   {'isolation_date': Timestamp('2010-08-14 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American green-winged teal/Wisconsin/10OS2767/2010',
#   {'isolation_date': Timestamp('2010-09-26 00:00:00'),
#    'subtype': 'H6N8',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'Wisconsin'}),
#  ('A/shorebird/Delaware/318/2009',
#   {'isolation_date': Timestamp('2009-05-20 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware'}),
#  ('A/northern shoveler/Interior Alaska/9BM12332R0/2009',
#   {'isolation_date': Timestamp('2009-09-02 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Shoveler/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/American green-winged teal/Interior Alaska/9BM12714R1/2009',
#   {'isolation_date': Timestamp('2009-09-06 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/blue-winged teal/New Brunswick/00289/2010',
#   {'isolation_date': Timestamp('2010-09-14 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Teal/Avian',
#    'state': 'New Brunswick'}),
#  ('A/northern pintail/Interior Alaska/9BM7836R0/2009',
#   {'isolation_date': Timestamp('2009-08-08 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Wisconsin/10OS2773/2010',
#   {'isolation_date': Timestamp('2010-09-26 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Wisconsin'}),
#  ('A/blue-winged Teal/Minnesota/AI09-3575/2009',
#   {'isolation_date': Timestamp('2009-09-12 00:00:00'),
#    'subtype': 'H4N8',
#    'host': 'IRD:Teal/Avian',
#    'state': 'Minnesota'}),
#  ('A/northern pintail/Interior Alaska/9BM7050R0/2009',
#   {'isolation_date': Timestamp('2009-08-06 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/9BM2073/2009',
#   {'isolation_date': Timestamp('2009-07-09 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/shorebird/Delaware Bay/257/2009',
#   {'isolation_date': Timestamp('2009-05-20 00:00:00'),
#    'subtype': 'H11N8',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware Bay'}),
#  ('A/American black duck/New Brunswick/00619/2010',
#   {'isolation_date': Timestamp('2010-08-16 00:00:00'),
#    'subtype': 'H3N6',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/black scoter/New Brunswick/00010/2009',
#   {'isolation_date': Timestamp('2009-05-02 00:00:00'),
#    'subtype': 'H7N6',
#    'host': 'IRD:Black Scoter/Avian',
#    'state': 'New Brunswick'}),
#  ('A/blue-winged teal/Iowa/10OS2649/2010',
#   {'isolation_date': Timestamp('2010-09-18 00:00:00'),
#    'subtype': 'H3N6',
#    'host': 'IRD:Teal/Avian',
#    'state': 'Iowa'}),
#  ('A/ruddy turnstone/New Jersey/AI09-169/2009',
#   {'isolation_date': Timestamp('2009-05-08 00:00:00'),
#    'subtype': 'H11N8',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'New Jersey'}),
#  ('A/American green-winged teal/Texas/AI09-6046/2009',
#   {'isolation_date': Timestamp('2009-12-13 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'Texas'}),
#  ('A/northern shoveler/California/3183/2010',
#   {'isolation_date': Timestamp('2010-11-27 00:00:00'),
#    'subtype': 'H11N2',
#    'host': 'IRD:Northern Shoveler/Avian',
#    'state': 'California'}),
#  ('A/mallard/Minnesota/AI09-1833/2009',
#   {'isolation_date': Timestamp('2009-07-28 00:00:00'),
#    'subtype': 'H8N4',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Minnesota'}),
#  ('A/blue-winged teal/Wisconsin/2572/2009',
#   {'isolation_date': Timestamp('2009-10-06 00:00:00'),
#    'subtype': 'H2N3',
#    'host': 'IRD:Blue-Winged Teal/Avian',
#    'state': 'Wisconsin'}),
#  ('A/northern pintail/Interior Alaska/9BM8803R0/2009',
#   {'isolation_date': Timestamp('2009-08-11 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Minnesota/AI09-1870/2009',
#   {'isolation_date': Timestamp('2009-07-28 00:00:00'),
#    'subtype': 'H3N3',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Minnesota'}),
#  ('A/northern pintail/Interior Alaska/9BM10210R0/2009',
#   {'isolation_date': Timestamp('2009-08-16 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/10BM12178R0/2010',
#   {'isolation_date': Timestamp('2010-08-13 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/10BM07040R0/2010',
#   {'isolation_date': Timestamp('2010-08-01 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/blue-winged teal/Prince Edward Island/03912/2009',
#   {'isolation_date': Timestamp('2009-08-19 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Blue-Winged Teal/Avian',
#    'state': 'Prince Edward Island'}),
#  ('A/blue-winged teal/Nova Scotia/00078/2010',
#   {'isolation_date': Timestamp('2010-09-07 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Teal/Avian',
#    'state': 'Nova Scotia'}),
#  ('A/mallard/Interior Alaska/10BM04626R0/2010',
#   {'isolation_date': Timestamp('2010-07-18 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/shorebird/Delaware Bay/250/2009',
#   {'isolation_date': Timestamp('2009-05-20 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware Bay'}),
#  ('A/mallard/Interior Alaska/10BM08100R0/2010',
#   {'isolation_date': Timestamp('2010-08-04 00:00:00'),
#    'subtype': 'H7N3',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/ring-necked duck/Interior Alaska/10BM05617R0/2010',
#   {'isolation_date': Timestamp('2010-07-26 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Ring-necked Duck/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/shorebird/Delaware/300/2009',
#   {'isolation_date': Timestamp('2009-05-20 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware'}),
#  ('A/mallard/California/5222/2009',
#   {'isolation_date': Timestamp('2009-07-27 00:00:00'),
#    'subtype': 'H5N2',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'California'}),
#  ('A/ring-billed gull/Quebec/02622-1/2009',
#   {'isolation_date': Timestamp('2009-07-20 00:00:00'),
#    'subtype': '(N6)',
#    'host': 'IRD:Gull/Avian',
#    'state': 'Quebec'}),
#  ('A/mallard/Wisconsin/2785/2009',
#   {'isolation_date': Timestamp('2009-10-31 00:00:00'),
#    'subtype': 'H2N3',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Wisconsin'}),
#  ('A/ruddy turnstone/New Jersey/AI09-525/2009',
#   {'isolation_date': Timestamp('2009-05-26 00:00:00'),
#    'subtype': 'H1N7',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'New Jersey'}),
#  ('A/American black duck/New Brunswick/00587/2010',
#   {'isolation_date': Timestamp('2010-08-15 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/mallard/Interior Alaska/9BM8829R0/2009',
#   {'isolation_date': Timestamp('2009-08-11 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Iowa/10OS2721/2010',
#   {'isolation_date': Timestamp('2010-10-16 00:00:00'),
#    'subtype': 'H2N2',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Iowa'}),
#  ('A/mallard/Interior Alaska/10BM06448R0/2010',
#   {'isolation_date': Timestamp('2010-07-30 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Wisconsin/10OS2917/2010',
#   {'isolation_date': Timestamp('2010-10-03 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Wisconsin'}),
#  ('A/mallard/Interior Alaska/9BM2751R0/2009',
#   {'isolation_date': Timestamp('2009-07-15 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/9BM7232R0/2009',
#   {'isolation_date': Timestamp('2009-08-06 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/long-tailed duck/Wisconsin/10OS3915/2010',
#   {'isolation_date': Timestamp('2010-11-16 00:00:00'),
#    'subtype': 'H3N6',
#    'host': 'IRD:Duck/Avian',
#    'state': 'Wisconsin'}),
#  ('A/mallard/Arkansas/AI09-5649/2009',
#   {'isolation_date': Timestamp('2009-12-11 00:00:00'),
#    'subtype': 'H9N2',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Arkansas'}),
#  ('A/northern pintail/Interior Alaska/9BM11409R0/2009',
#   {'isolation_date': Timestamp('2009-08-18 00:00:00'),
#    'subtype': 'H12N5',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/northern pintail/Interior Alaska/10BM06720R0/2010',
#   {'isolation_date': Timestamp('2010-07-30 00:00:00'),
#    'subtype': 'H7N3',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Minnesota/AI09-1684/2009',
#   {'isolation_date': Timestamp('2009-07-27 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Minnesota'}),
#  ('A/green-winged teal/Nova Scotia/00354/2010',
#   {'isolation_date': Timestamp('2010-08-08 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Green-winged Teal/Avian',
#    'state': 'Nova Scotia'}),
#  ('A/shorebird/Delaware Bay/271/2009',
#   {'isolation_date': Timestamp('2009-05-20 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Shorebird/Avian',
#    'state': 'Delaware Bay'}),
#  ('A/northern pintail/Interior Alaska/10BM14807R2/2010',
#   {'isolation_date': Timestamp('2010-08-18 00:00:00'),
#    'subtype': 'H9N2',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/10BM12172R0/2010',
#   {'isolation_date': Timestamp('2010-08-13 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/ruddy turnstone/New Jersey/AI09-1228/2009',
#   {'isolation_date': Timestamp('2009-06-03 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'New Jersey'}),
#  ('A/northern pintail/Interior Alaska/9BM6205R0/2009',
#   {'isolation_date': Timestamp('2009-08-02 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Interior Alaska/9BM3076R0/2009',
#   {'isolation_date': Timestamp('2009-07-18 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/gadwall/Nova Scotia/00783/2010',
#   {'isolation_date': Timestamp('2010-09-07 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Gadwall/Avian',
#    'state': 'Nova Scotia'}),
#  ('A/blue-winged Teal/North Dakota/AI09-3642/2009',
#   {'isolation_date': Timestamp('2009-09-04 00:00:00'),
#    'subtype': 'H3N1',
#    'host': 'IRD:Blue-Winged Teal/Avian',
#    'state': 'North Dakota'}),
#  ('A/mallard/Wisconsin/4197/2009',
#   {'isolation_date': Timestamp('2009-12-03 00:00:00'),
#    'subtype': 'H1N1',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Wisconsin'}),
#  ('A/ruddy turnstone/New Jersey/AI09-377/2009',
#   {'isolation_date': Timestamp('2009-05-14 00:00:00'),
#    'subtype': 'H6N1',
#    'host': 'IRD:Ruddy Turnstone/Avian',
#    'state': 'New Jersey'}),
#  ('A/gadwall/Mississippi/10OS4531/2010',
#   {'isolation_date': Timestamp('2010-12-11 00:00:00'),
#    'subtype': 'H6N2',
#    'host': 'IRD:Gadwall/Avian',
#    'state': 'Mississippi'}),
#  ('A/American black duck/New Brunswick/00617/2010',
#   {'isolation_date': Timestamp('2010-08-16 00:00:00'),
#    'subtype': '(N6)',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/American black duck/New Brunswick/03511/2009',
#   {'isolation_date': Timestamp('2009-09-10 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:American Black Duck/Avian',
#    'state': 'New Brunswick'}),
#  ('A/American wigeon/California/2423/2010',
#   {'isolation_date': Timestamp('2010-10-23 00:00:00'),
#    'subtype': 'H6N1',
#    'host': 'IRD:American Wigeon/Avian',
#    'state': 'California'}),
#  ('A/mallard/Nova Scotia/03271/2009',
#   {'isolation_date': Timestamp('2009-08-06 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Nova Scotia'}),
#  ('A/mallard/Alberta/35/2009',
#   {'isolation_date': Timestamp('2009-08-19 00:00:00'),
#    'subtype': 'H2N3',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Alberta'}),
#  ('A/blue-winged teal/Nova Scotia/00075/2010',
#   {'isolation_date': Timestamp('2010-09-07 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Teal/Avian',
#    'state': 'Nova Scotia'}),
#  ('A/blue-winged teal/New Brunswick/00771/2010',
#   {'isolation_date': Timestamp('2010-08-25 00:00:00'),
#    'subtype': 'H3N8',
#    'host': 'IRD:Teal/Avian',
#    'state': 'New Brunswick'}),
#  ('A/northern pintail/Interior Alaska/10BM04722R0/2010',
#   {'isolation_date': Timestamp('2010-07-18 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Northern Pintail/Avian',
#    'state': 'Interior Alaska'}),
#  ('A/mallard/Missouri/10MO0391/2010',
#   {'isolation_date': Timestamp('2010-12-22 00:00:00'),
#    'subtype': 'H10N7',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Missouri'}),
#  ('A/mallard/Interior Alaska/9BM2252/2009',
#   {'isolation_date': Timestamp('2009-07-11 00:00:00'),
#    'subtype': 'H4N6',
#    'host': 'IRD:Mallard/Avian',
#    'state': 'Interior Alaska'}),
#  ...]

# %%
undir_nodes = pd.DataFrame()

for node in undirected_G.nodes(data=True):
    node_series = pd.Series()
    node_series['Isolate Name'] = node[0]
    node_series['State'] = node[1]['state']
    node_series['Subtype'] = node[1]['subtype']
    node_series['Host'] = node[1]['host']
    node_series['Isolation Date'] = node[1]['isolation_date']
    
    undir_nodes = undir_nodes.append(node_series, ignore_index=True)
    
undir_nodes['Isolation Date'] = undir_nodes['Isolation Date'].astype('datetime64[ns]')
undir_nodes.to_csv('3.10 - Full Transmission as CSV/Undirected Transmission Nodes.csv')

# %%
# Write CSV file of the undirected graph

undir_edges = pd.DataFrame()

for edge in undirected_G.edges(data=True):
    df_edge = pd.Series()
    df_edge['Isolate1'] = edge[0]
    df_edge['Isolate2'] = edge[1]
    df_edge['Transmission Type'] = edge[2]['trtype']        
    df_edge['Time Delta'] = edge[2]['time_delta']
    df_edge['Weight'] = edge[2]['weight']
    df_edge['Time Class'] = edge[2]['tr_timeclass']
   
    undir_edges = undir_edges.append(df_edge, ignore_index=True)
    
undir_edges.to_csv('3.10 - Full Transmission as CSV/Undirected Full Transmission Edges.csv')

# %%
# Modify the Nodes column names to fit with the undirected isolate1-isolate2 paradigm.
undir_nodes.columns = map(lambda x: x + '1', undir_nodes.columns)
print(undir_nodes.columns)

undir_graph = undir_edges.set_index('Isolate1').join(undir_nodes.set_index('Isolate Name1'))
undir_nodes.columns = map(lambda x: x.replace('1', '2'), undir_nodes.columns)
print(undir_nodes.columns)

undir_graph = undir_graph.reset_index()
print(undir_graph.columns)

undir_graph.columns = ['Isolate1' if item == 'index' else item for item in list(undir_graph.columns)]
print(undir_graph.columns)

undir_graph = undir_graph.set_index('Isolate2').join(undir_nodes.set_index('Isolate Name2'))
undir_graph = undir_graph.reset_index()
undir_graph.columns = ['Isolate2' if item == 'index' else item for item in list(undir_graph.columns)]
undir_graph.columns

undir_graph.to_csv('3.10 - Full Transmission as CSV/Undirected Full Transmissions.csv')
# Out:
# Index(['Host1', 'Isolate Name1', 'Isolation Date1', 'State1', 'Subtype1'], dtype='object')
# Index(['Host2', 'Isolate Name2', 'Isolation Date2', 'State2', 'Subtype2'], dtype='object')
# Index(['index', 'Isolate2', 'Time Class', 'Time Delta', 'Transmission Type', 'Weight', 'Host1', 'Isolation Date1', 'State1', 'Subtype1'], dtype='object')
# Index(['Isolate1', 'Isolate2', 'Time Class', 'Time Delta', 'Transmission Type', 'Weight', 'Host1', 'Isolation Date1', 'State1', 'Subtype1'], dtype='object')

# %%
undir_graph[undir_graph['Time Delta'] < 2]
# Out:
#                                                Isolate2  \
# 0        A/American black duck/New Brunswick/00321/2010
# 1        A/American black duck/New Brunswick/00326/2010
# 2        A/American black duck/New Brunswick/00326/2010
# 3        A/American black duck/New Brunswick/00328/2010
# 4        A/American black duck/New Brunswick/00344/2010
# 5        A/American black duck/New Brunswick/00385/2010
# 6        A/American black duck/New Brunswick/00425/2010
# 7        A/American black duck/New Brunswick/00464/2010
# 9        A/American black duck/New Brunswick/00467/2010
# 12       A/American black duck/New Brunswick/00469/2010
# 15       A/American black duck/New Brunswick/00470/2010
# 17       A/American black duck/New Brunswick/00472/2010
# 18       A/American black duck/New Brunswick/00472/2010
# 20       A/American black duck/New Brunswick/00476/2010
# 21       A/American black duck/New Brunswick/00478/2010
# 23       A/American black duck/New Brunswick/00481/2010
# 25       A/American black duck/New Brunswick/00499/2010
# 26       A/American black duck/New Brunswick/00499/2010
# 28       A/American black duck/New Brunswick/00500/2010
# 29       A/American black duck/New Brunswick/00500/2010
# 31       A/American black duck/New Brunswick/00522/2010
# 36       A/American black duck/New Brunswick/00523/2010
# 42       A/American black duck/New Brunswick/00618/2010
# 43       A/American black duck/New Brunswick/00619/2010
# 44       A/American black duck/New Brunswick/00619/2010
# 45       A/American black duck/New Brunswick/00619/2010
# 46       A/American black duck/New Brunswick/00624/2010
# 47       A/American black duck/New Brunswick/00624/2010
# 48       A/American black duck/New Brunswick/00624/2010
# 50       A/American black duck/New Brunswick/00906/2010
# ...                                                 ...
# 1125  A/northern shoveler/Interior Alaska/9BM12332R0...
# 1126  A/northern shoveler/Interior Alaska/9BM12332R0...
# 1128      A/northern shoveler/Mississippi/10OS4526/2010
# 1129        A/red-necked grebe/Minnesota/AI10-1954/2010
# 1133                A/ring-billed gull/Quebec/G018/2010
# 1134                A/ring-billed gull/Quebec/G018/2010
# 1137              A/ring-necked duck/Illinois/4125/2009
# 1138  A/ring-necked duck/Interior Alaska/10BM05792R0...
# 20             0     Inter-Species  7.995223              IRD:Mallard/Avian
# 21             0     Intra-Species  7.996190  IRD:American Black Duck/Avian
# 23             0     Intra-Species  7.997571  IRD:American Black Duck/Avian
# 25             0     Intra-Species  7.996645  IRD:American Black Duck/Avian
# 26             0     Intra-Species  7.996279  IRD:American Black Duck/Avian
# 28             0     Intra-Species  7.961111  IRD:American Black Duck/Avian
# 29             0     Inter-Species  7.998692              IRD:Mallard/Avian
# 31             0     Intra-Species  7.998647  IRD:American Black Duck/Avian
# 36             1     Intra-Species  7.998074  IRD:American Black Duck/Avian
# 42             0     Intra-Species  8.000000  IRD:American Black Duck/Avian
# 43             0     Intra-Species  7.997323  IRD:American Black Duck/Avian
# 44             0     Intra-Species  7.997323  IRD:American Black Duck/Avian
# 45             0     Intra-Species  7.997323  IRD:American Black Duck/Avian
# 46             0     Intra-Species  8.000000  IRD:American Black Duck/Avian
# 47             0     Intra-Species  8.000000  IRD:American Black Duck/Avian
# 48             0     Intra-Species  7.998849  IRD:American Black Duck/Avian
# 50             0     Intra-Species  8.000000  IRD:American Black Duck/Avian
# ...          ...               ...       ...                            ...
# 1125           0     Inter-Species  7.994339              IRD:Mallard/Avian
# 1126           0     Inter-Species  7.994030              IRD:Mallard/Avian
# 1128           1     Inter-Species  7.991123              IRD:Gadwall/Avian
# 1129           0     Intra-Species  7.999566                IRD:Grebe/Avian
# 1133           0     Intra-Species  7.993516                 IRD:Gull/Avian
# 1134           0     Intra-Species  7.995170                 IRD:Gull/Avian
# 1137           0     Inter-Species  8.000000              IRD:Mallard/Avian
# 1138           0     Inter-Species  7.995888    IRD:Northern Shoveler/Avian
# 1139           0     Inter-Species  8.000000    IRD:Northern Shoveler/Avian
# 1140           0     Inter-Species  7.998482  IRD:American Black Duck/Avian
# 1147           0     Intra-Species  7.993106      IRD:Ruddy Turnstone/Avian
# 1173           0     Intra-Species  7.999547      IRD:Ruddy Turnstone/Avian
# 1177           0     Intra-Species  7.998020            IRD:Shorebird/Avian
# 1178           0     Intra-Species  7.996898            IRD:Shorebird/Avian
# 1179           0     Intra-Species  7.998545            IRD:Shorebird/Avian
# 1180           0     Intra-Species  7.997985            IRD:Shorebird/Avian
# 1182           0     Intra-Species  7.989587            IRD:Shorebird/Avian
# 1185           1     Intra-Species  7.992587            IRD:Shorebird/Avian
# 1187           0     Intra-Species  7.998717            IRD:Shorebird/Avian
# 1189           0     Intra-Species  7.993873            IRD:Shorebird/Avian
# 1190           0     Intra-Species  7.998389            IRD:Shorebird/Avian
# 1191           0     Intra-Species  7.999301            IRD:Shorebird/Avian
# 1192           0     Intra-Species  7.999301            IRD:Shorebird/Avian
# 1193           0     Intra-Species  8.000000            IRD:Shorebird/Avian
# 1198           1     Inter-Species  7.995685      IRD:Ruddy Turnstone/Avian
# 1200           0     Intra-Species  7.966778            IRD:Shorebird/Avian
# 1201           0     Intra-Species  7.997948            IRD:Shorebird/Avian
# 1202           0     Intra-Species  7.979379            IRD:Shorebird/Avian
# 1205           1     Intra-Species  7.995651               IRD:Turkey/Avian
# 50        2010-09-14    New Brunswick    H10N7
# ...              ...              ...      ...
# 1125      2009-09-02  Interior Alaska     H3N8
# 1126      2009-09-02  Interior Alaska     H3N8
# 1128      2010-12-10      Mississippi     H6N2
# 1129      2010-07-07        Minnesota     H1N1
# 1133      2010-05-12           Quebec     H1N3
# 1134      2010-05-12           Quebec     H1N3
# 1137      2009-11-29         Illinois     H4N8
# 1138      2010-07-26  Interior Alaska     H3N8
# 1139      2010-07-26  Interior Alaska     H3N8
# 1140      2009-08-09    New Brunswick     H3N8
# 1147      2009-06-03       New Jersey    H10N7
# 1173      2009-05-22       New Jersey     H1N8
# 1177      2009-05-20     Delaware Bay    H10N7
# 1178      2009-05-20     Delaware Bay    H10N7
# 1179      2009-05-20     Delaware Bay    H10N7
# 1180      2009-05-20     Delaware Bay    H10N7
# 1182      2009-05-20     Delaware Bay     H6N1
# 1185      2009-05-20     Delaware Bay    H10N7
# 1187      2009-05-20     Delaware Bay    H10N7
# 1189      2009-05-20     Delaware Bay    H10N7
# 1190      2009-05-20     Delaware Bay     H1N1
# 1191      2009-05-20     Delaware Bay    H10N1
# 1192      2009-05-20     Delaware Bay    H10N1
# 1193      2009-05-20     Delaware Bay    H10N1
# 1198      2009-06-04     Delaware Bay     H1N7
# 1200      2009-05-20         Delaware     H1N1
# 1201      2009-05-20         Delaware     H1N1
# 1202      2009-05-20         Delaware     H1N1
# 1205      2010-11-25               MB     H5N2
# 1209      2010-09-26        Wisconsin     H3N8
#
# [546 rows x 14 columns]

# %%
# Undirected version should have only 1213 edges.
# 22 September 2014: Update - with 2011 isolates removed, there are only 1210. This is consistent with Nichola removing 
# 3 edges as a result of 2011 isolates being present.
len(undirected_G.edges())
# Out:
# 1210

# %%
# Create a graph based on geography

geonet = nx.DiGraph()

year = df_full

# Add in the nodes 

geographic_locations = np.unique(year[['State1', 'State2']].values)
print(geographic_locations)

for place in geographic_locations:
    geonet.add_node(place)

# Add in the edges with initial weights 0

for row in year.iterrows():
    geonet.add_edge(row[1]['State1'], row[1]['State2'], weight=0)

# Add in the weights

for row in year.iterrows():
    if geonet.has_edge(row[1]['State1'], row[1]['State2']):
        geonet[row[1]['State1']][row[1]['State2']]['weight'] += row[1]['Weight']
        
# Add in lat-long data for each state
for row in lat_long_vals.iterrows():
    geonet.node[row[1]['State']]['N'] = row[1]['N']
    geonet.node[row[1]['State']]['W'] = row[1]['W']

fig = plt.figure(figsize=(12,12))
nx.draw_networkx(geonet)

d = json_graph.node_link_data(geonet) # node-link format to serialize
json.dump(d, open('viz/geonet.json','w'))
# Out:
# ['Alberta' 'Arkansas' 'California' 'Delaware' 'Delaware Bay' 'Guatemala'
#  'Illinois' 'Indiana' 'Interior Alaska' 'Iowa' 'Louisiana' 'MB' 'Michigan'
#  'Minnesota' 'Mississippi' 'Missouri' 'New Brunswick' 'New Jersey'
#  'North Dakota' 'Nova Scotia' 'Nunavet' 'Ohio' 'Prince Edward Island'
#  'Quebec' 'Southeastern Alaska' 'Texas' 'Wisconsin']
